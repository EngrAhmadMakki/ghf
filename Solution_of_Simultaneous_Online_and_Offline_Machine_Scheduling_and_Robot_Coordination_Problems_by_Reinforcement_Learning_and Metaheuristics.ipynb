# %% [markdown]
# <a href="https://colab.research.google.com/github/EngrAhmadMakki/ghf/blob/main/Solution_of_Simultaneous_Online_and_Offline_Machine_Scheduling_and_Robot_Coordination_Problems_by_Reinforcement_Learning_and%C2%A0Metaheuristics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Genetic Algorithm with Q-Learning in Python**
# This implementation demonstrates a combination of Genetic Algorithm (GA) and Q-learning. The process involves evolving a population using crossover and mutation, while Q-learning is used to decide the best actions for optimizing the fitness of the population.
#
#
# The figure below shows the **training procedure of Q-GA (Q-learning combined with Genetic Algorithm)**:
#
# ![Training procedure of Q-GA](/content/Q-GA.jpeg)

# %%
# Import necessary libraries
import numpy as np
import random

# %% [markdown]
# ## **Step 1: Parameter Initialization**
#
# We initialize parameters for both the genetic algorithm and Q-learning.
#
# - `population_size`: The number of individuals in the population.
# - `mutation_rate`: The probability of a mutation occurring on a gene.
# - `crossover_rate`: The probability of applying crossover between two parents.
# - `generations`: Maximum number of iterations the genetic algorithm will run.
# - `alpha`, `gamma`, and `epsilon`: Q-learning parameters (learning rate, discount factor, and exploration rate).

# %%
# Parameters for the Genetic Algorithm
population_size = 20
mutation_rate = 0.01
crossover_rate = 0.7
generations = 100

# Q-learning parameters
alpha = 0.1  # learning rate
gamma = 0.9  # discount factor
epsilon = 0.1  # exploration rate

# %% [markdown]
# ## **Step 2: Q-table Initialization**
#
# We initialize the Q-table, which will store Q-values for two actions: crossover and mutation. The Q-table will have dimensions based on the population size and the number of actions.

# %%
# Initialize the Q-table (actions are mutation and crossover rates)
actions = ['crossover', 'mutation']
Q_table = np.zeros((population_size, len(actions)))

# %% [markdown]
# ## **Step 3: Fitness Function**
#
# The fitness function evaluates how "fit" an individual is. For demonstration, we use a simple fitness function that sums the individual's binary genes. A higher sum indicates better fitness.

# %%
# Define a simple fitness function
def fitness_function(individual):
    # For demonstration purposes, we use the sum of the genes as fitness
    return sum(individual)

# %% [markdown]
# ## **Step 4: Population Initialization**
#
# We generate the initial population, where each individual is represented by a list of binary values (`0` or `1`).

# %%
# Initialize the population (binary encoded individuals)
def initialize_population(population_size, gene_length):
    return [np.random.randint(0, 2, gene_length).tolist() for _ in range(population_size)]

# %% [markdown]
# ## **Step 5: Crossover and Mutation Operators**
#
# We define two key genetic operations: crossover and mutation. These operations create new offspring from existing individuals in the population.
#
# - `crossover`: Combines the genes of two parents.
# - `mutation`: Flips bits in an individual's genes based on the mutation rate.

# %%
# Crossover operation
def crossover(parent1, parent2):
    point = random.randint(1, len(parent1) - 1)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2

# Mutation operation
def mutation(individual):
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] = 1 - individual[i]  # Flip the bit
    return individual

# %% [markdown]
# ## **Step 6: Parent Selection (Tournament Selection)**
#
# We select parents using tournament selection. A subset of individuals is chosen, and the one with the highest fitness is selected as a parent.

# %%
# Select individuals based on fitness (tournament selection)
def select_individual(population, fitness_values):
    tournament_size = 3
    selected = random.sample(list(zip(population, fitness_values)), tournament_size)
    selected.sort(key=lambda x: x[1], reverse=True)
    return selected[0][0]

# %% [markdown]
# ## **Step 7: Q-Learning Action Selection (ε-Greedy)**
#
# The algorithm selects whether to apply crossover or mutation using an ε-greedy policy. With probability `epsilon`, it explores a random action, and otherwise, it exploits the best action learned so far.

# %%
# Q-Learning action selection (ε-greedy)
def choose_action(state, epsilon):
    if random.random() < epsilon:
        return random.choice(actions)
    else:
        return actions[np.argmax(Q_table[state])]

# %% [markdown]
# ## **Step 8: Q-table Update**
#
# We update the Q-table based on the reward received from the new population's fitness. The Q-value update is based on the Q-learning formula.

# %%
# Update Q-table
def update_Q_table(state, action_idx, reward, next_state):
    best_next_action = np.argmax(Q_table[next_state])
    Q_table[state, action_idx] = Q_table[state, action_idx] + alpha * (
        reward + gamma * Q_table[next_state, best_next_action] - Q_table[state, action_idx])

# %% [markdown]
# ## **Step 9: Main Genetic Algorithm with Q-Learning Loop**
#
# Here we integrate the genetic algorithm with Q-learning. The population evolves over a number of generations, and Q-learning is used to decide the best actions to improve the population's fitness.

# %%
# Main genetic algorithm with Q-learning loop
def genetic_algorithm():
    population = initialize_population(population_size, gene_length=10)
    for generation in range(generations):
        fitness_values = [fitness_function(individual) for individual in population]

        new_population = []
        for _ in range(population_size // 2):  # Generating new population by crossover and mutation
            parent1 = select_individual(population, fitness_values)
            parent2 = select_individual(population, fitness_values)

            action = choose_action(_, epsilon)  # Choose action (crossover/mutation)
            if action == 'crossover':
                child1, child2 = crossover(parent1, parent2)
            else:  # Apply mutation
                child1, child2 = mutation(parent1), mutation(parent2)

            new_population.extend([child1, child2])

        # Evaluate new population fitness
        new_fitness_values = [fitness_function(individual) for individual in new_population]

        # Update Q-table based on the new population's fitness (reward is fitness gain)
        for i in range(population_size):
            reward = new_fitness_values[i] - fitness_values[i]
            update_Q_table(i, actions.index(action), reward, (i + 1) % population_size)

        # Check if maximum iteration is reached
        if generation == generations - 1:
            print("Reached final iteration")
            break

        # Update population for next generation
        population = new_population

    print("Q-table after training:")
    print(Q_table)

# %% [markdown]
# ## **Step 10: Running the Genetic Algorithm**
#
# Finally, we run the genetic algorithm to evolve the population over the defined number of generations and print the Q-table after training.

# %%
# Running the Genetic Algorithm
genetic_algorithm()
# Out:
# Reached final iteration
# Q-table after training:
# [[0.16496673 0.05498821]
#  [0.16294691 0.06242408]
#  [0.16296386 0.07358122]
#  [0.16655192 0.0859907 ]
#  [0.171106   0.08036942]
#  [0.17133276 0.06857716]
#  [0.17400933 0.05129401]
#  [0.17541885 0.06329365]
#  [0.17503209 0.0722906 ]
#  [0.17269268 0.07315901]
#  [0.16841078 0.06293913]
#  [0.16299244 0.0621853 ]
#  [0.15873507 0.06973963]
#  [0.15747673 0.07914056]
#  [0.15885482 0.07818248]
#  [0.1621142  0.07688919]
#  [0.16588733 0.0781177 ]
#  [0.16856325 0.07309005]
#  [0.16871431 0.05075149]
#  [0.16625572 0.05848406]]

# %%
# # Import necessary libraries
# import numpy as np
# import random

# # Parameters for the Genetic Algorithm
# population_size = 20
# mutation_rate = 0.01
# crossover_rate = 0.7
# generations = 100

# # Q-learning parameters
# alpha = 0.1  # learning rate
# gamma = 0.9  # discount factor
# epsilon = 0.1  # exploration rate

# # Initialize the Q-table (actions are mutation and crossover rates)
# actions = ['crossover', 'mutation']
# Q_table = np.zeros((population_size, len(actions)))

# # Define a simple fitness function
# def fitness_function(individual):
#     # For demonstration purposes, we use the sum of the genes as fitness
#     return sum(individual)

# # Initialize the population (binary encoded individuals)
# def initialize_population(population_size, gene_length):
#     return [np.random.randint(0, 2, gene_length).tolist() for _ in range(population_size)]

# # Crossover operation
# def crossover(parent1, parent2):
#     point = random.randint(1, len(parent1) - 1)
#     child1 = parent1[:point] + parent2[point:]
#     child2 = parent2[:point] + parent1[point:]
#     return child1, child2

# # Mutation operation
# def mutation(individual):
#     for i in range(len(individual)):
#         if random.random() < mutation_rate:
#             individual[i] = 1 - individual[i]  # Flip the bit
#     return individual

# # Select individuals based on fitness (tournament selection)
# def select_individual(population, fitness_values):
#     tournament_size = 3
#     selected = random.sample(list(zip(population, fitness_values)), tournament_size)
#     selected.sort(key=lambda x: x[1], reverse=True)
#     return selected[0][0]

# # Q-Learning action selection (ε-greedy)
# def choose_action(state, epsilon):
#     if random.random() < epsilon:
#         return random.choice(actions)
#     else:
#         return actions[np.argmax(Q_table[state])]

# # Update Q-table
# def update_Q_table(state, action_idx, reward, next_state):
#     best_next_action = np.argmax(Q_table[next_state])
#     Q_table[state, action_idx] = Q_table[state, action_idx] + alpha * (
#         reward + gamma * Q_table[next_state, best_next_action] - Q_table[state, action_idx])

# # Main genetic algorithm with Q-learning loop
# def genetic_algorithm():
#     population = initialize_population(population_size, gene_length=10)
#     for generation in range(generations):
#         fitness_values = [fitness_function(individual) for individual in population]

#         new_population = []
#         for _ in range(population_size // 2):  # Generating new population by crossover and mutation
#             parent1 = select_individual(population, fitness_values)
#             parent2 = select_individual(population, fitness_values)

#             action = choose_action(_, epsilon)  # Choose action (crossover/mutation)
#             if action == 'crossover':
#                 child1, child2 = crossover(parent1, parent2)
#             else:  # Apply mutation
#                 child1, child2 = mutation(parent1), mutation(parent2)

#             new_population.extend([child1, child2])

#         # Evaluate new population fitness
#         new_fitness_values = [fitness_function(individual) for individual in new_population]

#         # Update Q-table based on the new population's fitness (reward is fitness gain)
#         for i in range(population_size):
#             reward = new_fitness_values[i] - fitness_values[i]
#             update_Q_table(i, actions.index(action), reward, (i + 1) % population_size)

#         # Check if maximum iteration is reached
#         if generation == generations - 1:
#             print("Reached final iteration")
#             break

#         # Update population for next generation
#         population = new_population

#     print("Q-table after training:")
#     print(Q_table)

# # Running the Genetic Algorithm
# genetic_algorithm()

# %% [markdown]
# # **Genetic Algorithm with Q-Learning: Four-Segment Chromosome Representation**
#
# This Colab implements a hybrid Genetic Algorithm (GA) with Q-learning for solving machine scheduling problems, using a Four-Segment Chromosome Representation for optimization.
#
# We will focus on:
# 1. Cell formation (machine grouping)
# 2. Machine selection (operation assignment)
# 3. Local sequencing (job sequencing within cells)
# 4. Global scheduling (overall scheduling of jobs and product families)

# %%
# Import necessary libraries
import numpy as np
import random

# %% [markdown]
# # Define Genetic Algorithm Parameters
# Here, we define key parameters for the Genetic Algorithm (GA) such as population size, mutation rate, and generations. Additionally, we define Q-learning parameters such as learning rate, discount factor, and exploration rate.

# %%
# Parameters for the Genetic Algorithm
population_size = 20
mutation_rate = 0.01
crossover_rate = 0.7
generations = 100

# Q-learning parameters
alpha = 0.1  # learning rate
gamma = 0.9  # discount factor
epsilon = 0.1  # exploration rate

# %% [markdown]
# # Define Machines, Jobs, and Product Families
# We define the machine resources (`m1`, `m2`, etc.) and the jobs that need to be scheduled. Additionally, we define product families, which contain jobs grouped together.

# %%
# Machine and job definitions (as per the image)
machines = ['m1', 'm2', 'm3', 'm4', 'm5']
cells = ['c1', 'c2']  # Cell formation gene

# Individualized products (jobs j1 and j2)
jobs = ['j1', 'j2']
operations = {
    'j1': ['o11', 'o12', 'o13', 'o14'],
    'j2': ['o21', 'o22', 'o23']
}

# Product families (Family 1 with j3, Family 2 with j4)
product_families = {
    'j3': ['o31', 'o32'],  # Family 1
    'j4': ['o41', 'o42']   # Family 2
}

# Volume of products in each family
family_volumes = {
    'j3': 3,  # 3 products in Family 1
    'j4': 2   # 2 products in Family 2
}

# %% [markdown]
# # Define Fitness Function
# The fitness function evaluates the schedule's efficiency. It aims to minimize the total makespan or another relevant scheduling metric.

# %%
# # Fitness function (total makespan or any other scheduling metric)
# def fitness_function(schedule):
#     # Simplified fitness function, adjust for actual scheduling problem
#     return sum(sum(machine_schedule) for machine_schedule in schedule)


# Fitness function: calculate based on a mock schedule where numerical values are extracted
def fitness_function(individual):
    """
    Calculate the fitness of an individual based on the number of operations.
    This is a simplified fitness function and can be adjusted to your specific problem.
    """
    cell_assignment, machine_assignment, local_sequence, global_schedule = individual

    # Mock-up: Assign fitness based on the number of operations (just as an example)
    fitness = 0

    # Example: Fitness could be based on the number of operations assigned to machines
    for job in machine_assignment:
        fitness += len(machine_assignment[job])  # Add the number of operations

    # Optionally adjust based on other factors, like local sequencing or global schedule

    return fitness

# %% [markdown]
# # Initialize Population with Four-Segment Chromosome Representation
# This section initializes the population of chromosomes using the four-segment representation. Each chromosome consists of:
# 1. **Cell formation**: Grouping machines into cells.
# 2. **Machine selection**: Assigning operations to machines.
# 3. **Local sequencing**: Ordering jobs and operations within machines and product families.
# 4. **Global scheduling**: Scheduling both jobs and product families.

# %%
# Four-Segment Chromosome Representation (with product families)
def initialize_population(population_size, gene_length):
    population = []
    for _ in range(population_size):
        # 1st Segment: Cell formation (Assign machines to cells)
        cell_assignment = [random.choice(cells) for _ in range(len(machines))]

        # 2nd Segment: Machine selection (Assign operations to machines)
        machine_assignment = {job: [random.choice(machines) for _ in operations[job]] for job in jobs}
        machine_assignment.update({family: [random.choice(machines) for _ in product_families[family]] for family in product_families})

        # 3rd Segment: Local sequencing (Order jobs within machines and families)
        local_sequence = {job: random.sample(operations[job], len(operations[job])) for job in jobs}
        local_sequence.update({family: random.sample(product_families[family], len(product_families[family])) for family in product_families})

        # 4th Segment: Global scheduling (Overall schedule of jobs and families)
        global_schedule = random.sample(jobs + list(product_families.keys()), len(jobs) + len(product_families))  # Random order of jobs and families

        population.append((cell_assignment, machine_assignment, local_sequence, global_schedule))
    return population

# %% [markdown]
# # Crossover and Mutation Operations
# The crossover and mutation operations are essential for genetic algorithms. The crossover exchanges segments between two parents to produce new offspring, while mutation introduces variability into the population.

# %%
# Crossover operation
def crossover(parent1, parent2):
    point = random.randint(1, len(parent1[0]) - 1)

    # Cross cells, machine assignments, local sequencing, and global scheduling
    child1 = (
        parent1[0][:point] + parent2[0][point:],
        parent1[1],  # Can perform more complex crossover for this segment
        parent1[2],
        parent1[3][:point] + parent2[3][point:]
    )
    child2 = (
        parent2[0][:point] + parent1[0][point:],
        parent2[1],
        parent2[2],
        parent2[3][:point] + parent1[3][point:]
    )
    return child1, child2

# Mutation operation
def mutation(individual):
    # Ensure individual is mutable (convert to list if necessary)
    individual = list(individual)

    # Mutate each segment randomly
    if random.random() < mutation_rate:
        individual[0] = [random.choice(cells) for _ in individual[0]]  # Mutate cell formation

    if random.random() < mutation_rate:
        individual[1] = {job: [random.choice(machines) for _ in operations[job]] for job in jobs}  # Mutate machine selection
        individual[1].update({family: [random.choice(machines) for _ in product_families[family]] for family in product_families})

    if random.random() < mutation_rate:
        individual[2] = {job: random.sample(operations[job], len(operations[job])) for job in jobs}  # Mutate local sequencing
        individual[2].update({family: random.sample(product_families[family], len(product_families[family])) for family in product_families})

    if random.random() < mutation_rate:
        individual[3] = random.sample(jobs + list(product_families.keys()), len(jobs) + len(product_families))  # Mutate global scheduling

    return individual

# %% [markdown]
# # Selection and Q-Learning Action Selection
# Tournament selection is used to choose parents based on their fitness. Q-Learning helps select actions (crossover or mutation) based on the state of the population.

# %%
# Select individuals based on fitness
def select_individual(population, fitness_values):
    tournament_size = 3
    selected = random.sample(list(zip(population, fitness_values)), tournament_size)
    selected.sort(key=lambda x: x[1], reverse=True)
    return selected[0][0]

# Define possible actions for Q-learning: crossover and mutation
actions = ['crossover', 'mutation']

# Q-Learning action selection (ε-greedy)
def choose_action(state, epsilon):
    if random.random() < epsilon:
        return random.choice(actions)
    else:
        return actions[np.argmax(Q_table[state])]

# %% [markdown]
# # Q-Table Update Function
# The Q-table is updated based on the rewards (improvements in fitness) after applying actions (crossover or mutation). The goal is to learn the best strategy for evolving the population over generations.

# %%
# # Update Q-table
# def update_Q_table(state, action_idx, reward, next_state):
#     best_next_action = np.argmax(Q_table[next_state])
#     Q_table[state, action_idx] = Q_table[state, action_idx] + alpha * (
#         reward + gamma * Q_table[next_state, best_next_action] - Q_table[state, action_idx])

# Update Q-table
def update_Q_table(state, action_idx, reward, next_state):
    best_next_action = np.argmax(Q_table[next_state])  # Find best next action
    Q_table[state, action_idx] = Q_table[state, action_idx] + alpha * (
        reward + gamma * Q_table[next_state, best_next_action] - Q_table[state, action_idx])

# %% [markdown]
# # Main Genetic Algorithm with Q-Learning Loop
# This is the main loop where the genetic algorithm operates. It includes the initialization of the population, selection of parents, crossover, mutation, and updating the Q-table.

# %%
# Update Q-table based on the fitness improvement
def genetic_algorithm():
    population = initialize_population(population_size, gene_length=10)
    for generation in range(generations):
        fitness_values = [fitness_function(individual) for individual in population]

        new_population = []
        for _ in range(population_size // 2):
            parent1 = select_individual(population, fitness_values)
            parent2 = select_individual(population, fitness_values)

            action = choose_action(_, epsilon)
            if action == 'crossover':
                child1, child2 = crossover(parent1, parent2)
            else:  # Apply mutation
                child1, child2 = mutation(parent1), mutation(parent2)

            new_population.extend([child1, child2])

        # Evaluate new population fitness
        new_fitness_values = [fitness_function(individual) for individual in new_population]

        # Update Q-table based on the new population's fitness
        for i in range(population_size):
            reward = new_fitness_values[i] - fitness_values[i]
            if reward > 0:
                reward = 1  # Positive reward for improvement
            elif reward < 0:
                reward = -1  # Negative reward for worse performance
            else:
                reward = 0  # No reward for no change

            update_Q_table(i, actions.index(action), reward, (i + 1) % population_size)

        # Update population for the next generation
        population = new_population

    print("Q-table after training:")
    print(Q_table)

# %% [markdown]
# # Run the Genetic Algorithm
# Finally, we run the genetic algorithm with Q-learning to optimize the scheduling problem.

# %%
# Running the Genetic Algorithm
genetic_algorithm()
# Out:
# Q-table after training:
# [[0.07516176 0.07116486]
#  [0.07627687 0.07362578]
#  [0.07657874 0.07647516]
#  [0.07307146 0.07579815]
#  [0.07076778 0.07224609]
#  [0.07017628 0.06970029]
#  [0.06990116 0.06635273]
#  [0.06995932 0.06898969]
#  [0.0702843  0.07070528]
#  [0.07080275 0.07098926]
#  [0.07152912 0.06965009]
#  [0.07250563 0.07038787]
#  [0.07347678 0.07317597]
#  [0.07306422 0.0746188 ]
#  [0.07257117 0.0740927 ]
#  [0.07220245 0.07349458]
#  [0.0718152  0.07278486]
#  [0.07233548 0.07220908]
#  [0.07290222 0.06845176]
#  [0.07357621 0.07094563]]

# %%
import numpy as np
import random

# Parameters for the Genetic Algorithm
population_size = 20
mutation_rate = 0.01
crossover_rate = 0.7
generations = 100

# Q-learning parameters
alpha = 0.5  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.2  # Exploration rate

# Define possible actions for Q-learning: crossover and mutation
actions = ['crossover', 'mutation']

# Machine and job definitions (as per the image)
machines = ['m1', 'm2', 'm3', 'm4', 'm5']
cells = ['c1', 'c2']  # Cell formation gene

# Individualized products (jobs j1 and j2)
jobs = ['j1', 'j2']
operations = {
    'j1': ['o11', 'o12', 'o13', 'o14'],
    'j2': ['o21', 'o22', 'o23']
}

# Product families (Family 1 with j3, Family 2 with j4)
product_families = {
    'j3': ['o31', 'o32'],  # Family 1
    'j4': ['o41', 'o42']   # Family 2
}

# Volume of products in each family
family_volumes = {
    'j3': 3,  # 3 products in Family 1
    'j4': 2   # 2 products in Family 2
}

# Initialize Q-table with zeros
Q_table = np.zeros((population_size, len(actions)))

# Fitness function: calculate based on a mock schedule where numerical values are extracted
def fitness_function(individual):
    """
    Calculate the fitness of an individual based on the number of operations.
    This is a simplified fitness function and can be adjusted to your specific problem.
    """
    cell_assignment, machine_assignment, local_sequence, global_schedule = individual
    fitness = 0

    # Fitness based on the number of operations assigned to machines
    for job in machine_assignment:
        fitness += len(machine_assignment[job])  # Add the number of operations

    # Example penalty for inefficiency or randomness
    penalty = random.uniform(0.1, 1)
    fitness -= penalty

    return fitness

# Four-Segment Chromosome Representation (with product families)
def initialize_population(population_size, gene_length):
    population = []
    for _ in range(population_size):
        # 1st Segment: Cell formation (Assign machines to cells)
        cell_assignment = [random.choice(cells) for _ in range(len(machines))]

        # 2nd Segment: Machine selection (Assign operations to machines)
        machine_assignment = {job: [random.choice(machines) for _ in operations[job]] for job in jobs}
        machine_assignment.update({family: [random.choice(machines) for _ in product_families[family]] for family in product_families})

        # 3rd Segment: Local sequencing (Order jobs within machines and families)
        local_sequence = {job: random.sample(operations[job], len(operations[job])) for job in jobs}
        local_sequence.update({family: random.sample(product_families[family], len(product_families[family])) for family in product_families})

        # 4th Segment: Global scheduling (Overall schedule of jobs and families)
        global_schedule = random.sample(jobs + list(product_families.keys()), len(jobs) + len(product_families))  # Random order of jobs and families

        population.append([cell_assignment, machine_assignment, local_sequence, global_schedule])
    return population

# Crossover operation
def crossover(parent1, parent2):
    point = random.randint(1, len(parent1[0]) - 1)

    # Cross cells, machine assignments, local sequencing, and global scheduling
    child1 = [
        parent1[0][:point] + parent2[0][point:],
        parent1[1],
        parent1[2],
        parent1[3][:point] + parent2[3][point:]
    ]
    child2 = [
        parent2[0][:point] + parent1[0][point:],
        parent2[1],
        parent2[2],
        parent2[3][:point] + parent1[3][point:]
    ]
    return child1, child2

# Mutation operation
def mutation(individual):
    individual = list(individual)

    # Mutate each segment randomly
    if random.random() < mutation_rate:
        individual[0] = [random.choice(cells) for _ in individual[0]]  # Mutate cell formation

    if random.random() < mutation_rate:
        individual[1] = {job: [random.choice(machines) for _ in operations[job]] for job in jobs}  # Mutate machine selection
        individual[1].update({family: [random.choice(machines) for _ in product_families[family]] for family in product_families})

    if random.random() < mutation_rate:
        individual[2] = {job: random.sample(operations[job], len(operations[job])) for job in jobs}  # Mutate local sequencing
        individual[2].update({family: random.sample(product_families[family], len(product_families[family])) for family in product_families})

    if random.random() < mutation_rate:
        individual[3] = random.sample(jobs + list(product_families.keys()), len(jobs) + len(product_families))  # Mutate global scheduling

    return individual

# Select individuals based on fitness
def select_individual(population, fitness_values):
    tournament_size = 3
    selected = random.sample(list(zip(population, fitness_values)), tournament_size)
    selected.sort(key=lambda x: x[1], reverse=True)
    return selected[0][0]

# Q-Learning action selection (ε-greedy)
def choose_action(state, epsilon):
    if random.random() < epsilon:
        return random.choice(actions)
    else:
        return actions[np.argmax(Q_table[state])]

# Update Q-table
def update_Q_table(state, action_idx, reward, next_state):
    best_next_action = np.argmax(Q_table[next_state])
    Q_table[state, action_idx] = Q_table[state, action_idx] + alpha * (
        reward + gamma * Q_table[next_state, best_next_action] - Q_table[state, action_idx])
    print(f"Q-value updated for state {state}, action {action_idx}: {Q_table[state, action_idx]}")

# Main genetic algorithm with Q-learning loop
def genetic_algorithm():
    population = initialize_population(population_size, gene_length=10)

    for generation in range(generations):
        fitness_values = [fitness_function(individual) for individual in population]

        new_population = []
        for i in range(population_size // 2):
            parent1 = select_individual(population, fitness_values)
            parent2 = select_individual(population, fitness_values)

            action = choose_action(i, epsilon)
            if action == 'crossover':
                child1, child2 = crossover(parent1, parent2)
            else:  # Apply mutation
                child1, child2 = mutation(parent1), mutation(parent2)

            new_population.extend([child1, child2])

        # Evaluate new population fitness
        new_fitness_values = [fitness_function(individual) for individual in new_population]

        # Update Q-table based on the new population's fitness (reward is fitness gain)
        for i in range(population_size):
            reward = new_fitness_values[i] - fitness_values[i]
            print(f"Fitness difference (reward) for individual {i}: {reward}")  # Check reward value
            if reward != 0:
                update_Q_table(i, actions.index(action), reward, (i + 1) % population_size)
                print(f"Updated Q-table after applying reward: {Q_table}")  # Check Q-table update

        # Update population for next generation
        population = new_population

    print("Q-table after training:")
    print(Q_table)

# Running the Genetic Algorithm
genetic_algorithm()
# Out:
# Streaming output truncated to the last 5000 lines.
#  [0.78531746 1.2707827 ]
#  [1.35996238 0.64438016]
#  [0.88130166 0.50449038]
#  [0.34921273 0.39071095]
#  [0.69733767 0.82465977]
#  [1.15445001 0.79089204]
#  [0.98118291 1.31997075]]
# Fitness difference (reward) for individual 14: -0.1959636442831858
# Q-value updated for state 14, action 1: 0.6207940037719191
# Updated Q-table after applying reward: [[0.98807398 0.8111562 ]
#  [0.89013428 0.44439459]
#  [0.40001472 0.24359102]
#  [0.8328759  0.575921  ]
#  [1.0470219  0.66770249]
#  [0.63572156 0.89537196]
#  [1.19513628 1.1743288 ]
#  [1.55177956 0.56517208]
#  [0.76212841 0.92426787]
#  [0.59179922 0.41535285]
#  [0.80138857 0.60964514]
#  [0.99898273 0.96323139]
#  [1.22303111 0.95645054]
#  [0.78531746 1.2707827 ]
#  [1.35996238 0.620794  ]
#  [0.88130166 0.50449038]
#  [0.34921273 0.39071095]
#  [0.69733767 0.82465977]
#  [1.15445001 0.79089204]
#  [0.98118291 1.31997075]]
# Fitness difference (reward) for individual 15: 0.18753973604827756
# Q-value updated for state 15, action 1: 0.5218349862388975
# Updated Q-table after applying reward: [[0.98807398 0.8111562 ]
#  [0.89013428 0.44439459]
#  [0.40001472 0.24359102]
#  [0.8328759  0.575921  ]
#  [1.0470219  0.66770249]
#  [0.63572156 0.89537196]
#  [1.19513628 1.1743288 ]
#  [1.55177956 0.56517208]
#  [0.76212841 0.92426787]
#  [0.59179922 0.41535285]
#  [0.80138857 0.60964514]
#  [0.99898273 0.96323139]
#  [1.22303111 0.95645054]
#  [0.78531746 1.2707827 ]
#  [1.35996238 0.620794  ]
#  [0.88130166 0.52183499]
#  [0.34921273 0.39071095]
#  [0.69733767 0.82465977]
#  [1.15445001 0.79089204]
#  [0.98118291 1.31997075]]
# Fitness difference (reward) for individual 16: -0.34931458253380754
# Q-value updated for state 16, action 1: 0.39179507914746425
# Updated Q-table after applying reward: [[0.98807398 0.8111562 ]
#  [0.89013428 0.44439459]
#  [0.40001472 0.24359102]
#  [0.8328759  0.575921  ]
#  [1.0470219  0.66770249]
#  [0.63572156 0.89537196]
#  [1.19513628 1.1743288 ]
#  [1.55177956 0.56517208]
#  [0.76212841 0.92426787]
#  [0.59179922 0.41535285]
#  [0.80138857 0.60964514]
#  [0.99898273 0.96323139]
#  [1.22303111 0.95645054]
#  [0.78531746 1.2707827 ]
#  [1.35996238 0.620794  ]
#  [0.88130166 0.52183499]
#  [0.34921273 0.39179508]
#  [0.69733767 0.82465977]
#  [1.15445001 0.79089204]
#  [0.98118291 1.31997075]]
# Fitness difference (reward) for individual 17: 0.04556150931692038
# Q-value updated for state 17, action 1: 0.9546131421104862
# Updated Q-table after applying reward: [[0.98807398 0.8111562 ]
#  [0.89013428 0.44439459]
#  [0.40001472 0.24359102]
#  [0.8328759  0.575921  ]
#  [1.0470219  0.66770249]
#  [0.63572156 0.89537196]
#  [1.19513628 1.1743288 ]
#  [1.55177956 0.56517208]
#  [0.76212841 0.92426787]
#  [0.59179922 0.41535285]
#  [0.80138857 0.60964514]
#  [0.99898273 0.96323139]
#  [1.22303111 0.95645054]
#  [0.78531746 1.2707827 ]
#  [1.35996238 0.620794  ]
#  [0.88130166 0.52183499]
#  [0.34921273 0.39179508]
#  [0.69733767 0.95461314]
#  [1.15445001 0.79089204]
#  [0.98118291 1.31997075]]
# Fitness difference (reward) for individual 18: -0.8624375633907349
# Q-value updated for state 18, action 1: 0.5582140776998233
# Updated Q-table after applying reward: [[0.98807398 0.8111562 ]
#  [0.89013428 0.44439459]
#  [0.40001472 0.24359102]
#  [0.8328759  0.575921  ]
#  [1.0470219  0.66770249]
#  [0.63572156 0.89537196]
#  [1.19513628 1.1743288 ]
#  [1.55177956 0.56517208]
#  [0.76212841 0.92426787]
#  [0.59179922 0.41535285]
#  [0.80138857 0.60964514]
#  [0.99898273 0.96323139]
#  [1.22303111 0.95645054]
#  [0.78531746 1.2707827 ]
#  [1.35996238 0.620794  ]
#  [0.88130166 0.52183499]
#  [0.34921273 0.39179508]
#  [0.69733767 0.95461314]
#  [1.15445001 0.55821408]
#  [0.98118291 1.31997075]]
# Fitness difference (reward) for individual 19: 0.7001636008808418
# Q-value updated for state 19, action 1: 1.4547004683401958
# Updated Q-table after applying reward: [[0.98807398 0.8111562 ]
#  [0.89013428 0.44439459]
#  [0.40001472 0.24359102]
#  [0.8328759  0.575921  ]
#  [1.0470219  0.66770249]
#  [0.63572156 0.89537196]
#  [1.19513628 1.1743288 ]
#  [1.55177956 0.56517208]
#  [0.76212841 0.92426787]
#  [0.59179922 0.41535285]
#  [0.80138857 0.60964514]
#  [0.99898273 0.96323139]
#  [1.22303111 0.95645054]
#  [0.78531746 1.2707827 ]
#  [1.35996238 0.620794  ]
#  [0.88130166 0.52183499]
#  [0.34921273 0.39179508]
#  [0.69733767 0.95461314]
#  [1.15445001 0.55821408]
#  [0.98118291 1.45470047]]
# Fitness difference (reward) for individual
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.37606568 0.95645054]
#  [0.76791707 1.2707827 ]
#  [1.26319792 0.620794  ]
#  [0.56280271 0.52183499]
#  [0.63546163 0.39179508]
#  [1.07755613 0.95461314]
#  [1.31051431 0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 12: 0.2707407380684188
# Q-value updated for state 12, action 0: 1.395255424229835
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.76791707 1.2707827 ]
#  [1.26319792 0.620794  ]
#  [0.56280271 0.52183499]
#  [0.63546163 0.39179508]
#  [1.07755613 0.95461314]
#  [1.31051431 0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 13: -0.12951544070038779
# Q-value updated for state 13, action 0: 0.8876398807071133
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [1.26319792 0.620794  ]
#  [0.56280271 0.52183499]
#  [0.63546163 0.39179508]
#  [1.07755613 0.95461314]
#  [1.31051431 0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 14: -0.16480709837092355
# Q-value updated for state 14, action 0: 0.8024566317183095
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.56280271 0.52183499]
#  [0.63546163 0.39179508]
#  [1.07755613 0.95461314]
#  [1.31051431 0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 15: -0.4126193132197926
# Q-value updated for state 15, action 0: 0.36104943167251363
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.63546163 0.39179508]
#  [1.07755613 0.95461314]
#  [1.31051431 0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 16: 0.037597878883858016
# Q-value updated for state 16, action 0: 0.821430013214039
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.07755613 0.95461314]
#  [1.31051431 0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 17: 0.5478423114209736
# Q-value updated for state 17, action 0: 1.4024306608919506
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.31051431 0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 18: 0.31471507770531026
# Q-value updated for state 18, action 0: 1.4672299038757908
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.05002895 1.45470047]]
# Fitness difference (reward) for individual 19: 0.4566984587426184
# Q-value updated for state 19, action 0: 1.154152342206463
# Updated Q-table after applying reward: [[0.89064142 0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 0: 0.4183752046746054
# Q-value updated for state 0, action 0: 0.9056995964286141
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.55820285 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 1: 0.02848816047395175
# Q-value updated for state 1, action 0: 0.48593992144624854
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.42798759 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 2: -0.5261330435602325
# Q-value updated for state 2, action 0: 0.4130398919237661
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [1.02691693 0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 3: -0.27939983730292717
# Q-value updated for state 3, action 0: 0.8764050977334511
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [1.11699234 0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 4: -0.5836809044113931
# Q-value updated for state 4, action 0: 0.6695730969015805
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [0.87926771 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 5: 0.20793332363440342
# Q-value updated for state 5, action 0: 1.072048476573706
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [0.97155037 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 6: 0.7095994464225264
# Q-value updated for state 6, action 0: 1.260390471621922
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.93292347 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 7: -0.19959708598760173
# Q-value updated for state 7, action 0: 0.7825837348175435
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.64048102 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 8: 0.4718387025493964
# Q-value updated for state 8, action 0: 0.9218772449191097
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.81270529 0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 9: -0.15829599857482712
# Q-value updated for state 9, action 0: 0.6772378973557905
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.77785167 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 10: 0.13022838897451017
# Q-value updated for state 10, action 0: 0.8874941546980408
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [0.7739818  0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 11: 0.7249471474638618
# Q-value updated for state 11, action 0: 1.3773294161368073
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.39525542 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 12: -0.10471071524768938
# Q-value updated for state 12, action 0: 1.2171245677392069
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [0.88763988 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 13: 0.5783915071433441
# Q-value updated for state 13, action 0: 1.0941211781984679
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.80245663 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 14: 0.3953477261073566
# Q-value updated for state 14, action 0: 0.8337279227203369
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.36104943 0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 15: 0.37052655446627547
# Q-value updated for state 15, action 0: 0.735431499015712
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [0.82143001 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 16: 0.09563302764876092
# Q-value updated for state 16, action 0: 1.0896253178327777
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.40243066 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 17: 0.15708719363794188
# Q-value updated for state 17, action 0: 1.440012384009052
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.4672299  0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 18: -0.13022642287617003
# Q-value updated for state 18, action 0: 1.3231169512528984
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.32311695 0.55821408]
#  [1.15415234 1.45470047]]
# Fitness difference (reward) for individual 19: -0.17385544118811502
# Q-value updated for state 19, action 0: 0.8977132689020504
# Updated Q-table after applying reward: [[0.9056996  0.8111562 ]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.32311695 0.55821408]
#  [0.89771327 1.45470047]]
# Fitness difference (reward) for individual 0: 0.0802780402422254
# Q-value updated for state 0, action 1: 0.6643900833127635
# Updated Q-table after applying reward: [[0.9056996  0.66439008]
#  [0.48593992 0.44439459]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.32311695 0.55821408]
#  [0.89771327 1.45470047]]
# Fitness difference (reward) for individual 1: 0.19284452826820697
# Q-value updated for state 1, action 1: 0.5044875114601447
# Updated Q-table after applying reward: [[0.9056996  0.66439008]
#  [0.48593992 0.50448751]
#  [0.41303989 0.24359102]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.32311695 0.55821408]
#  [0.89771327 1.45470047]]
# Fitness difference (reward) for individual 2: 0.6763563615946531
# Q-value updated for state 2, action 1: 0.8543559865928287
# Updated Q-table after applying reward: [[0.9056996  0.66439008]
#  [0.48593992 0.50448751]
#  [0.41303989 0.85435599]
#  [0.8764051  0.575921  ]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.32311695 0.55821408]
#  [0.89771327 1.45470047]]
# Fitness difference (reward) for individual 3: -0.49268246804979476
# Q-value updated for state 3, action 1: 0.3429271591742598
# Updated Q-table after applying reward: [[0.9056996  0.66439008]
#  [0.48593992 0.50448751]
#  [0.41303989 0.85435599]
#  [0.8764051  0.34292716]
#  [0.6695731  0.66770249]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.32311695 0.55821408]
#  [0.89771327 1.45470047]]
# Fitness difference (reward) for individual 4: -0.08269247859285223
# Q-value updated for state 4, action 1: 0.7749268197723422
# Updated Q-table after applying reward: [[0.9056996  0.66439008]
#  [0.48593992 0.50448751]
#  [0.41303989 0.85435599]
#  [0.8764051  0.34292716]
#  [0.6695731  0.77492682]
#  [1.07204848 0.89537196]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
#  [0.7354315  0.52183499]
#  [1.08962532 0.39179508]
#  [1.44001238 0.95461314]
#  [1.32311695 0.55821408]
#  [0.89771327 1.45470047]]
# Fitness difference (reward) for individual 5: -0.23268792077643852
# Q-value updated for state 5, action 1: 0.8985177302109433
# Updated Q-table after applying reward: [[0.9056996  0.66439008]
#  [0.48593992 0.50448751]
#  [0.41303989 0.85435599]
#  [0.8764051  0.34292716]
#  [0.6695731  0.77492682]
#  [1.07204848 0.89851773]
#  [1.26039047 1.1743288 ]
#  [0.78258373 0.56517208]
#  [0.92187724 0.92426787]
#  [0.6772379  0.41535285]
#  [0.88749415 0.60964514]
#  [1.37732942 0.96323139]
#  [1.21712457 0.95645054]
#  [1.09412118 1.2707827 ]
#  [0.83372792 0.620794  ]
# ...
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [1.19726644 1.0673299 ]
#  [0.75804819 1.06040794]
#  [0.60943929 1.04745136]]
# Fitness difference (reward) for individual 17: -0.6282331323039045
# Q-value updated for state 17, action 0: 0.7617002291765087
# Updated Q-table after applying reward: [[1.00921145 0.66439008]
#  [0.62030723 0.50448751]
#  [0.91416318 0.85435599]
#  [0.8855855  0.34292716]
#  [1.31787659 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.75804819 1.06040794]
#  [0.60943929 1.04745136]]
# Fitness difference (reward) for individual 18: -0.35221735965001777
# Q-value updated for state 18, action 0: 0.6742685299397012
# Updated Q-table after applying reward: [[1.00921145 0.66439008]
#  [0.62030723 0.50448751]
#  [0.91416318 0.85435599]
#  [0.8855855  0.34292716]
#  [1.31787659 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.60943929 1.04745136]]
# Fitness difference (reward) for individual 19: -0.1037798349320056
# Q-value updated for state 19, action 0: 0.7069748811742693
# Updated Q-table after applying reward: [[1.00921145 0.66439008]
#  [0.62030723 0.50448751]
#  [0.91416318 0.85435599]
#  [0.8855855  0.34292716]
#  [1.31787659 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 0: 0.17932730683443943
# Q-value updated for state 0, action 0: 0.8734076332396039
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.62030723 0.50448751]
#  [0.91416318 0.85435599]
#  [0.8855855  0.34292716]
#  [1.31787659 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 1: -0.4061813828371257
# Q-value updated for state 1, action 0: 0.5184363536883111
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [0.91416318 0.85435599]
#  [0.8855855  0.34292716]
#  [1.31787659 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 2: 0.4723671232432203
# Q-value updated for state 2, action 0: 1.0917786252226127
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [0.8855855  0.34292716]
#  [1.31787659 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 3: 0.10773821906183656
# Q-value updated for state 3, action 0: 1.0897063272490155
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.31787659 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 4: -0.32023674913847877
# Q-value updated for state 4, action 0: 1.0213044800995357
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [1.1610768  0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 5: -0.3534948618996854
# Q-value updated for state 5, action 0: 0.9511376545320634
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.06978042 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 6: 0.495331560692275
# Q-value updated for state 6, action 0: 1.1109607291051626
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.66678521 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 7: 0.4564109207809981
# Q-value updated for state 7, action 0: 0.9328050248562983
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.66747778 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 8: 0.2766896370734049
# Q-value updated for state 8, action 0: 0.803541025181755
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.73657182 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 9: 0.2947713327617283
# Q-value updated for state 9, action 0: 0.874744951176973
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.7096184  0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 10: -0.0525862993992785
# Q-value updated for state 10, action 0: 0.9723062914019713
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.43064498 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 11: -0.23171174365467806
# Q-value updated for state 11, action 0: 1.1581544197943376
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [0.66580486 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 12: 0.23832725251253883
# Q-value updated for state 12, action 0: 1.0870343638145608
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.41104068 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 13: -0.014792427276747233
# Q-value updated for state 13, action 0: 1.1986735522326066
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.11233206 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 14: 0.43260604931105107
# Q-value updated for state 14, action 0: 1.3954968909831535
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.39549689 0.60318079]
#  [1.38450631 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 15: -0.5586614204429114
# Q-value updated for state 15, action 0: 1.0713806362513671
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.39549689 0.60318079]
#  [1.07138064 0.78589963]
#  [1.46324043 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 16: 0.11562924047420431
# Q-value updated for state 16, action 0: 1.2697332881811705
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.39549689 0.60318079]
#  [1.07138064 0.78589963]
#  [1.26973329 0.66201927]
#  [0.76170023 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 17: -0.1365507620532007
# Q-value updated for state 17, action 0: 0.7897583076700474
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.39549689 0.60318079]
#  [1.07138064 0.78589963]
#  [1.26973329 0.66201927]
#  [0.78975831 1.0673299 ]
#  [0.67426853 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 18: -0.19606349252774535
# Q-value updated for state 18, action 0: 0.7104556320645794
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.39549689 0.60318079]
#  [1.07138064 0.78589963]
#  [1.26973329 0.66201927]
#  [0.78975831 1.0673299 ]
#  [0.71045563 1.06040794]
#  [0.70697488 1.04745136]]
# Fitness difference (reward) for individual 19: -0.14911697915968603
# Q-value updated for state 19, action 0: 0.6719623859651134
# Updated Q-table after applying reward: [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.39549689 0.60318079]
#  [1.07138064 0.78589963]
#  [1.26973329 0.66201927]
#  [0.78975831 1.0673299 ]
#  [0.71045563 1.06040794]
#  [0.67196239 1.04745136]]
# Q-table after training:
# [[0.87340763 0.66439008]
#  [0.51843635 0.50448751]
#  [1.09177863 0.85435599]
#  [1.08970633 0.34292716]
#  [1.02130448 0.77492682]
#  [0.95113765 0.89851773]
#  [1.11096073 1.21632597]
#  [0.93280502 0.72978831]
#  [0.80354103 0.82490435]
#  [0.87474495 0.66026034]
#  [0.97230629 0.79794083]
#  [1.15815442 0.83754675]
#  [1.08703436 1.24152845]
#  [1.19867355 0.83326082]
#  [1.39549689 0.60318079]
#  [1.07138064 0.78589963]
#  [1.26973329 0.66201927]
#  [0.78975831 1.0673299 ]
#  [0.71045563 1.06040794]
#  [0.67196239 1.04745136]]

# %% [markdown]
# # Flexible Job Shop Scheduling Problem (FJSP) Using a Genetic Algorithm (GA) Approach
#
# In this notebook, we will implement the **Flexible Job Shop Scheduling Problem (FJSP)** using a **Genetic Algorithm (GA)** approach. This method will involve several key steps to define the problem instance, encoding the solutions, evaluating their fitness, and applying genetic operations like crossover and mutation.
#
# ## Problem Overview
#
# In the **Flexible Job Shop Scheduling Problem (FJSP)**, we have multiple jobs, each consisting of a set of tasks. Each task can be processed on one or more available machines, but each machine can only process one task at a time. The objective is to schedule the tasks in such a way that the makespan (the total completion time) is minimized.
#
# ---
#
# ### Step 1: Define the Problem Instance
#
# The problem instance will be represented as:
#
# 1. **Jobs**: A list of jobs, where each job consists of multiple tasks.
# 2. **Machines**: A set of machines, and each machine can process certain tasks. Machines are characterized by their processing times for each task.
#
# #### Problem Representation
# - **Jobs**: List of jobs, where each job contains a sequence of tasks.
# - **Machines**: A list of machines, where each machine can process specific tasks with different processing times.
#
# Let's represent this using a Python-like structure:
#
# ```python
# # Number of jobs and machines
# num_jobs = 5
# num_machines = 3
#
# # Example structure for tasks: (task_id, list_of_possible_machines)
# tasks = [
#     [(0, [0, 1]), (1, [0, 2])],  # Job 0: Task 0 on machine 0 or 1, Task 1 on machine 0 or 2
#     [(0, [1, 2]), (1, [0, 2])],  # Job 1: Task 0 on ma

# %% [markdown]
# # Flexible Job Shop Scheduling Problem (FJSP) using a Genetic Algorithm (GA) Approach
#
# The steps will involve the following:
#
# ## 1. Instance Storage Format
# - Representing the problem (jobs, machines, and tasks).
#
# ## Encoding Scheme
# - How we will encode a solution for the FJSP problem.
#
# ## Decoding/Encoding and Fitness Evaluation
# - How we will evaluate the fitness of a solution (i.e., schedule) and encode/decode solutions.
#
# ## Crossover and Mutation
# - Customizing these operations for the FJSP.

# %%
import random

# Example of problem data (jobs, machines, and task durations)
jobs = [
    {"tasks": [5, 4]},  # Job 1: Task 1 takes 5 units of time, Task 2 takes 4 units
    {"tasks": [3, 6]},  # Job 2: Task 1 takes 3 units of time, Task 2 takes 6 units
    {"tasks": [7, 2]},  # Job 3: Task 1 takes 7 units of time, Task 2 takes 2 units
]

machines = ["M1", "M2", "M3"]  # List of machines

# Function to encode a solution (chromosome)
def encode_solution(num_jobs, num_machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}  # Track machine availability

    for job_id in range(num_jobs):
        job_end_time = 0  # Track when the current job can start

        for task_id in range(len(jobs[job_id]["tasks"])):
            # Randomly assign a machine for the task
            machine_id = random.choice(machines)

            # Find the earliest time this task can start based on the machine's availability and job dependencies
            start_time = max(machine_end_times[machine_id], job_end_time)

            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration  # When does this task finish?

            # Update machine's next available time
            machine_end_times[machine_id] = end_time

            # Update job end time to reflect the completion of this task
            job_end_time = max(job_end_time, end_time)

            # Add to the chromosome
            chromosome.append((job_id, task_id, machine_id, start_time))

    return chromosome


# Fitness function: Minimize makespan, tardiness, and machine penalty
def calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates=None):
    machine_end_times = {machine: 0 for machine in machines}  # Track machine end times
    job_end_times = [0] * num_jobs  # Track job completion times

    total_tardiness = 0  # Initialize tardiness counter

    for job_id, task_id, machine_id, start_time in chromosome:
        task_duration = jobs[job_id]["tasks"][task_id]
        end_time = start_time + task_duration  # When does this task finish?

        # Update job end time (the time when the job is done)
        job_end_times[job_id] = max(job_end_times[job_id], end_time)

        # Update machine's available time
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)

    # Calculate makespan: time when last job is completed
    makespan = max(job_end_times)

    # Penalize tardiness (if there are due dates for the jobs)
    if job_due_dates:
        for job_id in range(num_jobs):
            tardiness = max(0, job_end_times[job_id] - job_due_dates[job_id])
            total_tardiness += tardiness

    # Penalize for underutilized machines (based on idle time)
    machine_penalty = sum(max(0, machine_end_times[machine_id] - makespan) for machine_id in machines)

    # Combine makespan, tardiness, and machine penalties
    fitness_score = makespan + total_tardiness + machine_penalty
    return fitness_score

# Crossover: Perform one-point crossover
def crossover(parent1, parent2):
    # Perform one-point crossover (cut at a random point)
    crossover_point = random.randint(1, len(parent1) - 1)

    # Create child chromosomes by swapping part of the parents
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]

    return child1, child2

# Mutation: Randomly reassign tasks to different machines
def mutate(chromosome, max_retries=10):
    """ Mutates the chromosome and ensures no overlapping tasks on the same machine. """

    for _ in range(max_retries):
        # Select two random tasks from different jobs
        idx1, idx2 = random.sample(range(len(chromosome)), 2)

        # Extract the tasks
        job1, task1, machine1, start_time1 = chromosome[idx1]
        job2, task2, machine2, start_time2 = chromosome[idx2]

        # Swap machines between two tasks
        new_machine1 = random.choice(machines)
        new_machine2 = random.choice(machines)

        # Update the chromosome with new machine assignments
        chromosome[idx1] = (job1, task1, new_machine1, start_time1)
        chromosome[idx2] = (job2, task2, new_machine2, start_time2)

        # Check if the updated schedule is valid
        if is_valid_schedule(chromosome):
            return chromosome  # Return valid mutation

    # If mutation fails after max_retries, apply a more flexible strategy
    print("Mutation failed after maximum retries, attempting flexible mutation.")
    return flexible_mutation(chromosome)

def flexible_mutation(chromosome):
    """ Attempt to adjust the schedule to make a valid mutation when the original one fails. """

    # Try to swap machines or adjust start times for the tasks
    machine_end_times = {machine: 0 for machine in machines}

    # Iterate through the chromosome and adjust tasks one by one
    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        task_duration = jobs[job_id]["tasks"][task_id]

        # Try to adjust the start time if necessary (avoid overlaps)
        if machine_end_times[machine_id] > start_time:
            # Adjust the start time to avoid overlap
            new_start_time = machine_end_times[machine_id]
            chromosome[i] = (job_id, task_id, machine_id, new_start_time)

        # Update machine's availability
        machine_end_times[machine_id] = max(machine_end_times[machine_id], start_time + task_duration)

    # Return the adjusted chromosome
    return chromosome


# Tournament selection: Select parents for crossover
def select_parents(population, fitness, tournament_size=5):
    parents = []
    population_size = len(population)

    # Ensure tournament size is not greater than population size
    tournament_size = min(tournament_size, population_size)

    for _ in range(len(population) // 2):
        # Randomly select tournament_size individuals
        tournament = random.sample(list(zip(population, fitness)), tournament_size)
        # Choose the best individual from the tournament
        winner = min(tournament, key=lambda x: x[1])
        parents.append(winner[0])

    return parents


# Main genetic algorithm function
def genetic_algorithm(num_jobs, num_machines, population_size=50, generations=100, job_due_dates=None):
    # Initialize population with random solutions
    population = [encode_solution(num_jobs, num_machines) for _ in range(population_size)]

    for generation in range(generations):
        # Evaluate fitness for the entire population
        fitness = [calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates) for chromosome in population]

        # Selection (Tournament Selection)
        selected_parents = select_parents(population, fitness)

        # Crossover to generate offspring
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):  # Ensure we always have pairs
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            child1, child2 = crossover(parent1, parent2)
            offspring.extend([child1, child2])

        # If the number of parents is odd, randomly select one parent for direct copying to the next generation
        if len(selected_parents) % 2 != 0:
            offspring.append(selected_parents[-1])  # Directly add the last parent to the offspring

        # Mutation
        mutated_offspring = [mutate(child) for child in offspring]

        # Make sure the population is not empty
        if not mutated_offspring:
            print(f"Error: Population is empty after mutation in generation {generation + 1}")
            break

        # Update population
        population = mutated_offspring

        # Store best solution (minimizing fitness score)
        best_solution = min(population, key=lambda x: calculate_fitness(x, num_jobs, num_machines, job_due_dates))
        print(f"Generation {generation + 1}, Best Makespan: {calculate_fitness(best_solution, num_jobs, num_machines, job_due_dates)}")

    return best_solution





# Example usage of the genetic algorithm

# Due dates for jobs (optional, can be None if not needed)
job_due_dates = [20, 18, 15]  # Jobs 1, 2, and 3 should be completed by these times.

# Run the genetic algorithm
best_solution = genetic_algorithm(num_jobs=3, num_machines=3, population_size=50, generations=100, job_due_dates=job_due_dates)

# Decode and print the best solution (chromosome)
timeline = decode_chromosome(best_solution)
print("Best Schedule (Timeline):")
for job_id, tasks in timeline.items():
    print(f"Job {job_id + 1}:")
    for task_id, machine_id, start_time in tasks:
        print(f"  Task {task_id + 1} on {machine_id} starts at {start_time}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a083a9fe50df> in <cell line: 205>()
#     203
#     204 # Run the genetic algorithm
# --> 205 best_solution = genetic_algorithm(num_jobs=3, num_machines=3, population_size=50, generations=100, job_due_dates=job_due_dates)
#     206
#     207 # Decode and print the best solution (chromosome)
#
# <ipython-input-25-a083a9fe50df> in genetic_algorithm(num_jobs, num_machines, population_size, generations, job_due_dates)
#     177
#     178         # Mutation
# --> 179         mutated_offspring = [mutate(child) for child in offspring]
#     180
#     181         # Make sure the population is not empty
#
# <ipython-input-25-a083a9fe50df> in <listcomp>(.0)
#     177
#     178         # Mutation
# --> 179         mutated_offspring = [mutate(child) for child in offspring]
#     180
#     181         # Make sure the population is not empty
#
# <ipython-input-25-a083a9fe50df> in mutate(chromosome, max_retries)
#     105
#     106         # Check if the updated schedule is valid
# --> 107         if is_valid_schedule(chromosome):
#     108             return chromosome  # Return valid mutation
#     109
#
# NameError: name 'is_valid_schedule' is not defined

# %% [markdown]
# # Correct version from Professor "Handle my comments, in the attached file; they are marked with "XXX". This should avoid the population running empty.
#
# # Flexible Job Shop Scheduling Problem (FJSP) using a Genetic Algorithm (GA) Approach

# %%
import random

# Example problem data
jobs = [
    {"tasks": [5, 4]},  # Job 1: Task 1 takes 5 units, Task 2 takes 4 units
    {"tasks": [3, 6]},  # Job 2: Task 1 takes 3 units, Task 2 takes 6 units
    {"tasks": [7, 2]},  # Job 3: Task 1 takes 7 units, Task 2 takes 2 units
]

machines = ["M1", "M2", "M3"]  # List of machines

# Function to encode a solution
def encode_solution(num_jobs, num_machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}  # Track machine availability

    for job_id in range(num_jobs):
        job_end_time = 0  # Track job completion

        for task_id in range(len(jobs[job_id]["tasks"])):
            # Assign to the machine with the earliest availability
            compatible_machines = machines
            machine_id = min(compatible_machines, key=lambda m: machine_end_times[m])

            start_time = max(machine_end_times[machine_id], job_end_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration

            machine_end_times[machine_id] = end_time
            job_end_time = end_time

            chromosome.append((job_id, task_id, machine_id, start_time))

    return chromosome

# Fitness function
def calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates=None):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * num_jobs
    total_tardiness = 0

    for job_id, task_id, machine_id, start_time in chromosome:
        task_duration = jobs[job_id]["tasks"][task_id]
        end_time = start_time + task_duration
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)

    makespan = max(job_end_times)
    if job_due_dates:
        total_tardiness = sum(max(0, job_end_times[j] - job_due_dates[j]) for j in range(num_jobs))

    return makespan + total_tardiness

# Helper function to check schedule validity
def is_valid_schedule(chromosome):
    machine_end_times = {machine: 0 for machine in machines}
    for _, _, machine_id, start_time in chromosome:
        if start_time < machine_end_times[machine_id]:
            return False
        machine_end_times[machine_id] = start_time
    return True

# Decode chromosome into a readable schedule
def decode_chromosome(chromosome):
    timeline = {}
    for job_id, task_id, machine_id, start_time in chromosome:
        if job_id not in timeline:
            timeline[job_id] = []
        timeline[job_id].append((task_id, machine_id, start_time))
    return timeline

# Crossover function
def crossover(parent1, parent2):
    crossover_point = random.randint(1, len(parent1) - 1)
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return repair_solution(child1), repair_solution(child2)

# Repair function to ensure valid schedule
def repair_solution(chromosome):
    machine_end_times = {machine: 0 for machine in machines}
    repaired_chromosome = []
    for job_id, task_id, machine_id, start_time in chromosome:
        compatible_machines = machines
        machine_id = min(compatible_machines, key=lambda m: machine_end_times[m])
        start_time = machine_end_times[machine_id]
        task_duration = jobs[job_id]["tasks"][task_id]
        end_time = start_time + task_duration
        machine_end_times[machine_id] = end_time
        repaired_chromosome.append((job_id, task_id, machine_id, start_time))
    return repaired_chromosome

# Mutation function
def mutate(chromosome):
    idx = random.randint(0, len(chromosome) - 1)
    job_id, task_id, _, start_time = chromosome[idx]
    new_machine_id = random.choice(machines)
    chromosome[idx] = (job_id, task_id, new_machine_id, start_time)
    return repair_solution(chromosome)

# Genetic algorithm
def genetic_algorithm(num_jobs, num_machines, population_size=50, generations=100, job_due_dates=None):
    population = [encode_solution(num_jobs, num_machines) for _ in range(population_size)]

    for generation in range(generations):
        fitness = [calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates) for chromosome in population]
        selected_parents = random.choices(population, k=len(population))
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):
            child1, child2 = crossover(selected_parents[i], selected_parents[i + 1])
            offspring.extend([mutate(child1), mutate(child2)])
        population = offspring
        best_solution = min(population, key=lambda x: calculate_fitness(x, num_jobs, num_machines, job_due_dates))
        print(f"Generation {generation + 1}, Best Fitness: {calculate_fitness(best_solution, num_jobs, num_machines, job_due_dates)}")
    return best_solution

# Example usage
job_due_dates = [20, 18, 15]
best_solution = genetic_algorithm(num_jobs=3, num_machines=3, population_size=50, generations=100, job_due_dates=job_due_dates)
timeline = decode_chromosome(best_solution)
print("Best Schedule (Timeline):")
for job_id, tasks in timeline.items():
    print(f"Job {job_id + 1}: {tasks}")
# Out:
# Generation 1, Best Fitness: 11
# Generation 2, Best Fitness: 11
# Generation 3, Best Fitness: 11
# Generation 4, Best Fitness: 11
# Generation 5, Best Fitness: 11
# Generation 6, Best Fitness: 11
# Generation 7, Best Fitness: 11
# Generation 8, Best Fitness: 11
# Generation 9, Best Fitness: 11
# Generation 10, Best Fitness: 11
# Generation 11, Best Fitness: 11
# Generation 12, Best Fitness: 11
# Generation 13, Best Fitness: 11
# Generation 14, Best Fitness: 11
# Generation 15, Best Fitness: 11
# Generation 16, Best Fitness: 11
# Generation 17, Best Fitness: 11
# Generation 18, Best Fitness: 11
# Generation 19, Best Fitness: 11
# Generation 20, Best Fitness: 11
# Generation 21, Best Fitness: 11
# Generation 22, Best Fitness: 11
# Generation 23, Best Fitness: 11
# Generation 24, Best Fitness: 11
# Generation 25, Best Fitness: 11
# Generation 26, Best Fitness: 11
# Generation 27, Best Fitness: 11
# Generation 28, Best Fitness: 11
# Generation 29, Best Fitness: 11
# Generation 30, Best Fitness: 11
# Generation 31, Best Fitness: 11
# Generation 32, Best Fitness: 11
# Generation 33, Best Fitness: 11
# Generation 34, Best Fitness: 11
# Generation 35, Best Fitness: 11
# Generation 36, Best Fitness: 11
# Generation 37, Best Fitness: 11
# Generation 38, Best Fitness: 11
# Generation 39, Best Fitness: 11
# Generation 40, Best Fitness: 11
# Generation 41, Best Fitness: 11
# Generation 42, Best Fitness: 11
# Generation 43, Best Fitness: 11
# Generation 44, Best Fitness: 11
# Generation 45, Best Fitness: 11
# Generation 46, Best Fitness: 11
# Generation 47, Best Fitness: 11
# Generation 48, Best Fitness: 11
# Generation 49, Best Fitness: 11
# Generation 50, Best Fitness: 11
# Generation 51, Best Fitness: 11
# Generation 52, Best Fitness: 11
# Generation 53, Best Fitness: 11
# Generation 54, Best Fitness: 11
# Generation 55, Best Fitness: 11
# Generation 56, Best Fitness: 11
# Generation 57, Best Fitness: 11
# Generation 58, Best Fitness: 11
# Generation 59, Best Fitness: 11
# Generation 60, Best Fitness: 11
# Generation 61, Best Fitness: 11
# Generation 62, Best Fitness: 11
# Generation 63, Best Fitness: 11
# Generation 64, Best Fitness: 11
# Generation 65, Best Fitness: 11
# Generation 66, Best Fitness: 11
# Generation 67, Best Fitness: 11
# Generation 68, Best Fitness: 11
# Generation 69, Best Fitness: 11
# Generation 70, Best Fitness: 11
# Generation 71, Best Fitness: 11
# Generation 72, Best Fitness: 11
# Generation 73, Best Fitness: 11
# Generation 74, Best Fitness: 11
# Generation 75, Best Fitness: 11
# Generation 76, Best Fitness: 11
# Generation 77, Best Fitness: 11
# Generation 78, Best Fitness: 11
# Generation 79, Best Fitness: 11
# Generation 80, Best Fitness: 11
# Generation 81, Best Fitness: 11
# Generation 82, Best Fitness: 11
# Generation 83, Best Fitness: 11
# Generation 84, Best Fitness: 11
# Generation 85, Best Fitness: 11
# Generation 86, Best Fitness: 11
# Generation 87, Best Fitness: 11
# Generation 88, Best Fitness: 11
# Generation 89, Best Fitness: 11
# Generation 90, Best Fitness: 11
# Generation 91, Best Fitness: 11
# Generation 92, Best Fitness: 11
# Generation 93, Best Fitness: 11
# Generation 94, Best Fitness: 11
# Generation 95, Best Fitness: 11
# Generation 96, Best Fitness: 11
# Generation 97, Best Fitness: 11
# Generation 98, Best Fitness: 11
# Generation 99, Best Fitness: 11
# Generation 100, Best Fitness: 11
# Best Schedule (Timeline):
# Job 1: [(0, 'M1', 0), (1, 'M2', 0)]
# Job 2: [(0, 'M3', 0), (1, 'M3', 3)]
# Job 3: [(0, 'M2', 4), (1, 'M1', 5)]

# %% [markdown]
# # Extend FJSP code with the Q-learning used in the Cheng et al. Paper.

# %%
import random
import numpy as np

# Q-learning parameters
epsilon = 0.1  # Exploration rate
alpha = 0.1    # Learning rate
gamma = 0.9    # Discount factor
q_table = {}   # Q-table for storing state-action values

# Define actions: 0 = crossover, 1 = mutation
actions = [0, 1]

# Initialize Q-table
def initialize_q_table(states, actions):
    for state in states:
        q_table[state] = {action: 0 for action in actions}

# Define state representation
def get_state(population, fitness):
    # Example state: fitness improvement trend
    best_fitness = min(fitness)
    avg_fitness = sum(fitness) / len(fitness)
    return (round(best_fitness, 2), round(avg_fitness, 2))

# Select action using epsilon-greedy policy
def select_action(state):
    if random.random() < epsilon:  # Explore
        return random.choice(actions)
    # Exploit: Select the best action for the given state
    return max(q_table[state], key=q_table[state].get)

# Update Q-table
def update_q_table(state, action, reward, next_state):
    max_next_q = max(q_table[next_state].values())
    q_table[state][action] = q_table[state][action] + alpha * (reward + gamma * max_next_q - q_table[state][action])

# Reward function
def calculate_reward(previous_fitness, current_fitness):
    return previous_fitness - current_fitness  # Positive reward for fitness improvement

# Genetic algorithm with Q-learning
def genetic_algorithm_q_learning(num_jobs, num_machines, population_size=50, generations=100, job_due_dates=None):
    # Initialize population
    population = [encode_solution(num_jobs, num_machines) for _ in range(population_size)]
    fitness = [calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates) for chromosome in population]
    states = {get_state(population, fitness)}  # Initialize state set
    initialize_q_table(states, actions)

    for generation in range(generations):
        # Calculate current state
        state = get_state(population, fitness)

        # Select action using epsilon-greedy policy
        action = select_action(state)

        # Apply action: crossover or mutation
        if action == 0:  # Apply crossover
            offspring = []
            selected_parents = random.choices(population, k=len(population))
            for i in range(0, len(selected_parents) - 1, 2):
                child1, child2 = crossover(selected_parents[i], selected_parents[i + 1])
                offspring.extend([child1, child2])
            new_population = offspring
        elif action == 1:  # Apply mutation
            new_population = [mutate(individual) for individual in population]

        # Ensure population remains feasible
        new_population = [repair_solution(individual) for individual in new_population]

        # Evaluate new fitness
        new_fitness = [calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates) for chromosome in new_population]

        # Calculate reward
        reward = calculate_reward(min(fitness), min(new_fitness))

        # Update Q-table
        next_state = get_state(new_population, new_fitness)
        if next_state not in q_table:
            q_table[next_state] = {action: 0 for action in actions}
        update_q_table(state, action, reward, next_state)

        # Update population and fitness
        population = new_population
        fitness = new_fitness

        # Print progress
        best_solution = min(population, key=lambda x: calculate_fitness(x, num_jobs, num_machines, job_due_dates))
        print(f"Generation {generation + 1}, Best Fitness: {calculate_fitness(best_solution, num_jobs, num_machines, job_due_dates)}")

    return best_solution

# Example usage
job_due_dates = [20, 18, 15]
best_solution = genetic_algorithm_q_learning(num_jobs=3, num_machines=3, population_size=50, generations=100, job_due_dates=job_due_dates)
timeline = decode_chromosome(best_solution)
print("Best Schedule (Timeline):")
for job_id, tasks in timeline.items():
    print(f"Job {job_id + 1}: {tasks}")
# Out:
# Generation 1, Best Fitness: 11
# Generation 2, Best Fitness: 11
# Generation 3, Best Fitness: 11
# Generation 4, Best Fitness: 11
# Generation 5, Best Fitness: 11
# Generation 6, Best Fitness: 11
# Generation 7, Best Fitness: 11
# Generation 8, Best Fitness: 11
# Generation 9, Best Fitness: 11
# Generation 10, Best Fitness: 11
# Generation 11, Best Fitness: 11
# Generation 12, Best Fitness: 11
# Generation 13, Best Fitness: 11
# Generation 14, Best Fitness: 11
# Generation 15, Best Fitness: 11
# Generation 16, Best Fitness: 11
# Generation 17, Best Fitness: 11
# Generation 18, Best Fitness: 11
# Generation 19, Best Fitness: 11
# Generation 20, Best Fitness: 11
# Generation 21, Best Fitness: 11
# Generation 22, Best Fitness: 11
# Generation 23, Best Fitness: 11
# Generation 24, Best Fitness: 11
    {"tasks": [7, 2]},  # Job 3: Task 1 takes 7 units, Task 2 takes 2 units
]

machines = ["M1", "M2", "M3"]  # List of machines

# Transport times between machines (constant for simplicity)
transport_times = {
    ("M1", "M2"): 2,
    ("M1", "M3"): 3,
    ("M2", "M1"): 2,
    ("M2", "M3"): 1,
    ("M3", "M1"): 3,
    ("M3", "M2"): 1,
    ("M1", "M1"): 0,
    ("M2", "M2"): 0,
    ("M3", "M3"): 0,
}

# Q-learning parameters
epsilon = 0.1  # Exploration rate
alpha = 0.1    # Learning rate
gamma = 0.9    # Discount factor
q_table = {}   # Q-table for storing state-action values

actions = [0, 1]  # 0 = crossover, 1 = mutation

# Initialize Q-table
def initialize_q_table(states, actions):
    for state in states:
        q_table[state] = {action: 0 for action in actions}

# Define state representation
def get_state(population, fitness):
    best_fitness = min(fitness)
    avg_fitness = sum(fitness) / len(fitness)
    return (round(best_fitness, 2), round(avg_fitness, 2))

# Select action using epsilon-greedy policy
def select_action(state):
    if random.random() < epsilon:
        return random.choice(actions)
    return max(q_table[state], key=q_table[state].get)

# Update Q-table
def update_q_table(state, action, reward, next_state):
    max_next_q = max(q_table[next_state].values())
    q_table[state][action] = q_table[state][action] + alpha * (reward + gamma * max_next_q - q_table[state][action])

# Reward function
def calculate_reward(previous_fitness, current_fitness):
    return max(0, previous_fitness - current_fitness)  # Positive reward for fitness improvement

# Encode solution
def encode_solution(num_jobs, num_machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    for job_id in range(num_jobs):
        job_end_time = 0
        previous_machine = None
        for task_id in range(len(jobs[job_id]["tasks"])):
            compatible_machines = machines
            machine_id = min(compatible_machines, key=lambda m: machine_end_times[m])
            transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
            start_time = max(machine_end_times[machine_id], job_end_time + transport_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration
            machine_end_times[machine_id] = end_time
            job_end_time = end_time
            previous_machine = machine_id
            chromosome.append((job_id, task_id, machine_id, start_time))
    return chromosome

# Fitness function
def calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates=None):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * num_jobs
    total_tardiness = 0
    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        task_duration = jobs[job_id]["tasks"][task_id]
        transport_time = 0
        if i > 0:
            _, _, prev_machine, _ = chromosome[i - 1]
            transport_time = transport_times.get((prev_machine, machine_id), 0)
        end_time = start_time + task_duration + transport_time
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)
    makespan = max(job_end_times)
    if job_due_dates:
        total_tardiness = sum(max(0, job_end_times[j] - job_due_dates[j]) for j in range(num_jobs))
    return makespan + total_tardiness

# Repair solution
def repair_solution(chromosome):
    machine_end_times = {machine: 0 for machine in machines}
    previous_machine = None
    repaired_chromosome = []
    for job_id, task_id, machine_id, start_time in chromosome:
        transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
        start_time = max(machine_end_times[machine_id], start_time + transport_time)
        task_duration = jobs[job_id]["tasks"][task_id]
        end_time = start_time + task_duration
        machine_end_times[machine_id] = end_time
        previous_machine = machine_id
        repaired_chromosome.append((job_id, task_id, machine_id, start_time))
    return repaired_chromosome

# Genetic algorithm
def genetic_algorithm(num_jobs, num_machines, population_size=50, generations=100, job_due_dates=None):
    population = [encode_solution(num_jobs, num_machines) for _ in range(population_size)]
    fitness = [calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates) for chromosome in population]
    states = {get_state(population, fitness)}
    initialize_q_table(states, actions)
    for generation in range(generations):
        state = get_state(population, fitness)
        action = select_action(state)
        if action == 0:
            offspring = []
            selected_parents = random.choices(population, k=len(population))
            for i in range(0, len(selected_parents) - 1, 2):
                child1, child2 = crossover(selected_parents[i], selected_parents[i + 1])
                offspring.extend([child1, child2])
            new_population = offspring
        elif action == 1:
            new_population = [mutate(individual) for individual in population]
        new_population = [repair_solution(individual) for individual in new_population]
        new_fitness = [calculate_fitness(chromosome, num_jobs, num_machines, job_due_dates) for chromosome in new_population]
        reward = calculate_reward(min(fitness), min(new_fitness))
        next_state = get_state(new_population, new_fitness)
        if next_state not in q_table:
            q_table[next_state] = {action: 0 for action in actions}
        update_q_table(state, action, reward, next_state)
        population = new_population
        fitness = new_fitness
        best_solution = min(population, key=lambda x: calculate_fitness(x, num_jobs, num_machines, job_due_dates))
        print(f"Generation {generation + 1}, Best Fitness: {calculate_fitness(best_solution, num_jobs, num_machines, job_due_dates)}")
    return best_solution

# Example usage
job_due_dates = [20, 18, 15]
best_solution = genetic_algorithm(num_jobs=3, num_machines=3, population_size=50, generations=100, job_due_dates=job_due_dates)
print("Best Schedule (Timeline):")
timeline = decode_chromosome(best_solution)
for job_id, tasks in timeline.items():
    print(f"Job {job_id + 1}: {tasks}")
# Out:
# Generation 1, Best Fitness: 37
# Generation 2, Best Fitness: 50
# Generation 3, Best Fitness: 66
# Generation 4, Best Fitness: 82
# Generation 5, Best Fitness: 99
# Generation 6, Best Fitness: 99
# Generation 7, Best Fitness: 105
# Generation 8, Best Fitness: 111
# Generation 9, Best Fitness: 143
# Generation 10, Best Fitness: 165
# Generation 11, Best Fitness: 181
# Generation 12, Best Fitness: 185
# Generation 13, Best Fitness: 209
# Generation 14, Best Fitness: 229
# Generation 15, Best Fitness: 237
# Generation 16, Best Fitness: 267
# Generation 17, Best Fitness: 258
# Generation 18, Best Fitness: 272
# Generation 19, Best Fitness: 296
# Generation 20, Best Fitness: 330
# Generation 21, Best Fitness: 348
# Generation 22, Best Fitness: 348
# Generation 23, Best Fitness: 367
# Generation 24, Best Fitness: 392
# Generation 25, Best Fitness: 416
# Generation 26, Best Fitness: 424
# Generation 27, Best Fitness: 424
# Generation 28, Best Fitness: 444
# Generation 29, Best Fitness: 446
# Generation 30, Best Fitness: 446
# Generation 31, Best Fitness: 461
# Generation 32, Best Fitness: 456
# Generation 33, Best Fitness: 444
# Generation 34, Best Fitness: 466
# Generation 35, Best Fitness: 430
# Generation 36, Best Fitness: 518
# Generation 37, Best Fitness: 550
# Generation 38, Best Fitness: 568
# Generation 39, Best Fitness: 545
# Generation 40, Best Fitness: 568
# Generation 41, Best Fitness: 592
# Generation 42, Best Fitness: 602
# Generation 43, Best Fitness: 596
# Generation 44, Best Fitness: 591
# Generation 45, Best Fitness: 694
# Generation 46, Best Fitness: 664
# Generation 47, Best Fitness: 674
# Generation 48, Best Fitness: 712
# Generation 49, Best Fitness: 750
# Generation 50, Best Fitness: 756
# Generation 51, Best Fitness: 756
# Generation 52, Best Fitness: 716
# Generation 53, Best Fitness: 718
# Generation 54, Best Fitness: 792
# Generation 55, Best Fitness: 794
# Generation 56, Best Fitness: 748
# Generation 57, Best Fitness: 830
# Generation 58, Best Fitness: 783
# Generation 59, Best Fitness: 786
# Generation 60, Best Fitness: 804
# Generation 61, Best Fitness: 912
# Generation 62, Best Fitness: 954
# Generation 63, Best Fitness: 968
# Generation 64, Best Fitness: 970
# Generation 65, Best Fitness: 972
# Generation 66, Best Fitness: 996
# Generation 67, Best Fitness: 1043
# Generation 68, Best Fitness: 1064
# Generation 69, Best Fitness: 999
# Generation 70, Best Fitness: 1069
# Generation 71, Best Fitness: 1080
# Generation 72, Best Fitness: 1134
# Generation 73, Best Fitness: 1144
# Generation 74, Best Fitness: 1141
# Generation 75, Best Fitness: 1117
# Generation 76, Best Fitness: 1181
# Generation 77, Best Fitness: 1180
# Generation 78, Best Fitness: 1163
# Generation 79, Best Fitness: 1169
# Generation 80, Best Fitness: 1219
# Generation 81, Best Fitness: 1221
# Generation 82, Best Fitness: 1287
# Generation 83, Best Fitness: 1325
# Generation 84, Best Fitness: 1317
# Generation 85, Best Fitness: 1357
# Generation 86, Best Fitness: 1381
# Generation 87, Best Fitness: 1382
# Generation 88, Best Fitness: 1413
# Generation 89, Best Fitness: 1418
# Generation 90, Best Fitness: 1442
# Generation 91, Best Fitness: 1450
# Generation 92, Best Fitness: 1464
# Generation 93, Best Fitness: 1548
# Generation 94, Best Fitness: 1523
# Generation 95, Best Fitness: 1572
# Generation 96, Best Fitness: 1586
# Generation 97, Best Fitness: 1690
# Generation 98, Best Fitness: 1626
# Generation 99, Best Fitness: 1682
# Generation 100, Best Fitness: 1646
# Best Schedule (Timeline):
# Job 1: [(0, 'M1', 0), (1, 'M2', 219)]
# Job 2: [(0, 'M3', 421), (1, 'M3', 436)]
# Job 3: [(0, 'M1', 415), (1, 'M3', 511)]

# %%
import random

# Example problem data
jobs = [
    {"tasks": [5, 4]},  # Job 1: Task 1 takes 5 units, Task 2 takes 4 units
    {"tasks": [3, 6]},  # Job 2: Task 1 takes 3 units, Task 2 takes 6 units
    {"tasks": [7, 2]},  # Job 3: Task 1 takes 7 units, Task 2 takes 2 units
]

machines = ["M1", "M2", "M3"]  # List of machines

# Transport times between machines (constant for simplicity)
transport_times = {
    ("M1", "M2"): 2,
    ("M1", "M3"): 3,
    ("M2", "M1"): 2,
    ("M2", "M3"): 1,
    ("M3", "M1"): 3,
    ("M3", "M2"): 1,
    ("M1", "M1"): 0,
    ("M2", "M2"): 0,
    ("M3", "M3"): 0,
}

# Encode solution
def encode_solution(num_jobs, num_machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    for job_id in range(num_jobs):
        job_end_time = 0
        previous_machine = None
        for task_id in range(len(jobs[job_id]["tasks"])):
            machine_id = min(machines, key=lambda m: machine_end_times[m])
            transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
            start_time = max(machine_end_times[machine_id], job_end_time + transport_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration
            machine_end_times[machine_id] = end_time
            job_end_time = end_time
            previous_machine = machine_id
            chromosome.append((job_id, task_id, machine_id, start_time))
    return chromosome

# Fitness function
def calculate_fitness(chromosome):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * len(jobs)
    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        task_duration = jobs[job_id]["tasks"][task_id]
        transport_time = 0
        if i > 0:
            _, _, prev_machine, _ = chromosome[i - 1]
            transport_time = transport_times.get((prev_machine, machine_id), 0)
        end_time = start_time + task_duration + transport_time
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)
    makespan = max(job_end_times)
    return makespan

# Repair solution
def repair_solution(chromosome):
    repaired_chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    previous_machine = None
    for job_id, task_id, machine_id, start_time in chromosome:
        transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
        start_time = max(machine_end_times[machine_id], start_time + transport_time)
        task_duration = jobs[job_id]["tasks"][task_id]
        end_time = start_time + task_duration
        machine_end_times[machine_id] = end_time
        previous_machine = machine_id
        repaired_chromosome.append((job_id, task_id, machine_id, start_time))
    return repaired_chromosome

# Genetic algorithm
def genetic_algorithm(num_jobs, num_machines, population_size=50, generations=100):
    population = [encode_solution(num_jobs, num_machines) for _ in range(population_size)]
    for generation in range(generations):
        fitness_values = [calculate_fitness(ind) for ind in population]
        best_fitness = min(fitness_values)
        best_solution = population[fitness_values.index(best_fitness)]
        print(f"Generation {generation + 1}, Best Fitness: {best_fitness}")

        # Selection: Tournament selection
        selected_parents = random.choices(population, k=len(population))

        # Crossover
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = parent1[:crossover_point] + parent2[crossover_point:]
            child2 = parent2[:crossover_point] + parent1[crossover_point:]
            offspring.extend([repair_solution(child1), repair_solution(child2)])

        # Mutation
        for i in range(len(offspring)):
            if random.random() < 0.1:  # Mutation probability
                idx = random.randint(0, len(offspring[i]) - 1)
                job_id, task_id, _, start_time = offspring[i][idx]
                new_machine = random.choice(machines)
                offspring[i][idx] = (job_id, task_id, new_machine, start_time)
                offspring[i] = repair_solution(offspring[i])

        # Update population
        population = offspring

    return best_solution

# Example usage
best_solution = genetic_algorithm(num_jobs=3, num_machines=3, population_size=50, generations=100)
print("Best Schedule (Timeline):")
for job_id, task_id, machine_id, start_time in best_solution:
    print(f"Job {job_id + 1}, Task {task_id + 1} on {machine_id} starts at {start_time}")
# Out:
# Generation 1, Best Fitness: 20
# Generation 2, Best Fitness: 23
# Generation 3, Best Fitness: 24
# Generation 4, Best Fitness: 28
# Generation 5, Best Fitness: 29
# Generation 6, Best Fitness: 30
# Generation 7, Best Fitness: 31
# Generation 8, Best Fitness: 33
# Generation 9, Best Fitness: 38
# Generation 10, Best Fitness: 39
# Generation 11, Best Fitness: 40
# Generation 12, Best Fitness: 41
# Generation 13, Best Fitness: 46
# Job 2, Task 1 on M2 starts at 218
# Job 2, Task 2 on M3 starts at 209
# Job 3, Task 1 on M1 starts at 256
# Job 3, Task 2 on M2 starts at 278

# %% [markdown]
# # Task 1: Implement a new repair_solution function
# - Create a list or array for each job containing the next task that can be scheduled (all predecessor tasks must already be scheduled).
# - Initialize the list with the first task of each job.
# - Iterate over the list and:
#     - Find the task with the longest processing time.
#     - Schedule this task on a suitable machine.
#     - Update the machine's end time accordingly.
# - Update the list:
# - Remove the task just scheduled.
# - Repeat until all tasks are scheduled.
# ---

# %%
def repair_solution(jobs, machines):
    # Initialize the list with the first task of each job
    tasks_to_schedule = [{"job_id": i, "task_id": 0, "processing_time": job["tasks"][0]}
                         for i, job in enumerate(jobs)]
    machine_end_times = {machine: 0 for machine in machines}  # Track machine availability
    schedule = []  # Final schedule

    while tasks_to_schedule:
        # Find the task with the longest processing time
        task_to_schedule = max(tasks_to_schedule, key=lambda x: x["processing_time"])
        tasks_to_schedule.remove(task_to_schedule)

        # Determine the job and task
        job_id = task_to_schedule["job_id"]
        task_id = task_to_schedule["task_id"]

        # Schedule this task on the first available machine
        machine = min(machines, key=lambda m: machine_end_times[m])
        start_time = machine_end_times[machine]  # Machine's current end time
        processing_time = task_to_schedule["processing_time"]
        end_time = start_time + processing_time

        # Update the machine's end time
        machine_end_times[machine] = end_time

        # Add the scheduled task to the final schedule
        schedule.append({"job_id": job_id, "task_id": task_id, "machine": machine, "start_time": start_time})

        # Add the next task of the same job to the list if available
        if task_id + 1 < len(jobs[job_id]["tasks"]):
            tasks_to_schedule.append({
                "job_id": job_id,
                "task_id": task_id + 1,
                "processing_time": jobs[job_id]["tasks"][task_id + 1]
            })

    return schedule

# %%
import random

# Example problem data
jobs = [
    {"tasks": [5, 4]},  # Job 1: Task 1 takes 5 units, Task 2 takes 4 units
    {"tasks": [3, 6]},  # Job 2: Task 1 takes 3 units, Task 2 takes 6 units
    {"tasks": [7, 2]},  # Job 3: Task 1 takes 7 units, Task 2 takes 2 units
]

machines = ["M1", "M2", "M3"]  # List of machines

# Transport times between machines (constant for simplicity)
transport_times = {
    ("M1", "M2"): 2,
    ("M1", "M3"): 3,
    ("M2", "M1"): 2,
    ("M2", "M3"): 1,
    ("M3", "M1"): 3,
    ("M3", "M2"): 1,
    ("M1", "M1"): 0,
    ("M2", "M2"): 0,
    ("M3", "M3"): 0,
}

# Encode solution
def encode_solution(num_jobs, num_machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    for job_id in range(num_jobs):
        job_end_time = 0
        previous_machine = None
        for task_id in range(len(jobs[job_id]["tasks"])):
            machine_id = min(machines, key=lambda m: machine_end_times[m])
            transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
            start_time = max(machine_end_times[machine_id], job_end_time + transport_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration
            machine_end_times[machine_id] = end_time
            job_end_time = end_time
            previous_machine = machine_id
            chromosome.append((job_id, task_id, machine_id, start_time))
    return chromosome

# Fitness function
def calculate_fitness(chromosome):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * len(jobs)
    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        job_id = int(job_id)  # Ensure job_id is an integer
        task_id = int(task_id)  # Ensure task_id is an integer
        task_duration = jobs[job_id]["tasks"][task_id]
        transport_time = 0
        if i > 0:
            _, _, prev_machine, _ = chromosome[i - 1]
            transport_time = transport_times.get((prev_machine, machine_id), 0)
        end_time = start_time + task_duration + transport_time
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)
    makespan = max(job_end_times)
    return makespan

# Repair solution
def repair_solution(jobs, machines):
    tasks_to_schedule = [{"job_id": i, "task_id": 0, "processing_time": job["tasks"][0]}
                         for i, job in enumerate(jobs)]
    machine_end_times = {machine: 0 for machine in machines}
    schedule = []

    while tasks_to_schedule:
        task_to_schedule = max(tasks_to_schedule, key=lambda x: x["processing_time"])
        tasks_to_schedule.remove(task_to_schedule)

        job_id = task_to_schedule["job_id"]
        task_id = task_to_schedule["task_id"]

        machine = min(machines, key=lambda m: machine_end_times[m])
        start_time = machine_end_times[machine]
        processing_time = task_to_schedule["processing_time"]
        end_time = start_time + processing_time

        machine_end_times[machine] = end_time
        schedule.append((job_id, task_id, machine, start_time))

        if task_id + 1 < len(jobs[job_id]["tasks"]):
            tasks_to_schedule.append({
                "job_id": job_id,
                "task_id": task_id + 1,
                "processing_time": jobs[job_id]["tasks"][task_id + 1]
            })

    return schedule

# Genetic algorithm
def genetic_algorithm(num_jobs, num_machines, population_size=50, generations=100):
    population = [encode_solution(num_jobs, num_machines) for _ in range(population_size)]
    for generation in range(generations):
        fitness_values = [calculate_fitness(ind) for ind in population]
        best_fitness = min(fitness_values)
        best_solution = population[fitness_values.index(best_fitness)]
        print(f"Generation {generation + 1}, Best Fitness: {best_fitness}")

        # Selection: Tournament selection
        selected_parents = random.choices(population, k=len(population))

        # Crossover
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = parent1[:crossover_point] + parent2[crossover_point:]
            child2 = parent2[:crossover_point] + parent1[crossover_point:]
            offspring.extend([repair_solution(jobs, machines), repair_solution(jobs, machines)])

        # Mutation
        for i in range(len(offspring)):
            if random.random() < 0.1:  # Mutation probability
                idx = random.randint(0, len(offspring[i]) - 1)
                job_id, task_id, _, start_time = offspring[i][idx]
                new_machine = random.choice(machines)
                offspring[i][idx] = (int(job_id), int(task_id), new_machine, start_time)
                offspring[i] = repair_solution(jobs, machines)

        # Update population
        population = offspring

    return best_solution

# Example usage
best_solution = genetic_algorithm(num_jobs=3, num_machines=3, population_size=50, generations=100)
print("Best Schedule (Timeline):")
for job_id, task_id, machine_id, start_time in best_solution:
    print(f"Job {job_id + 1}, Task {task_id + 1} on {machine_id} starts at {start_time}")
# Out:
# Generation 1, Best Fitness: 20
# Generation 2, Best Fitness: 12
# Generation 3, Best Fitness: 12
# Generation 4, Best Fitness: 12
# Generation 5, Best Fitness: 12
# Generation 6, Best Fitness: 12
# Generation 7, Best Fitness: 12
# Generation 8, Best Fitness: 12
# Generation 9, Best Fitness: 12
# Generation 10, Best Fitness: 12
# Generation 11, Best Fitness: 12
# Generation 12, Best Fitness: 12
# Generation 13, Best Fitness: 12
# Generation 14, Best Fitness: 12
# Generation 15, Best Fitness: 12
# Generation 16, Best Fitness: 12
# Generation 17, Best Fitness: 12
# Generation 18, Best Fitness: 12
# Generation 19, Best Fitness: 12
# Generation 20, Best Fitness: 12
# Generation 21, Best Fitness: 12
# Generation 22, Best Fitness: 12
# Generation 23, Best Fitness: 12
# Generation 24, Best Fitness: 12
# Generation 25, Best Fitness: 12
# Generation 26, Best Fitness: 12
# Generation 27, Best Fitness: 12
# Generation 28, Best Fitness: 12
# Generation 29, Best Fitness: 12
# Generation 30, Best Fitness: 12
# Generation 31, Best Fitness: 12
# Generation 32, Best Fitness: 12
# Generation 33, Best Fitness: 12
# Generation 34, Best Fitness: 12
# Generation 35, Best Fitness: 12
# Generation 36, Best Fitness: 12
# Generation 37, Best Fitness: 12
# Generation 38, Best Fitness: 12
# Generation 39, Best Fitness: 12
# Generation 40, Best Fitness: 12
# Generation 41, Best Fitness: 12
# Generation 42, Best Fitness: 12
# Generation 43, Best Fitness: 12
# Generation 44, Best Fitness: 12
# Generation 45, Best Fitness: 12
# Generation 46, Best Fitness: 12
# Generation 47, Best Fitness: 12
# Generation 48, Best Fitness: 12
# Generation 49, Best Fitness: 12
# Generation 50, Best Fitness: 12
# Generation 51, Best Fitness: 12
# Generation 52, Best Fitness: 12
# Generation 53, Best Fitness: 12
# Generation 54, Best Fitness: 12
# Generation 55, Best Fitness: 12
# Generation 56, Best Fitness: 12
# Generation 57, Best Fitness: 12
# Generation 58, Best Fitness: 12
# Generation 59, Best Fitness: 12
# Generation 60, Best Fitness: 12
# Generation 61, Best Fitness: 12
# Generation 62, Best Fitness: 12
# Generation 63, Best Fitness: 12
# Generation 64, Best Fitness: 12
# Generation 65, Best Fitness: 12
# Generation 66, Best Fitness: 12
# Generation 67, Best Fitness: 12
# Generation 68, Best Fitness: 12
# Generation 69, Best Fitness: 12
# Generation 70, Best Fitness: 12
# Generation 71, Best Fitness: 12
# Generation 72, Best Fitness: 12
# Generation 73, Best Fitness: 12
# Generation 74, Best Fitness: 12
# Generation 75, Best Fitness: 12
# Generation 76, Best Fitness: 12
# Generation 77, Best Fitness: 12
# Generation 78, Best Fitness: 12
# Generation 79, Best Fitness: 12
# Generation 80, Best Fitness: 12
# Generation 81, Best Fitness: 12
# Generation 82, Best Fitness: 12
# Generation 83, Best Fitness: 12
# Generation 84, Best Fitness: 12
# Generation 85, Best Fitness: 12
# Generation 86, Best Fitness: 12
# Generation 87, Best Fitness: 12
# Generation 88, Best Fitness: 12
# Generation 89, Best Fitness: 12
# Generation 90, Best Fitness: 12
# Generation 91, Best Fitness: 12
# Generation 92, Best Fitness: 12
# Generation 93, Best Fitness: 12
# Generation 94, Best Fitness: 12
# Generation 95, Best Fitness: 12
# Generation 96, Best Fitness: 12
# Generation 97, Best Fitness: 12
# Generation 98, Best Fitness: 12
# Generation 99, Best Fitness: 12
# Generation 100, Best Fitness: 12
# Best Schedule (Timeline):
# Job 3, Task 1 on M1 starts at 0
# Job 1, Task 1 on M2 starts at 0
# Job 1, Task 2 on M3 starts at 0
# Job 2, Task 1 on M3 starts at 4
# Job 2, Task 2 on M2 starts at 5
# Job 3, Task 2 on M1 starts at 7

# %% [markdown]
# # Task 2: Modify the `is_valid_schedule` function
#
# - Change the function to calculate penalty values for schedule violations:
#   - Identify violations where `start_time < machine_end_times[machine_id]`.
#   - Compute the total time units of violations.
#   - Multiply the total violation time by a penalty factor (e.g., 5 or 10).
#
# - Add this penalty value to the fitness value in `calculate_fitness`
#   - Include the penalty in the fitness calculation to better reflect the quality of the schedule.

# %%
import random

# Example problem data
jobs = [
    {"tasks": [5, 4]},  # Job 1: Task 1 takes 5 units, Task 2 takes 4 units
    {"tasks": [3, 6]},  # Job 2: Task 1 takes 3 units, Task 2 takes 6 units
    {"tasks": [7, 2]},  # Job 3: Task 1 takes 7 units, Task 2 takes 2 units
]

machines = ["M1", "M2", "M3"]  # List of machines

# Transport times between machines (constant for simplicity)
transport_times = {
    ("M1", "M2"): 2,
    ("M1", "M3"): 3,
    ("M2", "M1"): 2,
    ("M2", "M3"): 1,
    ("M3", "M1"): 3,
    ("M3", "M2"): 1,
    ("M1", "M1"): 0,
    ("M2", "M2"): 0,
    ("M3", "M3"): 0,
}

# Encode solution
def encode_solution(num_jobs, num_machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    for job_id in range(num_jobs):
        job_end_time = 0
        previous_machine = None
        for task_id in range(len(jobs[job_id]["tasks"])):
            machine_id = random.choice(machines)  # Introduce randomness for diversity
            transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
            start_time = max(machine_end_times[machine_id], job_end_time + transport_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration
            machine_end_times[machine_id] = end_time
            job_end_time = end_time
            previous_machine = machine_id
            chromosome.append((job_id, task_id, machine_id, start_time))
    return chromosome

# Fitness function
def calculate_fitness(chromosome):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * len(jobs)
    penalty = 0

    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        job_id = int(job_id)  # Ensure job_id is an integer
        task_id = int(task_id)  # Ensure task_id is an integer
        task_duration = jobs[job_id]["tasks"][task_id]
        if start_time < machine_end_times[machine_id]:
            penalty += (machine_end_times[machine_id] - start_time) * 10

        transport_time = 0
        if i > 0:
            _, _, prev_machine, _ = chromosome[i - 1]
            transport_time = transport_times.get((prev_machine, machine_id), 0)
        end_time = start_time + task_duration + transport_time
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)

    makespan = max(job_end_times)
    fitness = makespan + penalty * 0.1  # Scale down penalty
    return fitness

# Repair solution
def repair_solution(jobs, machines):
    tasks_to_schedule = [{"job_id": i, "task_id": 0, "processing_time": job["tasks"][0]}
                         for i, job in enumerate(jobs)]
    machine_end_times = {machine: 0 for machine in machines}
    schedule = []

    while tasks_to_schedule:
        task_to_schedule = max(tasks_to_schedule, key=lambda x: x["processing_time"])
        tasks_to_schedule.remove(task_to_schedule)

        job_id = task_to_schedule["job_id"]
        task_id = task_to_schedule["task_id"]

        machine = min(machines, key=lambda m: machine_end_times[m])
        start_time = machine_end_times[machine]
        processing_time = task_to_schedule["processing_time"]
        end_time = start_time + processing_time

        machine_end_times[machine] = end_time
        schedule.append((job_id, task_id, machine, start_time))

        if task_id + 1 < len(jobs[job_id]["tasks"]):
            tasks_to_schedule.append({
                "job_id": job_id,
                "task_id": task_id + 1,
                "processing_time": jobs[job_id]["tasks"][task_id + 1]
            })

    return schedule

# Genetic algorithm
def genetic_algorithm(num_jobs, num_machines, population_size=50, generations=100):
    population = [encode_solution(num_jobs, num_machines) for _ in range(population_size)]
    mutation_rate = 0.1  # Initial mutation rate

    for generation in range(generations):
        fitness_values = [calculate_fitness(ind) for ind in population]
        best_fitness = min(fitness_values)
        best_solution = population[fitness_values.index(best_fitness)]
        print(f"Generation {generation + 1}, Best Fitness: {best_fitness}")

        # Selection: Tournament selection
        selected_parents = random.choices(population, k=len(population))

        # Crossover
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            crossover_point1 = random.randint(1, len(parent1) // 2)
            crossover_point2 = random.randint(len(parent1) // 2, len(parent1) - 1)
            child1 = parent1[:crossover_point1] + parent2[crossover_point1:crossover_point2] + parent1[crossover_point2:]
            child2 = parent2[:crossover_point1] + parent1[crossover_point1:crossover_point2] + parent2[crossover_point2:]
            offspring.extend([repair_solution(jobs, machines), repair_solution(jobs, machines)])

        # Mutation
        for i in range(len(offspring)):
            if random.random() < mutation_rate:  # Dynamic mutation rate
                idx = random.randint(0, len(offspring[i]) - 1)
                job_id, task_id, _, start_time = offspring[i][idx]
                new_machine = random.choice(machines)
                offspring[i][idx] = (int(job_id), int(task_id), new_machine, start_time)
                offspring[i] = repair_solution(jobs, machines)

        # Update population
        population = offspring

        # Adjust mutation rate dynamically
        mutation_rate = max(0.05, mutation_rate * 0.99)

    return best_solution

# Example usage
best_solution = genetic_algorithm(num_jobs=3, num_machines=3, population_size=50, generations=100)
print("Best Schedule (Timeline):")
for job_id, task_id, machine_id, start_time in best_solution:
    print(f"Job {job_id + 1}, Task {task_id + 1} on {machine_id} starts at {start_time}")
# Out:
# Generation 1, Best Fitness: 16.0
# Generation 2, Best Fitness: 15.0
# Generation 3, Best Fitness: 15.0
# Generation 4, Best Fitness: 15.0
# Generation 5, Best Fitness: 15.0
# Generation 6, Best Fitness: 15.0
# Generation 7, Best Fitness: 15.0
# Generation 8, Best Fitness: 15.0
# Generation 9, Best Fitness: 15.0
# Generation 10, Best Fitness: 15.0
# Generation 11, Best Fitness: 15.0
# Generation 12, Best Fitness: 15.0
# Generation 13, Best Fitness: 15.0
# Generation 14, Best Fitness: 15.0
# Generation 15, Best Fitness: 15.0
# Generation 16, Best Fitness: 15.0
# Generation 17, Best Fitness: 15.0
# Generation 18, Best Fitness: 15.0
# Generation 19, Best Fitness: 15.0
# Generation 20, Best Fitness: 15.0
# Generation 21, Best Fitness: 15.0
# Job 1, Task 1 on M2 starts at 0
# Job 1, Task 2 on M3 starts at 0
# Job 2, Task 1 on M3 starts at 4
# Job 2, Task 2 on M2 starts at 5
# Job 3, Task 2 on M1 starts at 7

# %% [markdown]
# # Task 3: Create larger instances for testing
# - Generate at least 10 problem instances.
# - Use 10 machines, 20 jobs, and 5 tasks per job for each instance.

# %%
import random

# Example problem data generator
def generate_problem_instance(num_jobs, num_machines, num_tasks_per_job):
    jobs = [{"tasks": [random.randint(1, 10) for _ in range(num_tasks_per_job)]} for _ in range(num_jobs)]
    machines = [f"M{i+1}" for i in range(num_machines)]
    return jobs, machines

# Generate larger problem instances
problem_instances = [generate_problem_instance(20, 10, 5) for _ in range(10)]

# Transport times between machines (constant for simplicity)
transport_times = {
    (f"M{i+1}", f"M{j+1}"): random.randint(1, 5) if i != j else 0
    for i in range(10) for j in range(10)
}

# Encode solution
def encode_solution(jobs, machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    for job_id in range(len(jobs)):
        job_end_time = 0
        previous_machine = None
        for task_id in range(len(jobs[job_id]["tasks"])):
            machine_id = random.choice(machines)  # Introduce randomness for diversity
            transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
            start_time = max(machine_end_times[machine_id], job_end_time + transport_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration
            machine_end_times[machine_id] = end_time
            job_end_time = end_time
            previous_machine = machine_id
            chromosome.append((job_id, task_id, machine_id, start_time))
    return chromosome

# Fitness function
def calculate_fitness(chromosome, jobs, machines):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * len(jobs)
    penalty = 0

    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        job_id = int(job_id)  # Ensure job_id is an integer
        task_id = int(task_id)  # Ensure task_id is an integer
        task_duration = jobs[job_id]["tasks"][task_id]
        if start_time < machine_end_times[machine_id]:
            penalty += (machine_end_times[machine_id] - start_time) * 10

        transport_time = 0
        if i > 0:
            _, _, prev_machine, _ = chromosome[i - 1]
            transport_time = transport_times.get((prev_machine, machine_id), 0)
        end_time = start_time + task_duration + transport_time
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)

    makespan = max(job_end_times)
    fitness = makespan + penalty * 0.1  # Scale down penalty
    return fitness

# Repair solution
def repair_solution(jobs, machines):
    tasks_to_schedule = [{"job_id": i, "task_id": 0, "processing_time": job["tasks"][0]}
                         for i, job in enumerate(jobs)]
    machine_end_times = {machine: 0 for machine in machines}
    schedule = []

    while tasks_to_schedule:
        task_to_schedule = max(tasks_to_schedule, key=lambda x: x["processing_time"])
        tasks_to_schedule.remove(task_to_schedule)

        job_id = task_to_schedule["job_id"]
        task_id = task_to_schedule["task_id"]

        machine = min(machines, key=lambda m: machine_end_times[m])
        start_time = machine_end_times[machine]
        processing_time = task_to_schedule["processing_time"]
        end_time = start_time + processing_time

        machine_end_times[machine] = end_time
        schedule.append((job_id, task_id, machine, start_time))

        if task_id + 1 < len(jobs[job_id]["tasks"]):
            tasks_to_schedule.append({
                "job_id": job_id,
                "task_id": task_id + 1,
                "processing_time": jobs[job_id]["tasks"][task_id + 1]
            })

    return schedule

# Genetic algorithm
def genetic_algorithm(jobs, machines, population_size=50, generations=100):
    population = [encode_solution(jobs, machines) for _ in range(population_size)]
    mutation_rate = 0.1  # Initial mutation rate

    for generation in range(generations):
        fitness_values = [calculate_fitness(ind, jobs, machines) for ind in population]
        best_fitness = min(fitness_values)
        best_solution = population[fitness_values.index(best_fitness)]
        print(f"Generation {generation + 1}, Best Fitness: {best_fitness}")

        # Selection: Tournament selection
        selected_parents = random.choices(population, k=len(population))

        # Crossover
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            crossover_point1 = random.randint(1, len(parent1) // 2)
            crossover_point2 = random.randint(len(parent1) // 2, len(parent1) - 1)
            child1 = parent1[:crossover_point1] + parent2[crossover_point1:crossover_point2] + parent1[crossover_point2:]
            child2 = parent2[:crossover_point1] + parent1[crossover_point1:crossover_point2] + parent2[crossover_point2:]
            offspring.extend([repair_solution(jobs, machines), repair_solution(jobs, machines)])

        # Mutation
        for i in range(len(offspring)):
            if random.random() < mutation_rate:  # Dynamic mutation rate
                idx = random.randint(0, len(offspring[i]) - 1)
                job_id, task_id, _, start_time = offspring[i][idx]
                new_machine = random.choice(machines)
                offspring[i][idx] = (int(job_id), int(task_id), new_machine, start_time)
                offspring[i] = repair_solution(jobs, machines)

        # Update population
        population = offspring

        # Adjust mutation rate dynamically
        mutation_rate = max(0.05, mutation_rate * 0.99)

    return best_solution

# Example usage for problem instances
for idx, (jobs, machines) in enumerate(problem_instances):
    print(f"Testing Problem Instance {idx + 1}")
    best_solution = genetic_algorithm(jobs, machines, population_size=50, generations=100)
    print("Best Schedule (Timeline):")
    for job_id, task_id, machine_id, start_time in best_solution:
        print(f"Job {job_id + 1}, Task {task_id + 1} on {machine_id} starts at {start_time}")
    print()
# Out:
# Testing Problem Instance 1
# Generation 1, Best Fitness: 383.0
# Generation 2, Best Fitness: 331.0
# Generation 3, Best Fitness: 331.0
# Generation 4, Best Fitness: 331.0
# Generation 5, Best Fitness: 331.0
# Generation 6, Best Fitness: 331.0
# Generation 7, Best Fitness: 331.0
# Generation 8, Best Fitness: 331.0
# Generation 9, Best Fitness: 331.0
# Generation 10, Best Fitness: 331.0
# Generation 11, Best Fitness: 331.0
# Generation 12, Best Fitness: 331.0
# Generation 13, Best Fitness: 331.0
# Generation 14, Best Fitness: 331.0
# Generation 15, Best Fitness: 331.0
# Generation 16, Best Fitness: 331.0
# Generation 17, Best Fitness: 331.0
# Generation 18, Best Fitness: 331.0
# Generation 19, Best Fitness: 331.0
# Generation 20, Best Fitness: 331.0
# Generation 21, Best Fitness: 331.0
# Generation 22, Best Fitness: 331.0
# Generation 23, Best Fitness: 331.0
# Generation 24, Best Fitness: 331.0
# Generation 25, Best Fitness: 331.0
# Generation 26, Best Fitness: 331.0
# Generation 27, Best Fitness: 331.0
# Generation 28, Best Fitness: 331.0
# Generation 29, Best Fitness: 331.0
# Generation 30, Best Fitness: 331.0
# Generation 31, Best Fitness: 331.0
# Generation 32, Best Fitness: 331.0
# Job 4, Task 1 on M8 starts at 7
# Job 4, Task 2 on M10 starts at 7
# Job 11, Task 1 on M4 starts at 8
# Job 16, Task 1 on M5 starts at 8
# Job 9, Task 2 on M6 starts at 8
# Job 13, Task 1 on M2 starts at 9
# Job 2, Task 2 on M3 starts at 9
# Job 2, Task 3 on M1 starts at 10
# Job 2, Task 4 on M9 starts at 10
# Job 6, Task 1 on M7 starts at 13
# Job 6, Task 2 on M8 starts at 13
# Job 6, Task 3 on M2 starts at 14
# Job 6, Task 4 on M3 starts at 14
# Job 7, Task 1 on M4 starts at 14
# Job 7, Task 2 on M5 starts at 14
# Job 7, Task 3 on M6 starts at 14
# Job 7, Task 4 on M7 starts at 17
# Job 7, Task 5 on M10 starts at 17
# Job 15, Task 1 on M4 starts at 18
# Job 15, Task 2 on M8 starts at 18
# Job 15, Task 3 on M1 starts at 19
# Job 15, Task 4 on M3 starts at 19
# Job 5, Task 2 on M5 starts at 19
# Job 9, Task 3 on M9 starts at 20
# Job 9, Task 4 on M4 starts at 22
# Job 2, Task 5 on M10 starts at 22
# Job 6, Task 5 on M5 starts at 23
# Job 15, Task 5 on M6 starts at 23
# Job 14, Task 1 on M2 starts at 24
# Job 3, Task 2 on M7 starts at 24
# Job 3, Task 3 on M9 starts at 24
# Job 3, Task 4 on M1 starts at 26
# Job 4, Task 3 on M3 starts at 26
# Job 4, Task 4 on M8 starts at 26
# Job 4, Task 5 on M10 starts at 26
# Job 1, Task 1 on M2 starts at 27
# Job 1, Task 2 on M5 starts at 27
# Job 1, Task 3 on M6 starts at 27
# Job 1, Task 4 on M7 starts at 27
# Job 1, Task 5 on M4 starts at 28
# Job 10, Task 1 on M2 starts at 29
# Job 10, Task 2 on M3 starts at 29
# Job 10, Task 3 on M8 starts at 29
# Job 12, Task 1 on M6 starts at 30
# Job 12, Task 2 on M2 starts at 31
# Job 18, Task 2 on M9 starts at 31
# Job 18, Task 3 on M1 starts at 32
# Job 18, Task 4 on M5 starts at 32
# Job 11, Task 2 on M6 starts at 32
# Job 11, Task 3 on M7 starts at 33
# Job 11, Task 4 on M9 starts at 33
# Job 14, Task 2 on M6 starts at 34
# Job 14, Task 3 on M6 starts at 36
# Job 14, Task 4 on M10 starts at 36
# Job 14, Task 5 on M3 starts at 37
# Job 10, Task 4 on M4 starts at 37
# Job 12, Task 3 on M8 starts at 37
# Job 12, Task 4 on M1 starts at 38
# Job 12, Task 5 on M2 starts at 38
# Job 11, Task 5 on M4 starts at 39
# Job 19, Task 2 on M8 starts at 39
# Job 19, Task 3 on M5 starts at 40
# Job 19, Task 4 on M6 starts at 40
# Job 19, Task 5 on M8 starts at 40
# Job 20, Task 2 on M4 starts at 41
# Job 8, Task 3 on M4 starts at 42
# Job 8, Task 4 on M8 starts at 42
# Job 17, Task 3 on M4 starts at 43
# Job 17, Task 4 on M5 starts at 43
# Job 17, Task 5 on M6 starts at 43
# Job 16, Task 2 on M7 starts at 43
# Job 16, Task 3 on M9 starts at 43
# Job 16, Task 4 on M4 starts at 44
# Generation 63, Best Fitness: 302.0
# Generation 64, Best Fitness: 302.0
# Generation 65, Best Fitness: 302.0
# Generation 66, Best Fitness: 302.0
# Generation 67, Best Fitness: 302.0
# Generation 68, Best Fitness: 302.0
# Generation 69, Best Fitness: 302.0
# Generation 70, Best Fitness: 302.0
# Generation 71, Best Fitness: 302.0
# Generation 72, Best Fitness: 302.0
# Generation 73, Best Fitness: 302.0
# Generation 74, Best Fitness: 302.0
# Generation 75, Best Fitness: 302.0
# Generation 76, Best Fitness: 302.0
# Generation 77, Best Fitness: 302.0
# Generation 78, Best Fitness: 302.0
# Generation 79, Best Fitness: 302.0
# Generation 80, Best Fitness: 302.0
# Generation 81, Best Fitness: 302.0
# Generation 82, Best Fitness: 302.0
# Generation 83, Best Fitness: 302.0
# Generation 84, Best Fitness: 302.0
# Generation 85, Best Fitness: 302.0
# Generation 86, Best Fitness: 302.0
# Generation 87, Best Fitness: 302.0
# Generation 88, Best Fitness: 302.0
# Generation 89, Best Fitness: 302.0
# Generation 90, Best Fitness: 302.0
# Generation 91, Best Fitness: 302.0
# Generation 92, Best Fitness: 302.0
# Generation 93, Best Fitness: 302.0
# Generation 94, Best Fitness: 302.0
# Generation 95, Best Fitness: 302.0
# Generation 96, Best Fitness: 302.0
# Generation 97, Best Fitness: 302.0
# Generation 98, Best Fitness: 302.0
# Generation 99, Best Fitness: 302.0
# Generation 100, Best Fitness: 302.0
# Best Schedule (Timeline):
# Job 2, Task 1 on M1 starts at 0
# Job 17, Task 1 on M2 starts at 0
# Job 18, Task 1 on M3 starts at 0
# Job 3, Task 1 on M4 starts at 0
# Job 3, Task 2 on M5 starts at 0
# Job 4, Task 1 on M6 starts at 0
# Job 13, Task 1 on M7 starts at 0
# Job 14, Task 1 on M8 starts at 0
# Job 15, Task 1 on M9 starts at 0
# Job 16, Task 1 on M10 starts at 0
# Job 4, Task 2 on M4 starts at 9
# Job 15, Task 2 on M6 starts at 9
# Job 2, Task 2 on M7 starts at 9
# Job 9, Task 1 on M8 starts at 9
# Job 19, Task 1 on M9 starts at 9
# Job 4, Task 3 on M10 starts at 9
# Job 15, Task 3 on M1 starts at 10
# Job 15, Task 4 on M2 starts at 10
# Job 15, Task 5 on M3 starts at 10
# Job 4, Task 4 on M5 starts at 10
# Job 8, Task 1 on M8 starts at 16
# Job 8, Task 2 on M9 starts at 16
# Job 12, Task 1 on M10 starts at 16
# Job 12, Task 2 on M1 starts at 17
# Job 10, Task 1 on M5 starts at 17
# Job 10, Task 2 on M7 starts at 17
# Job 4, Task 5 on M4 starts at 18
# Job 10, Task 3 on M6 starts at 18
# Job 5, Task 1 on M2 starts at 19
# Job 13, Task 2 on M3 starts at 20
# Job 13, Task 3 on M5 starts at 22
# Job 16, Task 2 on M8 starts at 22
# Job 16, Task 3 on M10 starts at 22
# Job 2, Task 3 on M1 starts at 23
# Job 2, Task 4 on M2 starts at 23
# Job 2, Task 5 on M4 starts at 23
# Job 5, Task 2 on M6 starts at 23
# Job 5, Task 3 on M3 starts at 24
# Job 5, Task 4 on M7 starts at 24
# Job 5, Task 5 on M8 starts at 26
# Job 16, Task 4 on M9 starts at 26
# Job 16, Task 5 on M1 starts at 27
# Job 1, Task 1 on M6 starts at 27
# Job 7, Task 1 on M5 starts at 29
# Job 7, Task 2 on M7 starts at 29
# Job 7, Task 3 on M6 starts at 30
# Job 7, Task 4 on M9 starts at 30
# Job 11, Task 1 on M3 starts at 31
# Job 11, Task 2 on M2 starts at 32
# Job 17, Task 2 on M5 starts at 32
# Job 17, Task 3 on M10 starts at 32
# Job 17, Task 4 on M4 starts at 33
# Job 18, Task 2 on M1 starts at 34
# Job 18, Task 3 on M3 starts at 34
# Job 18, Task 4 on M5 starts at 35
# Job 3, Task 3 on M6 starts at 35
# Job 3, Task 4 on M7 starts at 35
# Job 14, Task 2 on M8 starts at 36
# Job 9, Task 2 on M1 starts at 37
# Job 19, Task 2 on M2 starts at 38
# Job 19, Task 3 on M6 starts at 38
# Job 8, Task 3 on M7 starts at 39
# Job 8, Task 4 on M8 starts at 39
# Job 8, Task 5 on M9 starts at 39
# Job 12, Task 3 on M10 starts at 39
# Job 12, Task 4 on M1 starts at 40
# Job 12, Task 5 on M3 starts at 40
# Job 10, Task 4 on M2 starts at 41
# Job 10, Task 5 on M4 starts at 42
# Job 13, Task 4 on M6 starts at 42
# Job 13, Task 5 on M7 starts at 42
# Job 9, Task 3 on M10 starts at 42
# Job 9, Task 4 on M5 starts at 43
# Job 9, Task 5 on M2 starts at 44
# Job 6, Task 1 on M6 starts at 45
# Job 18, Task 5 on M10 starts at 45
# Job 3, Task 5 on M4 starts at 46
# Job 19, Task 4 on M5 starts at 46
# Job 19, Task 5 on M6 starts at 47
# Job 6, Task 2 on M9 starts at 47
# Job 6, Task 3 on M10 starts at 47
# Job 6, Task 4 on M1 starts at 48
# Job 20, Task 1 on M4 starts at 48
# Job 20, Task 2 on M5 starts at 48
# Job 20, Task 3 on M4 starts at 49
# Job 20, Task 4 on M8 starts at 49
# Job 20, Task 5 on M9 starts at 49
# Job 1, Task 2 on M3 starts at 50
# Job 1, Task 3 on M5 starts at 50
# Job 1, Task 4 on M7 starts at 50
# Job 1, Task 5 on M10 starts at 50
# Job 7, Task 5 on M3 starts at 51
# Job 11, Task 3 on M3 starts at 52
# Job 11, Task 4 on M2 starts at 53
# Job 11, Task 5 on M3 starts at 53
# Job 17, Task 5 on M4 starts at 53
# Job 14, Task 3 on M10 starts at 53
# Job 14, Task 4 on M4 starts at 54
# Job 6, Task 5 on M5 starts at 54
# Job 14, Task 5 on M6 starts at 54
#
# Testing Problem Instance 3
# Generation 1, Best Fitness: 394.0
# Generation 2, Best Fitness: 346.0
# Generation 3, Best Fitness: 346.0
# Generation 4, Best Fitness: 346.0
# Generation 5, Best Fitness: 346.0
# Generation 6, Best Fitness: 346.0
# Generation 7, Best Fitness: 346.0
# Generation 8, Best Fitness: 346.0
# Generation 9, Best Fitness: 346.0
# Generation 10, Best Fitness: 346.0
# Generation 11, Best Fitness: 346.0
# Generation 92, Best Fitness: 346.0
# Generation 93, Best Fitness: 346.0
# Generation 94, Best Fitness: 346.0
# Generation 95, Best Fitness: 346.0
# Generation 96, Best Fitness: 346.0
# Generation 97, Best Fitness: 346.0
# Generation 98, Best Fitness: 346.0
# Generation 99, Best Fitness: 346.0
# Generation 100, Best Fitness: 346.0
# Best Schedule (Timeline):
# Job 7, Task 1 on M1 starts at 0
# Job 18, Task 1 on M2 starts at 0
# Job 8, Task 1 on M3 starts at 0
# Job 10, Task 1 on M4 starts at 0
# Job 5, Task 1 on M5 starts at 0
# Job 20, Task 1 on M6 starts at 0
# Job 4, Task 1 on M7 starts at 0
# Job 4, Task 2 on M8 starts at 0
# Job 12, Task 1 on M9 starts at 0
# Job 17, Task 1 on M10 starts at 0
# Job 17, Task 2 on M10 starts at 6
# Job 19, Task 1 on M7 starts at 7
# Job 19, Task 2 on M9 starts at 7
# Job 7, Task 2 on M5 starts at 8
# Job 7, Task 3 on M6 starts at 8
# Job 20, Task 2 on M3 starts at 9
# Job 4, Task 3 on M4 starts at 9
# Job 4, Task 4 on M8 starts at 9
# Job 4, Task 5 on M1 starts at 10
# Job 20, Task 3 on M2 starts at 10
# Job 1, Task 1 on M7 starts at 13
# Job 9, Task 1 on M5 starts at 14
# Job 13, Task 1 on M3 starts at 15
# Job 14, Task 1 on M4 starts at 15
# Job 16, Task 1 on M10 starts at 15
# Job 11, Task 1 on M2 starts at 16
# Job 11, Task 2 on M9 starts at 16
# Job 5, Task 2 on M8 starts at 17
# Job 5, Task 3 on M6 starts at 18
# Job 5, Task 4 on M7 starts at 18
# Job 20, Task 4 on M5 starts at 19
# Job 20, Task 5 on M1 starts at 20
# Job 11, Task 3 on M2 starts at 20
# Job 11, Task 4 on M3 starts at 20
# Job 11, Task 5 on M4 starts at 20
# Job 5, Task 5 on M10 starts at 20
# Job 2, Task 1 on M8 starts at 21
# Job 2, Task 2 on M9 starts at 22
# Job 2, Task 3 on M5 starts at 23
# Job 2, Task 4 on M2 starts at 24
# Job 3, Task 1 on M6 starts at 24
# Job 3, Task 2 on M8 starts at 24
# Job 3, Task 3 on M10 starts at 24
# Job 3, Task 4 on M4 starts at 25
# Job 3, Task 5 on M9 starts at 26
# Job 6, Task 1 on M3 starts at 27
# Job 15, Task 1 on M5 starts at 27
# Job 17, Task 3 on M6 starts at 27
# Job 7, Task 4 on M7 starts at 27
# Job 7, Task 5 on M1 starts at 28
# Job 13, Task 2 on M3 starts at 30
# Job 16, Task 2 on M5 starts at 30
# Job 16, Task 3 on M6 starts at 30
# Job 16, Task 4 on M7 starts at 30
# Job 16, Task 5 on M10 starts at 30
# Job 17, Task 4 on M2 starts at 31
# Job 17, Task 5 on M9 starts at 31
# Job 18, Task 2 on M3 starts at 33
# Job 18, Task 3 on M4 starts at 33
# Job 1, Task 2 on M5 starts at 33
# Job 1, Task 3 on M8 starts at 33
# Job 1, Task 4 on M2 starts at 34
# Job 1, Task 5 on M3 starts at 35
# Job 9, Task 2 on M5 starts at 35
# Job 9, Task 3 on M10 starts at 35
# Job 9, Task 4 on M6 starts at 36
# Job 9, Task 5 on M7 starts at 36
# Job 14, Task 2 on M9 starts at 36
# Job 14, Task 3 on M1 starts at 37
# Job 14, Task 4 on M5 starts at 37
# Job 2, Task 5 on M9 starts at 38
# Job 15, Task 2 on M7 starts at 39
# Job 15, Task 3 on M9 starts at 40
# Job 15, Task 4 on M2 starts at 41
# Job 15, Task 5 on M5 starts at 41
# Job 8, Task 2 on M7 starts at 41
# Job 8, Task 3 on M4 starts at 42
# Job 8, Task 4 on M7 starts at 42
# Job 8, Task 5 on M8 starts at 42
# Job 10, Task 2 on M10 starts at 43
# Job 10, Task 3 on M1 starts at 44
# Job 10, Task 4 on M9 starts at 44
# Job 10, Task 5 on M10 starts at 44
# Job 12, Task 2 on M2 starts at 45
# Job 19, Task 3 on M3 starts at 45
# Job 19, Task 4 on M5 starts at 45
# Job 19, Task 5 on M7 starts at 45
# Job 6, Task 2 on M2 starts at 46
# Job 13, Task 3 on M3 starts at 46
# Job 13, Task 4 on M6 starts at 46
# Job 13, Task 5 on M2 starts at 47
# Job 18, Task 4 on M3 starts at 47
# Job 18, Task 5 on M8 starts at 47
# Job 14, Task 5 on M9 starts at 47
# Job 12, Task 3 on M3 starts at 48
# Job 12, Task 4 on M6 starts at 48
# Job 12, Task 5 on M9 starts at 48
# Job 6, Task 3 on M3 starts at 49
# Job 6, Task 4 on M1 starts at 50
# Job 6, Task 5 on M3 starts at 50
#
# Testing Problem Instance 4
# Generation 1, Best Fitness: 379.0
# Generation 2, Best Fitness: 287.0
# Generation 3, Best Fitness: 287.0
# Generation 4, Best Fitness: 287.0
# Generation 5, Best Fitness: 287.0
# Generation 6, Best Fitness: 287.0
# Generation 7, Best Fitness: 287.0
# Generation 8, Best Fitness: 287.0
# Generation 9, Best Fitness: 287.0
# Generation 10, Best Fitness: 287.0
# Generation 11, Best Fitness: 287.0
# Generation 12, Best Fitness: 287.0
# Generation 13, Best Fitness: 287.0
# Generation 14, Best Fitness: 287.0
# Generation 15, Best Fitness: 287.0
# Generation 16, Best Fitness: 287.0
# Generation 17, Best Fitness: 287.0
# Generation 18, Best Fitness: 287.0
# Generation 19, Best Fitness: 287.0
# Generation 20, Best Fitness: 287.0
# Generation 21, Best Fitness: 287.0
# Generation 22, Best Fitness: 287.0
# Generation 23, Best Fitness: 287.0
# Generation 24, Best Fitness: 287.0
# Generation 25, Best Fitness: 287.0
# Generation 26, Best Fitness: 287.0
# Generation 27, Best Fitness: 287.0
# Generation 28, Best Fitness: 287.0
# Generation 29, Best Fitness: 287.0
# Generation 30, Best Fitness: 287.0
# Generation 31, Best Fitness: 287.0
# Generation 32, Best Fitness: 287.0
# Generation 33, Best Fitness: 287.0
# Generation 34, Best Fitness: 287.0
# Generation 35, Best Fitness: 287.0
# Generation 36, Best Fitness: 287.0
# Generation 37, Best Fitness: 287.0
# Generation 38, Best Fitness: 287.0
# Generation 39, Best Fitness: 287.0
# Generation 40, Best Fitness: 287.0
# Job 3, Task 1 on M2 starts at 10
# Job 3, Task 2 on M9 starts at 10
# Job 3, Task 3 on M6 starts at 14
# Job 3, Task 4 on M7 starts at 14
# Job 3, Task 5 on M8 starts at 14
# Job 4, Task 2 on M10 starts at 14
# Job 12, Task 3 on M2 starts at 15
# Job 14, Task 3 on M4 starts at 15
# Job 14, Task 4 on M5 starts at 15
# Job 14, Task 5 on M1 starts at 16
# Job 18, Task 2 on M3 starts at 19
# Job 18, Task 3 on M9 starts at 19
# Job 12, Task 4 on M10 starts at 19
# Job 12, Task 5 on M2 starts at 20
# Job 18, Task 4 on M4 starts at 20
# Job 18, Task 5 on M7 starts at 20
# Job 11, Task 1 on M6 starts at 22
# Job 11, Task 2 on M3 starts at 23
# Job 17, Task 1 on M10 starts at 23
# Job 17, Task 2 on M4 starts at 24
# Job 17, Task 3 on M5 starts at 24
# Job 17, Task 4 on M8 starts at 24
# Job 17, Task 5 on M6 starts at 25
# Job 15, Task 2 on M7 starts at 25
# Job 15, Task 3 on M1 starts at 26
# Job 15, Task 4 on M2 starts at 26
# Job 15, Task 5 on M10 starts at 26
# Job 7, Task 1 on M3 starts at 27
# Job 8, Task 1 on M7 starts at 28
# Job 9, Task 1 on M3 starts at 29
# Job 16, Task 1 on M9 starts at 29
# Job 13, Task 2 on M4 starts at 30
# Job 13, Task 3 on M6 starts at 30
# Job 13, Task 4 on M7 starts at 30
# Job 13, Task 5 on M3 starts at 31
# Job 6, Task 3 on M9 starts at 31
# Job 6, Task 4 on M4 starts at 32
# Job 6, Task 5 on M5 starts at 32
# Job 10, Task 3 on M2 starts at 33
# Job 10, Task 4 on M8 starts at 33
# Job 10, Task 5 on M9 starts at 33
# Job 11, Task 3 on M10 starts at 33
# Job 11, Task 4 on M7 starts at 34
# Job 11, Task 5 on M2 starts at 35
# Job 7, Task 2 on M10 starts at 35
# Job 7, Task 3 on M1 starts at 36
# Job 7, Task 4 on M3 starts at 37
# Job 7, Task 5 on M5 starts at 37
# Job 9, Task 2 on M7 starts at 37
# Job 9, Task 3 on M10 starts at 37
# Job 9, Task 4 on M6 starts at 38
# Job 2, Task 1 on M7 starts at 39
# Job 2, Task 2 on M7 starts at 40
# Job 2, Task 3 on M8 starts at 40
# Job 2, Task 4 on M9 starts at 40
# Job 2, Task 5 on M1 starts at 41
# Job 1, Task 2 on M4 starts at 41
# Job 1, Task 3 on M4 starts at 42
# Job 1, Task 4 on M1 starts at 44
# Job 1, Task 5 on M7 starts at 44
# Job 20, Task 2 on M2 starts at 45
# Job 20, Task 3 on M3 starts at 45
# Job 20, Task 4 on M5 starts at 45
# Job 20, Task 5 on M6 starts at 45
# Job 5, Task 3 on M9 starts at 45
# Job 5, Task 4 on M2 starts at 46
# Job 5, Task 5 on M9 starts at 46
# Job 19, Task 3 on M10 starts at 47
# Job 19, Task 4 on M10 starts at 48
# Job 19, Task 5 on M1 starts at 49
# Job 4, Task 3 on M2 starts at 49
# Job 8, Task 2 on M4 starts at 49
# Job 8, Task 3 on M2 starts at 50
# Generation 71, Best Fitness: 302.0
# Generation 72, Best Fitness: 302.0
# Generation 73, Best Fitness: 302.0
# Generation 74, Best Fitness: 302.0
# Generation 75, Best Fitness: 302.0
# Generation 76, Best Fitness: 302.0
# Generation 77, Best Fitness: 302.0
# Generation 78, Best Fitness: 302.0
# Generation 79, Best Fitness: 302.0
# Generation 80, Best Fitness: 302.0
# Generation 81, Best Fitness: 302.0
# Generation 82, Best Fitness: 302.0
# Generation 83, Best Fitness: 302.0
# Generation 84, Best Fitness: 302.0
# Generation 85, Best Fitness: 302.0
# Generation 86, Best Fitness: 302.0
# Generation 87, Best Fitness: 302.0
# Generation 88, Best Fitness: 302.0
# Generation 89, Best Fitness: 302.0
# Generation 90, Best Fitness: 302.0
# Generation 91, Best Fitness: 302.0
# Generation 92, Best Fitness: 302.0
# Generation 93, Best Fitness: 302.0
# Generation 94, Best Fitness: 302.0
# Generation 95, Best Fitness: 302.0
# Generation 96, Best Fitness: 302.0
# Generation 97, Best Fitness: 302.0
# Generation 98, Best Fitness: 302.0
# Generation 99, Best Fitness: 302.0
# Generation 100, Best Fitness: 302.0
# Best Schedule (Timeline):
# Job 17, Task 1 on M1 starts at 0
# Job 1, Task 1 on M2 starts at 0
# Job 19, Task 1 on M3 starts at 0
# Job 17, Task 2 on M4 starts at 0
# Job 10, Task 1 on M5 starts at 0
# Job 12, Task 1 on M6 starts at 0
# Job 17, Task 3 on M7 starts at 0
# Job 10, Task 2 on M8 starts at 0
# Job 11, Task 1 on M9 starts at 0
# Job 11, Task 2 on M10 starts at 0
# Job 13, Task 1 on M9 starts at 7
# Job 13, Task 2 on M5 starts at 8
# Job 16, Task 1 on M6 starts at 8
# Job 16, Task 2 on M7 starts at 8
# Job 11, Task 3 on M8 starts at 8
# Job 4, Task 1 on M2 starts at 9
# Job 7, Task 1 on M3 starts at 9
# Job 9, Task 1 on M4 starts at 9
# Job 15, Task 1 on M10 starts at 9
# Job 18, Task 1 on M1 starts at 10
# Job 10, Task 3 on M9 starts at 14
# Job 11, Task 4 on M2 starts at 15
# Job 6, Task 1 on M3 starts at 15
# Job 8, Task 1 on M4 starts at 15
# Job 8, Task 2 on M6 starts at 15
# Job 8, Task 3 on M8 starts at 15
# Job 19, Task 2 on M10 starts at 15
# Job 19, Task 3 on M1 starts at 16
# Job 7, Task 2 on M7 starts at 17
# Job 7, Task 3 on M5 starts at 18
# Job 7, Task 4 on M3 starts at 20
# Job 7, Task 5 on M4 starts at 20
# Job 15, Task 2 on M9 starts at 20
# Job 14, Task 1 on M10 starts at 20
# Job 1, Task 2 on M2 starts at 21
# Job 17, Task 4 on M7 starts at 22
# Job 4, Task 2 on M8 starts at 24
# Job 10, Task 4 on M10 starts at 24
# Job 10, Task 5 on M1 starts at 25
# Job 14, Task 2 on M2 starts at 25
# Job 14, Task 3 on M6 starts at 25
# Job 2, Task 1 on M9 starts at 25
# Job 2, Task 2 on M7 starts at 26
# Job 20, Task 1 on M3 starts at 28
# Job 20, Task 2 on M4 starts at 28
# Job 20, Task 3 on M5 starts at 28
# Job 12, Task 2 on M8 starts at 28
# Job 12, Task 3 on M9 starts at 28
# Job 12, Task 4 on M10 starts at 28
# Job 12, Task 5 on M2 starts at 29
# Job 16, Task 3 on M3 starts at 31
# Job 16, Task 4 on M8 starts at 31
# Job 9, Task 2 on M6 starts at 32
# Job 9, Task 3 on M7 starts at 32
# Job 8, Task 4 on M10 starts at 33
# Job 19, Task 4 on M1 starts at 34
# Job 19, Task 5 on M3 starts at 34
# Job 15, Task 3 on M9 starts at 34
# Job 15, Task 4 on M6 starts at 35
# Job 15, Task 5 on M4 starts at 36
# Job 1, Task 3 on M10 starts at 36
# Job 1, Task 4 on M1 starts at 37
# Job 2, Task 3 on M5 starts at 37
# Job 16, Task 5 on M9 starts at 37
# Job 8, Task 5 on M2 starts at 38
# Job 1, Task 5 on M10 starts at 39
# Job 3, Task 1 on M4 starts at 40
# Job 18, Task 2 on M5 starts at 40
# Job 18, Task 3 on M7 starts at 40
# Job 18, Task 4 on M8 starts at 40
# Job 18, Task 5 on M9 starts at 40
# Job 6, Task 2 on M1 starts at 41
# Job 6, Task 3 on M2 starts at 41
# Job 6, Task 4 on M6 starts at 41
# Job 6, Task 5 on M4 starts at 42
# Job 17, Task 5 on M5 starts at 42
# Job 4, Task 3 on M10 starts at 42
# Job 4, Task 4 on M1 starts at 43
# Job 4, Task 5 on M3 starts at 43
# Job 14, Task 4 on M8 starts at 43
# Job 14, Task 5 on M5 starts at 44
# Job 20, Task 4 on M7 starts at 44
# Job 20, Task 5 on M10 starts at 44
# Job 2, Task 4 on M6 starts at 45
# Job 2, Task 5 on M8 starts at 45
# Job 3, Task 2 on M2 starts at 46
# Job 3, Task 3 on M3 starts at 46
# Job 3, Task 4 on M4 starts at 46
# Job 3, Task 5 on M7 starts at 46
# Job 5, Task 1 on M6 starts at 47
# Job 5, Task 2 on M2 starts at 48
# Job 5, Task 3 on M6 starts at 48
# Job 5, Task 4 on M9 starts at 48
# Job 5, Task 5 on M1 starts at 51
# Job 13, Task 3 on M10 starts at 52
# Job 13, Task 4 on M3 starts at 53
# Job 13, Task 5 on M8 starts at 53
# Job 11, Task 5 on M10 starts at 53
# Job 9, Task 4 on M5 starts at 54
# Job 9, Task 5 on M10 starts at 54
#
# Testing Problem Instance 6
# Generation 1, Best Fitness: 412.0
# Generation 2, Best Fitness: 339.0
# Generation 3, Best Fitness: 339.0
# Generation 4, Best Fitness: 339.0
# Generation 5, Best Fitness: 339.0
# Generation 6, Best Fitness: 339.0
# Generation 7, Best Fitness: 339.0
# Generation 8, Best Fitness: 339.0
# Generation 9, Best Fitness: 339.0
# Generation 10, Best Fitness: 339.0
# Generation 11, Best Fitness: 339.0
# Generation 12, Best Fitness: 339.0
# Generation 13, Best Fitness: 339.0
# Generation 14, Best Fitness: 339.0
# Generation 15, Best Fitness: 339.0
# Generation 16, Best Fitness: 339.0
# Generation 17, Best Fitness: 339.0
# Generation 18, Best Fitness: 339.0
# Generation 19, Best Fitness: 339.0
# Generation 100, Best Fitness: 339.0
# Best Schedule (Timeline):
# Job 3, Task 1 on M1 starts at 0
# Job 9, Task 1 on M2 starts at 0
# Job 12, Task 1 on M3 starts at 0
# Job 16, Task 1 on M4 starts at 0
# Job 16, Task 2 on M5 starts at 0
# Job 9, Task 2 on M6 starts at 0
# Job 18, Task 1 on M7 starts at 0
# Job 18, Task 2 on M8 starts at 0
# Job 20, Task 1 on M9 starts at 0
# Job 20, Task 2 on M10 starts at 0
# Job 16, Task 3 on M7 starts at 8
# Job 16, Task 4 on M9 starts at 8
# Job 1, Task 1 on M3 starts at 9
# Job 2, Task 1 on M4 starts at 9
# Job 2, Task 2 on M6 starts at 9
# Job 2, Task 3 on M8 starts at 9
# Job 2, Task 4 on M1 starts at 10
# Job 17, Task 1 on M2 starts at 10
# Job 17, Task 2 on M5 starts at 10
# Job 3, Task 2 on M10 starts at 10
# Job 3, Task 3 on M3 starts at 15
# Job 18, Task 3 on M4 starts at 15
# Job 18, Task 4 on M7 starts at 15
# Job 18, Task 5 on M2 starts at 16
# Job 6, Task 1 on M10 starts at 16
# Job 7, Task 1 on M8 starts at 17
# Job 10, Task 1 on M1 starts at 18
# Job 20, Task 3 on M5 starts at 18
# Job 2, Task 5 on M6 starts at 18
# Job 17, Task 3 on M9 starts at 18
# Job 3, Task 4 on M4 starts at 21
# Job 20, Task 4 on M7 starts at 21
# Job 4, Task 1 on M10 starts at 21
# Job 5, Task 1 on M1 starts at 22
# Job 5, Task 2 on M2 starts at 22
# Job 5, Task 3 on M5 starts at 22
# Job 5, Task 4 on M6 starts at 22
# Job 5, Task 5 on M8 starts at 22
# Job 12, Task 2 on M9 starts at 22
# Job 12, Task 3 on M3 starts at 23
# Job 12, Task 4 on M10 starts at 24
# Job 12, Task 5 on M1 starts at 25
# Job 17, Task 4 on M4 starts at 25
# Job 3, Task 5 on M7 starts at 25
# Job 13, Task 1 on M9 starts at 25
# Job 14, Task 1 on M8 starts at 26
# Job 14, Task 2 on M2 starts at 27
# Job 14, Task 3 on M6 starts at 27
# Job 15, Task 1 on M9 starts at 27
# Job 15, Task 2 on M3 starts at 28
# Job 15, Task 3 on M4 starts at 28
# Job 15, Task 4 on M7 starts at 28
# Job 15, Task 5 on M8 starts at 28
# Job 1, Task 2 on M9 starts at 29
# Job 1, Task 3 on M2 starts at 30
# Job 1, Task 4 on M5 starts at 30
# Job 1, Task 5 on M3 starts at 31
# Job 6, Task 2 on M4 starts at 31
# Job 6, Task 3 on M8 starts at 31
# Job 6, Task 4 on M9 starts at 31
# Job 6, Task 5 on M1 starts at 32
# Job 20, Task 5 on M10 starts at 32
# Job 4, Task 2 on M2 starts at 33
# Job 17, Task 5 on M4 starts at 33
# Job 4, Task 3 on M8 starts at 34
# Job 4, Task 4 on M10 starts at 34
# Job 4, Task 5 on M2 starts at 35
# Job 8, Task 1 on M4 starts at 35
# Job 8, Task 2 on M9 starts at 35
# Job 8, Task 3 on M4 starts at 36
# Job 8, Task 4 on M8 starts at 36
# Job 8, Task 5 on M6 starts at 37
# Job 11, Task 1 on M1 starts at 38
# Job 11, Task 2 on M7 starts at 38
# Job 11, Task 3 on M1 starts at 39
# Job 11, Task 4 on M10 starts at 39
# Job 11, Task 5 on M2 starts at 40
# Job 19, Task 1 on M3 starts at 40
# Job 9, Task 3 on M5 starts at 40
# Job 9, Task 4 on M6 starts at 40
# Job 9, Task 5 on M7 starts at 40
# Job 16, Task 5 on M9 starts at 40
# Job 7, Task 2 on M3 starts at 41
# Job 10, Task 2 on M5 starts at 41
# Job 10, Task 3 on M9 starts at 41
# Job 10, Task 4 on M3 starts at 42
# Job 10, Task 5 on M5 starts at 42
# Job 13, Task 2 on M4 starts at 43
# Job 13, Task 3 on M9 starts at 43
# Job 13, Task 4 on M10 starts at 43
# Job 13, Task 5 on M4 starts at 44
# Job 14, Task 4 on M6 starts at 44
# Job 19, Task 2 on M2 starts at 45
# Job 19, Task 3 on M6 starts at 45
# Job 19, Task 4 on M1 starts at 46
# Job 19, Task 5 on M2 starts at 46
# Job 7, Task 3 on M8 starts at 46
# Job 7, Task 4 on M8 starts at 47
# Job 7, Task 5 on M5 starts at 48
# Job 14, Task 5 on M7 starts at 48
#
# Testing Problem Instance 7
# Generation 1, Best Fitness: 395.0
# Generation 2, Best Fitness: 321.0
# Generation 3, Best Fitness: 321.0
# Generation 4, Best Fitness: 321.0
# Generation 5, Best Fitness: 321.0
# Generation 6, Best Fitness: 321.0
# Generation 7, Best Fitness: 321.0
# Generation 8, Best Fitness: 321.0
# Generation 9, Best Fitness: 321.0
# Generation 10, Best Fitness: 321.0
# Generation 11, Best Fitness: 321.0
# Generation 12, Best Fitness: 321.0
# Generation 13, Best Fitness: 321.0
# Generation 14, Best Fitness: 321.0
# Generation 15, Best Fitness: 321.0
# Generation 16, Best Fitness: 321.0
# Generation 17, Best Fitness: 321.0
# Generation 18, Best Fitness: 321.0
# Generation 19, Best Fitness: 321.0
# Generation 20, Best Fitness: 321.0
# Generation 21, Best Fitness: 321.0
# Generation 22, Best Fitness: 321.0
# Generation 23, Best Fitness: 321.0
# Generation 24, Best Fitness: 321.0
# Generation 25, Best Fitness: 321.0
# Generation 26, Best Fitness: 321.0
# Generation 27, Best Fitness: 321.0
# Generation 28, Best Fitness: 321.0
# Generation 29, Best Fitness: 321.0
# Generation 30, Best Fitness: 321.0
# Generation 31, Best Fitness: 321.0
# Generation 32, Best Fitness: 321.0
# Generation 33, Best Fitness: 321.0
# Generation 34, Best Fitness: 321.0
# Generation 35, Best Fitness: 321.0
# Generation 36, Best Fitness: 321.0
# Generation 37, Best Fitness: 321.0
# Generation 38, Best Fitness: 321.0
# Generation 39, Best Fitness: 321.0
# Generation 40, Best Fitness: 321.0
# Generation 41, Best Fitness: 321.0
# Generation 42, Best Fitness: 321.0
# Generation 43, Best Fitness: 321.0
# Generation 44, Best Fitness: 321.0
# Generation 45, Best Fitness: 321.0
# Generation 46, Best Fitness: 321.0
# Generation 47, Best Fitness: 321.0
# Generation 48, Best Fitness: 321.0
# Generation 49, Best Fitness: 321.0
# Generation 50, Best Fitness: 321.0
# Generation 51, Best Fitness: 321.0
# Generation 52, Best Fitness: 321.0
# Generation 53, Best Fitness: 321.0
# Generation 54, Best Fitness: 321.0
# Generation 55, Best Fitness: 321.0
# Generation 56, Best Fitness: 321.0
# Generation 57, Best Fitness: 321.0
# Generation 58, Best Fitness: 321.0
# Generation 59, Best Fitness: 321.0
# Generation 60, Best Fitness: 321.0
# Generation 61, Best Fitness: 321.0
# Generation 62, Best Fitness: 321.0
# Generation 63, Best Fitness: 321.0
# Generation 64, Best Fitness: 321.0
# Generation 65, Best Fitness: 321.0
# Generation 66, Best Fitness: 321.0
# Generation 67, Best Fitness: 321.0
# Generation 68, Best Fitness: 321.0
# Generation 69, Best Fitness: 321.0
# Generation 70, Best Fitness: 321.0
# Generation 71, Best Fitness: 321.0
# Generation 72, Best Fitness: 321.0
# Generation 73, Best Fitness: 321.0
# Generation 74, Best Fitness: 321.0
# Generation 75, Best Fitness: 321.0
# Generation 76, Best Fitness: 321.0
# Generation 77, Best Fitness: 321.0
# Generation 78, Best Fitness: 321.0
# Generation 79, Best Fitness: 321.0
# Generation 80, Best Fitness: 321.0
# Generation 81, Best Fitness: 321.0
# Generation 82, Best Fitness: 321.0
# Generation 83, Best Fitness: 321.0
# Generation 84, Best Fitness: 321.0
# Generation 85, Best Fitness: 321.0
# Generation 86, Best Fitness: 321.0
# Generation 87, Best Fitness: 321.0
# Generation 88, Best Fitness: 321.0
# Generation 89, Best Fitness: 321.0
# Generation 90, Best Fitness: 321.0
# Generation 91, Best Fitness: 321.0
# Generation 92, Best Fitness: 321.0
# Generation 93, Best Fitness: 321.0
# Generation 94, Best Fitness: 321.0
# Generation 95, Best Fitness: 321.0
# Generation 96, Best Fitness: 321.0
# Generation 97, Best Fitness: 321.0
# Generation 98, Best Fitness: 321.0
# Generation 99, Best Fitness: 321.0
# Generation 100, Best Fitness: 321.0
# Best Schedule (Timeline):
# Job 2, Task 1 on M1 starts at 0
# Job 9, Task 1 on M2 starts at 0
# Job 5, Task 1 on M3 starts at 0
# Job 15, Task 1 on M4 starts at 0
# Job 16, Task 1 on M5 starts at 0
# Job 17, Task 1 on M6 starts at 0
# Job 2, Task 2 on M7 starts at 0
# Job 5, Task 2 on M8 starts at 0
# Job 16, Task 2 on M9 starts at 0
# Job 16, Task 3 on M10 starts at 0
# Job 7, Task 1 on M4 starts at 8
# Job 14, Task 1 on M5 starts at 8
# Job 20, Task 1 on M6 starts at 8
# Job 3, Task 1 on M7 starts at 8
# Job 18, Task 1 on M8 starts at 8
# Job 2, Task 3 on M9 starts at 8
# Job 8, Task 1 on M10 starts at 8
# Job 8, Task 2 on M3 starts at 9
# Job 5, Task 3 on M1 starts at 10
# Job 14, Task 2 on M2 starts at 10
# Job 6, Task 1 on M10 starts at 13
# Job 10, Task 1 on M7 starts at 14
# Job 15, Task 2 on M8 starts at 14
# Job 15, Task 3 on M9 starts at 14
# Job 15, Task 4 on M1 starts at 15
# Job 15, Task 5 on M2 starts at 15
# Job 17, Task 2 on M4 starts at 15
# Job 16, Task 4 on M5 starts at 15
# Job 16, Task 5 on M6 starts at 15
# Job 18, Task 2 on M3 starts at 16
# Job 18, Task 3 on M10 starts at 17
# Job 18, Task 4 on M7 starts at 18
# Job 17, Task 3 on M8 starts at 18
# Job 17, Task 4 on M4 starts at 19
# Job 9, Task 2 on M5 starts at 19
# Job 9, Task 3 on M9 starts at 19
# Job 9, Task 4 on M3 starts at 20
# Job 9, Task 5 on M2 starts at 21
# Job 1, Task 1 on M1 starts at 22
# Job 1, Task 2 on M5 starts at 22
# Job 1, Task 3 on M8 starts at 22
# Job 12, Task 1 on M7 starts at 23
# Job 12, Task 2 on M1 starts at 24
# Job 13, Task 1 on M6 starts at 25
# Job 13, Task 2 on M7 starts at 25
# Job 13, Task 3 on M2 starts at 26
# Job 13, Task 4 on M3 starts at 26
# Job 13, Task 5 on M10 starts at 26
# Job 19, Task 1 on M6 starts at 27
# Job 19, Task 2 on M4 starts at 28
# Job 19, Task 3 on M8 starts at 28
# Job 20, Task 2 on M6 starts at 29
# Job 20, Task 3 on M9 starts at 29
# Job 20, Task 4 on M1 starts at 30
# Job 3, Task 2 on M5 starts at 30
# Job 3, Task 3 on M6 starts at 31
# Job 3, Task 4 on M5 starts at 32
# Job 3, Task 5 on M7 starts at 32
# Job 14, Task 3 on M2 starts at 34
# Job 14, Task 4 on M4 starts at 34
# Job 14, Task 5 on M6 starts at 34
# Job 17, Task 5 on M8 starts at 34
# Job 19, Task 4 on M2 starts at 36
# Job 19, Task 5 on M3 starts at 36
# Job 4, Task 1 on M7 starts at 36
# Job 11, Task 1 on M8 starts at 36
# Job 7, Task 2 on M10 starts at 36
# Job 7, Task 3 on M4 starts at 37
# Job 7, Task 4 on M7 starts at 37
# Job 7, Task 5 on M8 starts at 37
# Job 2, Task 4 on M10 starts at 37
# Job 2, Task 5 on M2 starts at 38
# Job 8, Task 3 on M10 starts at 38
# Job 8, Task 4 on M1 starts at 39
# Job 5, Task 4 on M3 starts at 39
# Job 5, Task 5 on M9 starts at 39
# Job 6, Task 2 on M10 starts at 39
# Job 6, Task 3 on M3 starts at 40
# Job 6, Task 4 on M10 starts at 40
# Job 6, Task 5 on M2 starts at 41
# Job 10, Task 2 on M9 starts at 41
# Job 18, Task 5 on M5 starts at 42
# Job 1, Task 4 on M9 starts at 42
# Job 1, Task 5 on M5 starts at 43
# Job 12, Task 3 on M9 starts at 43
# Job 12, Task 4 on M6 starts at 44
# Job 12, Task 5 on M9 starts at 44
# Job 20, Task 5 on M4 starts at 45
# Job 4, Task 2 on M5 starts at 45
# Job 4, Task 3 on M7 starts at 45
# Job 4, Task 4 on M4 starts at 46
# Job 4, Task 5 on M5 starts at 46
# ...
# Job 10, Task 2 on M10 starts at 19
# Job 10, Task 3 on M3 starts at 21
# Job 10, Task 4 on M4 starts at 21
# Job 10, Task 5 on M8 starts at 21
# Job 15, Task 1 on M9 starts at 22
# Job 7, Task 3 on M1 starts at 24
# Job 7, Task 4 on M5 starts at 24
# Job 7, Task 5 on M7 starts at 24
# Job 8, Task 3 on M10 starts at 24
# Job 16, Task 2 on M9 starts at 25
# Job 16, Task 3 on M2 starts at 26
# Job 16, Task 4 on M3 starts at 26
# Job 16, Task 5 on M6 starts at 26
# Job 17, Task 1 on M8 starts at 26
# Job 17, Task 2 on M1 starts at 27
# Job 17, Task 3 on M4 starts at 27
# Job 17, Task 4 on M10 starts at 27
# Job 17, Task 5 on M5 starts at 28
# Job 20, Task 1 on M8 starts at 28
# Job 14, Task 3 on M9 starts at 28
# Job 14, Task 4 on M7 starts at 30
# Job 14, Task 5 on M8 starts at 30
# Job 3, Task 2 on M9 starts at 30
# Job 12, Task 2 on M10 starts at 30
# Job 12, Task 3 on M1 starts at 31
# Job 12, Task 4 on M5 starts at 32
# Job 12, Task 5 on M9 starts at 32
# Job 11, Task 2 on M10 starts at 32
# Job 13, Task 3 on M4 starts at 33
# Job 11, Task 3 on M6 starts at 34
# Job 4, Task 1 on M10 starts at 34
# Job 4, Task 2 on M1 starts at 35
# Job 4, Task 3 on M3 starts at 35
# Job 4, Task 4 on M4 starts at 35
# Job 4, Task 5 on M7 starts at 35
# Job 5, Task 1 on M8 starts at 35
# Job 5, Task 2 on M10 starts at 35
# Job 5, Task 3 on M2 starts at 36
# Job 5, Task 4 on M6 starts at 36
# Job 5, Task 5 on M8 starts at 36
# Job 18, Task 1 on M3 starts at 37
# Job 18, Task 2 on M3 starts at 38
# Job 18, Task 3 on M5 starts at 38
# Job 18, Task 4 on M2 starts at 39
# Job 18, Task 5 on M9 starts at 39
# Job 9, Task 3 on M1 starts at 40
# Job 9, Task 4 on M5 starts at 40
# Job 9, Task 5 on M1 starts at 41
# Job 15, Task 2 on M4 starts at 41
# Job 15, Task 3 on M4 starts at 42
# Job 8, Task 4 on M10 starts at 42
# Job 8, Task 5 on M6 starts at 43
# Job 20, Task 2 on M8 starts at 43
# Job 3, Task 3 on M10 starts at 43
# Job 3, Task 4 on M4 starts at 44
# Job 3, Task 5 on M7 starts at 44
# Job 13, Task 4 on M8 starts at 44
# Job 13, Task 5 on M10 starts at 44
# Job 11, Task 4 on M8 starts at 45
# Job 11, Task 5 on M7 starts at 46
# Job 15, Task 4 on M8 starts at 46
# Job 15, Task 5 on M3 starts at 47
# Job 20, Task 3 on M8 starts at 47
# Job 20, Task 4 on M1 starts at 48
# Job 20, Task 5 on M2 starts at 48
#
# Testing Problem Instance 9
# Generation 1, Best Fitness: 420.0
# Generation 2, Best Fitness: 290.0
# Generation 3, Best Fitness: 290.0
# Generation 4, Best Fitness: 290.0
# Generation 5, Best Fitness: 290.0
# Generation 6, Best Fitness: 290.0
# Generation 7, Best Fitness: 290.0
# Generation 8, Best Fitness: 290.0
# Generation 9, Best Fitness: 290.0
# Generation 10, Best Fitness: 290.0
# Generation 11, Best Fitness: 290.0
# Generation 12, Best Fitness: 290.0
# Generation 13, Best Fitness: 290.0
# Generation 14, Best Fitness: 290.0
# Generation 15, Best Fitness: 290.0
# Generation 96, Best Fitness: 290.0
# Generation 97, Best Fitness: 290.0
# Generation 98, Best Fitness: 290.0
# Generation 99, Best Fitness: 290.0
# Generation 100, Best Fitness: 290.0
# Best Schedule (Timeline):
# Job 3, Task 1 on M1 starts at 0
# Job 5, Task 1 on M2 starts at 0
# Job 6, Task 1 on M3 starts at 0
# Job 17, Task 1 on M4 starts at 0
# Job 5, Task 2 on M5 starts at 0
# Job 2, Task 1 on M6 starts at 0
# Job 8, Task 1 on M7 starts at 0
# Job 5, Task 3 on M8 starts at 0
# Job 2, Task 2 on M9 starts at 0
# Job 5, Task 4 on M10 starts at 0
# Job 2, Task 3 on M6 starts at 8
# Job 2, Task 4 on M7 starts at 8
# Job 1, Task 1 on M8 starts at 8
# Job 4, Task 1 on M9 starts at 8
# Job 9, Task 1 on M10 starts at 8
# Job 3, Task 2 on M1 starts at 9
# Job 3, Task 3 on M2 starts at 9
# Job 2, Task 5 on M3 starts at 9
# Job 11, Task 1 on M4 starts at 9
# Job 19, Task 1 on M5 starts at 9
# Job 9, Task 2 on M4 starts at 15
# Job 18, Task 1 on M5 starts at 15
# Job 18, Task 2 on M8 starts at 15
# Job 5, Task 5 on M9 starts at 15
# Job 18, Task 3 on M10 starts at 15
# Job 18, Task 4 on M1 starts at 16
# Job 18, Task 5 on M3 starts at 16
# Job 16, Task 1 on M6 starts at 16
# Job 16, Task 2 on M7 starts at 17
# Job 16, Task 3 on M2 starts at 19
# Job 16, Task 4 on M5 starts at 20
# Job 8, Task 2 on M6 starts at 20
# Job 8, Task 3 on M9 starts at 20
# Job 1, Task 2 on M10 starts at 20
# Job 4, Task 2 on M1 starts at 21
# Job 4, Task 3 on M4 starts at 21
# Job 4, Task 4 on M8 starts at 22
# Job 7, Task 1 on M3 starts at 23
# Job 7, Task 2 on M6 starts at 24
# Job 7, Task 3 on M10 starts at 24
# Job 12, Task 1 on M1 starts at 25
# Job 12, Task 2 on M7 starts at 25
# Job 12, Task 3 on M2 starts at 26
# Job 13, Task 1 on M3 starts at 26
# Job 13, Task 2 on M5 starts at 27
# Job 13, Task 3 on M1 starts at 28
# Job 13, Task 4 on M3 starts at 29
# Job 20, Task 1 on M8 starts at 29
# Job 20, Task 2 on M9 starts at 29
# Job 17, Task 2 on M2 starts at 30
# Job 17, Task 3 on M4 starts at 30
# Job 3, Task 4 on M5 starts at 31
# Job 3, Task 5 on M6 starts at 31
# Job 9, Task 3 on M8 starts at 32
# Job 9, Task 4 on M1 starts at 33
# Job 9, Task 5 on M2 starts at 33
# Job 8, Task 4 on M10 starts at 33
# Job 8, Task 5 on M4 starts at 34
# Job 1, Task 3 on M5 starts at 34
# Job 1, Task 4 on M7 starts at 34
# Job 13, Task 5 on M8 starts at 35
# Job 1, Task 5 on M10 starts at 36
# Job 14, Task 1 on M2 starts at 37
# Job 14, Task 2 on M3 starts at 37
# Job 14, Task 3 on M5 starts at 37
# Job 14, Task 4 on M4 starts at 38
# Job 14, Task 5 on M6 starts at 38
# Job 6, Task 2 on M8 starts at 38
# Job 19, Task 2 on M9 starts at 38
# Job 19, Task 3 on M2 starts at 39
# Job 19, Task 4 on M10 starts at 39
# Job 19, Task 5 on M1 starts at 40
# Job 12, Task 4 on M8 starts at 40
# Job 12, Task 5 on M9 starts at 40
# Job 10, Task 1 on M5 starts at 41
# Job 10, Task 2 on M5 starts at 42
# Job 10, Task 3 on M8 starts at 42
# Job 10, Task 4 on M2 starts at 43
# Job 10, Task 5 on M3 starts at 43
# Job 15, Task 1 on M1 starts at 44
# Job 15, Task 2 on M7 starts at 44
# Job 15, Task 3 on M10 starts at 44
# Job 15, Task 4 on M1 starts at 45
# Job 15, Task 5 on M6 starts at 45
# Job 11, Task 2 on M5 starts at 46
# Job 11, Task 3 on M10 starts at 46
# Job 11, Task 4 on M5 starts at 47
# Job 11, Task 5 on M7 starts at 47
# Job 16, Task 5 on M9 starts at 47
# Job 4, Task 5 on M4 starts at 48
# Job 7, Task 4 on M9 starts at 48
# Job 7, Task 5 on M10 starts at 48
# Job 20, Task 3 on M4 starts at 49
# Job 20, Task 4 on M9 starts at 49
# Job 20, Task 5 on M4 starts at 50
# Job 17, Task 4 on M8 starts at 50
# Job 17, Task 5 on M5 starts at 51
# Job 6, Task 3 on M8 starts at 51
# Job 6, Task 4 on M2 starts at 52
# Job 6, Task 5 on M8 starts at 52
#
# Testing Problem Instance 10
# Generation 1, Best Fitness: 391.0
# Generation 2, Best Fitness: 317.0
# Generation 3, Best Fitness: 317.0
# Generation 4, Best Fitness: 317.0
# Generation 5, Best Fitness: 317.0
# Generation 6, Best Fitness: 317.0
# Generation 7, Best Fitness: 317.0
# Generation 8, Best Fitness: 317.0
# Generation 9, Best Fitness: 317.0
# Generation 10, Best Fitness: 317.0
# Generation 11, Best Fitness: 317.0
# Generation 12, Best Fitness: 317.0
# Generation 13, Best Fitness: 317.0
# Generation 14, Best Fitness: 317.0
# Generation 15, Best Fitness: 317.0
# Generation 16, Best Fitness: 317.0
# Generation 17, Best Fitness: 317.0
# Generation 18, Best Fitness: 317.0
# Generation 19, Best Fitness: 317.0
# Generation 20, Best Fitness: 317.0
# Generation 21, Best Fitness: 317.0
# Generation 22, Best Fitness: 317.0
# Generation 23, Best Fitness: 317.0
# Generation 24, Best Fitness: 317.0
# Generation 25, Best Fitness: 317.0
# Generation 26, Best Fitness: 317.0
# Generation 27, Best Fitness: 317.0
# Generation 28, Best Fitness: 317.0
# Generation 29, Best Fitness: 317.0
# Generation 30, Best Fitness: 317.0
# Generation 31, Best Fitness: 317.0
# Generation 32, Best Fitness: 317.0
# Generation 33, Best Fitness: 317.0
# Generation 34, Best Fitness: 317.0
# Generation 35, Best Fitness: 317.0
# Generation 36, Best Fitness: 317.0
# Generation 37, Best Fitness: 317.0
# Generation 38, Best Fitness: 317.0
# Generation 39, Best Fitness: 317.0
# Generation 40, Best Fitness: 317.0
# Generation 41, Best Fitness: 317.0
# Generation 42, Best Fitness: 317.0
# Generation 43, Best Fitness: 317.0
# Generation 44, Best Fitness: 317.0
# Generation 45, Best Fitness: 317.0
# Job 12, Task 3 on M9 starts at 14
# Job 12, Task 4 on M3 starts at 15
# Job 12, Task 5 on M4 starts at 15
# Job 18, Task 1 on M5 starts at 15
# Job 20, Task 1 on M6 starts at 15
# Job 20, Task 2 on M10 starts at 15
# Job 20, Task 3 on M2 starts at 16
# Job 15, Task 3 on M1 starts at 18
# Job 11, Task 2 on M7 starts at 19
# Job 5, Task 1 on M5 starts at 20
# Job 5, Task 2 on M6 starts at 20
# Job 19, Task 1 on M8 starts at 21
# Job 16, Task 2 on M4 starts at 22
# Job 16, Task 3 on M9 starts at 22
# Job 16, Task 4 on M1 starts at 23
# Job 16, Task 5 on M2 starts at 23
# Job 7, Task 3 on M10 starts at 23
# Job 7, Task 4 on M5 starts at 24
# Job 7, Task 5 on M7 starts at 24
# Job 2, Task 2 on M3 starts at 25
# Job 2, Task 3 on M6 starts at 25
# Job 2, Task 4 on M8 starts at 25
# Job 1, Task 1 on M4 starts at 26
# Job 1, Task 2 on M10 starts at 27
# Job 4, Task 1 on M9 starts at 28
# Job 4, Task 2 on M3 starts at 29
# Job 17, Task 2 on M4 starts at 29
# Job 13, Task 2 on M6 starts at 29
# Job 14, Task 5 on M1 starts at 31
# Job 2, Task 5 on M5 starts at 31
# Job 1, Task 3 on M9 starts at 31
# Job 1, Task 4 on M2 starts at 32
# Job 17, Task 3 on M4 starts at 32
# Job 1, Task 5 on M6 starts at 32
# Job 6, Task 1 on M8 starts at 32
# Job 6, Task 2 on M3 starts at 33
# Job 6, Task 3 on M1 starts at 34
# Job 6, Task 4 on M5 starts at 34
# Job 6, Task 5 on M7 starts at 34
# Job 3, Task 2 on M8 starts at 34
# Job 3, Task 3 on M9 starts at 34
# Job 3, Task 4 on M10 starts at 34
# Job 3, Task 5 on M4 starts at 35
# Job 18, Task 2 on M6 starts at 35
# Job 18, Task 3 on M8 starts at 36
# Job 18, Task 4 on M3 starts at 37
# Job 20, Task 4 on M6 starts at 37
# Job 20, Task 5 on M7 starts at 37
# Job 19, Task 2 on M1 starts at 39
# Job 4, Task 3 on M6 starts at 39
# Job 4, Task 4 on M2 starts at 40
# Job 4, Task 5 on M1 starts at 41
# Job 8, Task 1 on M3 starts at 41
# Job 8, Task 2 on M6 starts at 41
# Job 8, Task 3 on M3 starts at 42
# Job 8, Task 4 on M1 starts at 43
# Job 8, Task 5 on M4 starts at 43
# Job 9, Task 2 on M5 starts at 44
# Job 9, Task 3 on M9 starts at 44
# Job 9, Task 4 on M10 starts at 44
# Job 9, Task 5 on M1 starts at 45
# Job 15, Task 4 on M5 starts at 45
# Job 15, Task 5 on M8 starts at 45
# Job 11, Task 3 on M3 starts at 46
# Job 11, Task 4 on M5 starts at 46
# Job 11, Task 5 on M2 starts at 47
# Job 5, Task 3 on M3 starts at 47
# Job 5, Task 4 on M7 starts at 47
# Job 5, Task 5 on M9 starts at 47
# Job 13, Task 3 on M3 starts at 48
# Job 13, Task 4 on M2 starts at 49
# Job 13, Task 5 on M3 starts at 49
# Job 17, Task 4 on M4 starts at 49
# Job 17, Task 5 on M4 starts at 50
# Job 18, Task 5 on M6 starts at 50
# Job 19, Task 3 on M5 starts at 51
# Job 19, Task 4 on M6 starts at 51
# Job 19, Task 5 on M10 starts at 51

# %% [markdown]
# # Task 4(a): Test the Genetic Algorithm (GA) without Q-Learning.

# %%
import random

# Example problem data generator
def generate_problem_instance(num_jobs, num_machines, num_tasks_per_job):
    jobs = [{"tasks": [random.randint(1, 10) for _ in range(num_tasks_per_job)]} for _ in range(num_jobs)]
    machines = [f"M{i+1}" for i in range(num_machines)]
    return jobs, machines

# Generate larger problem instances
problem_instances = [generate_problem_instance(20, 10, 5) for _ in range(10)]

# Transport times between machines (constant for simplicity)
transport_times = {
    (f"M{i+1}", f"M{j+1}"): random.randint(1, 5) if i != j else 0
    for i in range(10) for j in range(10)
}

# Encode solution
def encode_solution(jobs, machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    for job_id in range(len(jobs)):
        job_end_time = 0
        previous_machine = None
        for task_id in range(len(jobs[job_id]["tasks"])):
            machine_id = random.choice(machines)  # Introduce randomness for diversity
            transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
            start_time = max(machine_end_times[machine_id], job_end_time + transport_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration
            machine_end_times[machine_id] = end_time
            job_end_time = end_time
            previous_machine = machine_id
            chromosome.append((job_id, task_id, machine_id, start_time))
    return chromosome

# Fitness function
def calculate_fitness(chromosome, jobs, machines):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * len(jobs)
    penalty = 0

    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        job_id = int(job_id)  # Ensure job_id is an integer
        task_id = int(task_id)  # Ensure task_id is an integer
        task_duration = jobs[job_id]["tasks"][task_id]
        if start_time < machine_end_times[machine_id]:
            penalty += (machine_end_times[machine_id] - start_time) * 10

        transport_time = 0
        if i > 0:
            _, _, prev_machine, _ = chromosome[i - 1]
            transport_time = transport_times.get((prev_machine, machine_id), 0)
        end_time = start_time + task_duration + transport_time
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)

    makespan = max(job_end_times)
    fitness = makespan + penalty * 0.1  # Scale down penalty
    return fitness

# Repair solution
def repair_solution(jobs, machines):
    tasks_to_schedule = [{"job_id": i, "task_id": 0, "processing_time": job["tasks"][0]}
                         for i, job in enumerate(jobs)]
    machine_end_times = {machine: 0 for machine in machines}
    schedule = []

    while tasks_to_schedule:
        task_to_schedule = max(tasks_to_schedule, key=lambda x: x["processing_time"])
        tasks_to_schedule.remove(task_to_schedule)

        job_id = task_to_schedule["job_id"]
        task_id = task_to_schedule["task_id"]

        machine = min(machines, key=lambda m: machine_end_times[m])
        start_time = machine_end_times[machine]
        processing_time = task_to_schedule["processing_time"]
        end_time = start_time + processing_time

        machine_end_times[machine] = end_time
        schedule.append((job_id, task_id, machine, start_time))

        if task_id + 1 < len(jobs[job_id]["tasks"]):
            tasks_to_schedule.append({
                "job_id": job_id,
                "task_id": task_id + 1,
                "processing_time": jobs[job_id]["tasks"][task_id + 1]
            })

    return schedule

# Genetic algorithm
def genetic_algorithm(jobs, machines, population_size=50, generations=100):
    population = [encode_solution(jobs, machines) for _ in range(population_size)]
    mutation_rate = 0.2  # Higher initial mutation rate to promote exploration

    for generation in range(generations):
        fitness_values = [calculate_fitness(ind, jobs, machines) for ind in population]
        best_fitness = min(fitness_values)
        best_solution = population[fitness_values.index(best_fitness)]
        average_fitness = sum(fitness_values) / len(fitness_values)
        print(f"Generation {generation + 1}: Best Fitness = {best_fitness}, Average Fitness = {average_fitness:.2f}")

        # Selection: Tournament selection
        selected_parents = random.choices(population, k=len(population))

        # Crossover
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            crossover_point1 = random.randint(1, len(parent1) // 2)
            crossover_point2 = random.randint(len(parent1) // 2, len(parent1) - 1)
            child1 = parent1[:crossover_point1] + parent2[crossover_point1:crossover_point2] + parent1[crossover_point2:]
            child2 = parent2[:crossover_point1] + parent1[crossover_point1:crossover_point2] + parent2[crossover_point2:]
            offspring.append(repair_solution(jobs, machines))
            offspring.append(repair_solution(jobs, machines))

        # Mutation
        for i in range(len(offspring)):
            if random.random() < mutation_rate:  # Dynamic mutation rate
                idx = random.randint(0, len(offspring[i]) - 1)
                job_id, task_id, _, start_time = offspring[i][idx]
                new_machine = random.choice(machines)
                offspring[i][idx] = (int(job_id), int(task_id), new_machine, start_time)
                offspring[i] = repair_solution(jobs, machines)

        # Update population
        population = offspring

        # Adjust mutation rate dynamically
        mutation_rate = max(0.05, mutation_rate * 0.95)  # Gradually reduce mutation rate

    return best_solution

# Example usage for problem instances
for idx, (jobs, machines) in enumerate(problem_instances):
    print(f"\nTesting Problem Instance {idx + 1}")
    best_solution = genetic_algorithm(jobs, machines, population_size=50, generations=100)
    print("Best Schedule (Timeline):")
    for job_id, task_id, machine_id, start_time in best_solution:
        print(f"Job {job_id + 1}, Task {task_id + 1} on {machine_id} starts at {start_time}")
# Out:
# Testing Problem Instance 1
# Generation 1: Best Fitness = 422.0, Average Fitness = 519.72
# Generation 2: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 3: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 4: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 5: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 6: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 7: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 8: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 9: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 10: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 11: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 12: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 13: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 14: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 15: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 16: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 17: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 18: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 19: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 20: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 21: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 22: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 23: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 24: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 25: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 26: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 27: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 28: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 29: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 30: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 31: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 32: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 33: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 34: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 35: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 36: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 37: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 38: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 39: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 40: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 41: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 42: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 43: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 44: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 45: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 46: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 47: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 48: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 49: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 50: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 51: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 52: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 53: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 54: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 55: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 56: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 57: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 58: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 59: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 60: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 61: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 62: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 63: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 64: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 65: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 66: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 67: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 68: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 69: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 70: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 71: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 72: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 73: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 74: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 75: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 76: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 77: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 78: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 79: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 80: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 81: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 82: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 83: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 84: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 85: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 86: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 87: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 88: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 89: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 90: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 91: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 92: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 93: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 94: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 95: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 96: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 97: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 98: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 99: Best Fitness = 347.0, Average Fitness = 347.00
# Generation 100: Best Fitness = 347.0, Average Fitness = 347.00
# Best Schedule (Timeline):
# Job 9, Task 1 on M1 starts at 0
# Job 13, Task 1 on M2 starts at 0
# Job 14, Task 1 on M3 starts at 0
# Job 17, Task 1 on M4 starts at 0
# Job 9, Task 2 on M5 starts at 0
# Job 4, Task 1 on M6 starts at 0
# Job 4, Task 2 on M7 starts at 0
# Job 12, Task 1 on M8 starts at 0
# Job 18, Task 1 on M9 starts at 0
# Job 18, Task 2 on M10 starts at 0
# Job 18, Task 3 on M6 starts at 6
# Job 20, Task 1 on M8 starts at 6
# Job 1, Task 1 on M9 starts at 6
# Job 1, Task 2 on M4 starts at 8
# Job 1, Task 3 on M5 starts at 8
# Job 11, Task 1 on M2 starts at 9
# Job 14, Task 2 on M3 starts at 9
# Job 14, Task 3 on M7 starts at 9
# Job 9, Task 3 on M10 starts at 9
# Job 11, Task 2 on M1 starts at 10
# Job 11, Task 3 on M9 starts at 11
# Job 11, Task 4 on M8 starts at 12
# Job 2, Task 1 on M2 starts at 14
# Job 2, Task 2 on M3 starts at 14
# Job 10, Task 1 on M6 starts at 14
# Job 10, Task 2 on M10 starts at 14
# Job 10, Task 3 on M1 starts at 15
# Job 4, Task 3 on M4 starts at 15
# Job 4, Task 4 on M5 starts at 17
# Job 4, Task 5 on M2 starts at 18
# Job 12, Task 2 on M6 starts at 18
# Job 12, Task 3 on M7 starts at 18
# Job 2, Task 3 on M4 starts at 19
# Job 2, Task 4 on M9 starts at 20
# Job 2, Task 5 on M1 starts at 21
# Job 5, Task 1 on M8 starts at 21
# Job 5, Task 2 on M10 starts at 21
# Job 5, Task 3 on M6 starts at 22
# Job 5, Task 4 on M2 starts at 23
# Job 15, Task 1 on M4 starts at 23
# Job 15, Task 2 on M7 starts at 23
# Job 15, Task 3 on M3 starts at 24
# Job 6, Task 1 on M8 starts at 24
# Job 6, Task 2 on M9 starts at 25
# Job 6, Task 3 on M4 starts at 26
# Job 6, Task 4 on M5 starts at 26
# Job 6, Task 5 on M8 starts at 26
# Job 8, Task 1 on M10 starts at 26
# Job 8, Task 2 on M7 starts at 27
# Job 16, Task 1 on M10 starts at 28
# Job 16, Task 2 on M1 starts at 29
# Job 16, Task 3 on M2 starts at 29
# Job 16, Task 4 on M6 starts at 30
# Job 16, Task 5 on M10 starts at 30
# Job 19, Task 1 on M4 starts at 31
# Job 13, Task 2 on M7 starts at 32
# Job 13, Task 3 on M3 starts at 33
# Job 13, Task 4 on M4 starts at 33
# Job 13, Task 5 on M8 starts at 33
# Job 17, Task 2 on M2 starts at 34
# Job 17, Task 3 on M7 starts at 34
# Job 17, Task 4 on M9 starts at 34
# Job 14, Task 4 on M2 starts at 36
# Job 14, Task 5 on M5 starts at 36
# Job 11, Task 5 on M8 starts at 36
# Job 10, Task 4 on M1 starts at 37
# Job 10, Task 5 on M6 starts at 37
# Job 5, Task 5 on M2 starts at 38
# Job 8, Task 3 on M8 starts at 38
# Job 8, Task 4 on M1 starts at 39
# Job 8, Task 5 on M2 starts at 40
# Job 19, Task 2 on M8 starts at 40
# Job 19, Task 3 on M10 starts at 40
# Job 19, Task 4 on M4 starts at 41
# Job 19, Task 5 on M7 starts at 41
# Job 17, Task 5 on M3 starts at 42
# Job 3, Task 1 on M5 starts at 42
# Job 3, Task 2 on M8 starts at 42
# Job 7, Task 1 on M5 starts at 43
# Job 7, Task 2 on M9 starts at 43
# Job 7, Task 3 on M1 starts at 44
# Job 7, Task 4 on M3 starts at 44
# Job 7, Task 5 on M5 starts at 44
# Job 18, Task 4 on M2 starts at 47
# Job 18, Task 5 on M6 starts at 47
# Job 20, Task 2 on M10 starts at 47
# Job 20, Task 3 on M2 starts at 48
# Job 20, Task 4 on M7 starts at 48
# Job 20, Task 5 on M10 starts at 48
# Job 1, Task 4 on M8 starts at 49
# Job 1, Task 5 on M8 starts at 50
# Job 9, Task 4 on M1 starts at 51
# Job 12, Task 4 on M4 starts at 51
# Job 12, Task 5 on M6 starts at 51
# Job 15, Task 4 on M1 starts at 52
# Job 15, Task 5 on M3 starts at 52
# Job 3, Task 3 on M4 starts at 52
# Job 3, Task 4 on M9 starts at 52
# Job 3, Task 5 on M10 starts at 52
# Job 9, Task 5 on M1 starts at 53
#
# Testing Problem Instance 2
# Generation 1: Best Fitness = 435.0, Average Fitness = 520.46
# Generation 2: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 3: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 4: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 5: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 6: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 7: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 8: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 9: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 10: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 11: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 12: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 13: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 14: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 15: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 16: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 17: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 18: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 19: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 20: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 21: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 22: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 23: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 24: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 25: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 26: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 27: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 28: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 29: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 30: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 31: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 32: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 33: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 34: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 35: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 36: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 37: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 38: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 39: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 40: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 41: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 42: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 43: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 44: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 45: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 46: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 47: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 48: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 49: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 50: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 51: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 52: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 53: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 54: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 55: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 56: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 57: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 58: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 59: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 60: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 61: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 62: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 63: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 64: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 65: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 66: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 67: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 68: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 69: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 70: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 71: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 72: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 73: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 74: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 75: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 76: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 77: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 78: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 79: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 80: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 81: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 82: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 83: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 84: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 85: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 86: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 87: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 88: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 89: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 90: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 91: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 92: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 93: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 94: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 95: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 96: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 97: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 98: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 99: Best Fitness = 331.0, Average Fitness = 331.00
# Generation 100: Best Fitness = 331.0, Average Fitness = 331.00
# Best Schedule (Timeline):
# Job 19, Task 1 on M1 starts at 0
# Job 17, Task 1 on M2 starts at 0
# Job 6, Task 1 on M3 starts at 0
# Job 10, Task 1 on M4 starts at 0
# Job 13, Task 1 on M5 starts at 0
# Job 15, Task 1 on M6 starts at 0
# Job 17, Task 2 on M7 starts at 0
# Job 2, Task 1 on M8 starts at 0
# Job 14, Task 1 on M9 starts at 0
# Job 14, Task 2 on M10 starts at 0
# Job 19, Task 2 on M8 starts at 7
# Job 13, Task 2 on M9 starts at 7
# Job 2, Task 2 on M3 starts at 8
# Job 13, Task 3 on M4 starts at 8
# Job 3, Task 1 on M5 starts at 8
# Job 7, Task 1 on M6 starts at 8
# Job 16, Task 1 on M7 starts at 8
# Job 10, Task 2 on M2 starts at 9
# Job 10, Task 3 on M10 starts at 9
# Job 10, Task 4 on M1 starts at 10
# Job 10, Task 5 on M5 starts at 14
# Job 17, Task 3 on M6 starts at 14
# Job 14, Task 3 on M7 starts at 14
# Job 13, Task 4 on M8 starts at 14
# Job 13, Task 5 on M9 starts at 14
# Job 3, Task 2 on M2 starts at 15
# Job 7, Task 2 on M3 starts at 15
# Job 7, Task 3 on M4 starts at 15
# Job 6, Task 2 on M1 starts at 17
# Job 6, Task 3 on M10 starts at 19
# Job 6, Task 4 on M6 starts at 20
# Job 19, Task 3 on M7 starts at 20
# Job 17, Task 4 on M8 starts at 20
# Job 9, Task 1 on M2 starts at 21
# Job 15, Task 2 on M3 starts at 21
# Job 15, Task 3 on M9 starts at 21
# Job 2, Task 3 on M1 starts at 22
# Job 2, Task 4 on M4 starts at 22
# Job 1, Task 1 on M5 starts at 23
# Job 1, Task 2 on M2 starts at 25
# Job 18, Task 1 on M3 starts at 25
# Job 3, Task 3 on M7 starts at 25
# Job 3, Task 4 on M8 starts at 25
# Job 3, Task 5 on M10 starts at 25
# Job 19, Task 4 on M1 starts at 26
# Job 19, Task 5 on M5 starts at 26
# Job 17, Task 5 on M6 starts at 27
# Job 2, Task 5 on M3 starts at 28
# Job 4, Task 1 on M7 starts at 28
# Job 4, Task 2 on M1 starts at 29
# Job 4, Task 3 on M2 starts at 30
# Job 4, Task 4 on M6 starts at 30
# Job 4, Task 5 on M7 starts at 30
# Job 5, Task 1 on M9 starts at 30
# Job 8, Task 1 on M3 starts at 31
# Job 11, Task 1 on M4 starts at 31
# Job 12, Task 1 on M5 starts at 31
# Job 12, Task 2 on M8 starts at 32
# Job 12, Task 3 on M9 starts at 32
# Job 12, Task 4 on M3 starts at 33
# Job 12, Task 5 on M4 starts at 33
# Job 16, Task 2 on M5 starts at 33
# Job 16, Task 3 on M10 starts at 33
# Job 14, Task 4 on M5 starts at 35
# Job 14, Task 5 on M9 starts at 35
# Job 7, Task 4 on M6 starts at 36
# Job 7, Task 5 on M7 starts at 36
# Job 9, Task 2 on M5 starts at 37
# Job 9, Task 3 on M2 starts at 38
# Job 9, Task 4 on M6 starts at 38
# Job 9, Task 5 on M1 starts at 39
# Job 11, Task 2 on M5 starts at 39
# Job 20, Task 1 on M5 starts at 41
# Job 20, Task 2 on M8 starts at 41
# Job 20, Task 3 on M4 starts at 42
# Job 20, Task 4 on M5 starts at 42
# Job 20, Task 5 on M7 starts at 42
# Job 6, Task 5 on M9 starts at 42
# Job 15, Task 4 on M2 starts at 43
# Job 15, Task 5 on M3 starts at 43
# Job 1, Task 3 on M9 starts at 43
# Job 1, Task 4 on M10 starts at 43
# Job 1, Task 5 on M2 starts at 44
# Job 18, Task 2 on M8 starts at 44
# Job 18, Task 3 on M9 starts at 44
# Job 5, Task 2 on M1 starts at 45
# Job 5, Task 3 on M7 starts at 45
# Job 5, Task 4 on M8 starts at 45
# Job 5, Task 5 on M1 starts at 46
# Job 8, Task 2 on M6 starts at 46
# Job 16, Task 4 on M9 starts at 46
# Job 16, Task 5 on M6 starts at 47
# Job 11, Task 3 on M9 starts at 47
# Job 11, Task 4 on M2 starts at 48
# Job 11, Task 5 on M9 starts at 48
# Job 18, Task 4 on M1 starts at 50
# Job 18, Task 5 on M5 starts at 50
# Job 8, Task 3 on M8 starts at 50
# Job 8, Task 4 on M1 starts at 51
# Job 8, Task 5 on M8 starts at 51
#
# Testing Problem Instance 3
# Generation 1: Best Fitness = 444.0, Average Fitness = 523.88
# Generation 2: Best Fitness = 336.0, Average Fitness = 336.00
# Generation
# Job 17, Task 3 on M10 starts at 27
# Job 17, Task 4 on M3 starts at 29
# Job 3, Task 5 on M6 starts at 29
# Job 11, Task 3 on M7 starts at 29
# Job 11, Task 4 on M1 starts at 30
# Job 1, Task 4 on M2 starts at 30
# Job 1, Task 5 on M4 starts at 31
# Job 11, Task 5 on M8 starts at 31
# Job 14, Task 1 on M6 starts at 32
# Job 14, Task 2 on M7 starts at 32
# Job 14, Task 3 on M2 starts at 33
# Job 16, Task 1 on M5 starts at 33
# Job 16, Task 2 on M3 starts at 34
# Job 16, Task 3 on M6 starts at 34
# Job 16, Task 4 on M8 starts at 34
# Job 13, Task 5 on M5 starts at 35
# Job 20, Task 3 on M9 starts at 36
# Job 20, Task 4 on M1 starts at 37
# Job 20, Task 5 on M5 starts at 37
# Job 12, Task 5 on M10 starts at 37
# Job 14, Task 4 on M9 starts at 38
# Job 14, Task 5 on M3 starts at 39
# Job 2, Task 1 on M4 starts at 39
# Job 2, Task 2 on M10 starts at 39
# Job 2, Task 3 on M4 starts at 40
# Job 2, Task 4 on M7 starts at 40
# Job 2, Task 5 on M8 starts at 40
# Job 5, Task 1 on M9 starts at 40
# Job 5, Task 2 on M9 starts at 41
# Job 5, Task 3 on M2 starts at 42
# Job 5, Task 4 on M5 starts at 43
# Job 5, Task 5 on M6 starts at 43
# Job 10, Task 1 on M9 starts at 43
# Job 10, Task 2 on M1 starts at 44
# Job 10, Task 3 on M2 starts at 44
# Job 10, Task 4 on M9 starts at 44
# Job 10, Task 5 on M3 starts at 45
# Job 4, Task 2 on M8 starts at 45
# Job 4, Task 3 on M10 starts at 45
# Job 4, Task 4 on M4 starts at 46
# Job 4, Task 5 on M8 starts at 46
# Job 9, Task 3 on M1 starts at 48
# Job 9, Task 4 on M1 starts at 49
# Job 9, Task 5 on M3 starts at 49
# Job 15, Task 2 on M5 starts at 49
# Job 15, Task 3 on M5 starts at 50
# Job 15, Task 4 on M7 starts at 50
# Job 15, Task 5 on M2 starts at 51
# Job 18, Task 5 on M3 starts at 51
# Job 8, Task 4 on M6 starts at 51
# Job 8, Task 5 on M3 starts at 52
# Job 17, Task 5 on M6 starts at 52
# Job 16, Task 5 on M7 starts at 52
#
# Testing Problem Instance 4
# Generation 1: Best Fitness = 387.0, Average Fitness = 479.20
# Generation 2: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 3: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 4: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 5: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 6: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 7: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 8: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 9: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 10: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 11: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 12: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 13: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 14: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 15: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 16: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 17: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 18: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 19: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 20: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 21: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 22: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 23: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 24: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 25: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 26: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 27: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 28: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 29: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 30: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 31: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 32: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 33: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 34: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 35: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 36: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 37: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 38: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 39: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 40: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 41: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 42: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 43: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 44: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 45: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 46: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 47: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 48: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 49: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 50: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 51: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 52: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 53: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 54: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 55: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 56: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 57: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 58: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 59: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 60: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 61: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 62: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 63: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 64: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 65: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 66: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 67: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 68: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 69: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 70: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 71: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 72: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 73: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 74: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 75: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 76: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 77: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 78: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 79: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 80: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 81: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 82: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 83: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 84: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 85: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 86: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 87: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 88: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 89: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 90: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 91: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 92: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 93: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 94: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 95: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 96: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 97: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 98: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 99: Best Fitness = 337.0, Average Fitness = 337.00
# Generation 100: Best Fitness = 337.0, Average Fitness = 337.00
# Best Schedule (Timeline):
# Job 1, Task 1 on M1 starts at 0
# Job 10, Task 1 on M2 starts at 0
# Job 7, Task 1 on M3 starts at 0
# Job 9, Task 1 on M4 starts at 0
# Job 7, Task 2 on M5 starts at 0
# Job 9, Task 2 on M6 starts at 0
# Job 7, Task 3 on M7 starts at 0
# Job 7, Task 4 on M8 starts at 0
# Job 8, Task 1 on M9 starts at 0
# Job 8, Task 2 on M10 starts at 0
# Job 7, Task 5 on M9 starts at 6
# Job 8, Task 3 on M7 starts at 7
# Job 2, Task 1 on M8 starts at 7
# Job 2, Task 2 on M6 starts at 8
# Job 3, Task 1 on M3 starts at 9
# Job 11, Task 1 on M4 starts at 9
# Job 11, Task 2 on M5 starts at 9
# Job 18, Task 1 on M10 starts at 9
# Job 18, Task 2 on M1 starts at 10
# Job 5, Task 1 on M2 starts at 10
# Job 5, Task 2 on M8 starts at 12
# Job 5, Task 3 on M9 starts at 12
# Job 5, Task 4 on M7 starts at 13
# Job 14, Task 1 on M2 starts at 14
# Job 20, Task 1 on M3 starts at 14
# Job 11, Task 3 on M4 starts at 14
# Job 6, Task 1 on M10 starts at 14
# Job 6, Task 2 on M5 starts at 15
# Job 6, Task 3 on M10 starts at 17
# Job 6, Task 4 on M1 starts at 18
# Job 19, Task 1 on M2 starts at 18
# Job 19, Task 2 on M3 starts at 18
# Job 19, Task 3 on M4 starts at 18
# Job 1, Task 2 on M6 starts at 18
# Job 1, Task 3 on M8 starts at 18
# Job 1, Task 4 on M2 starts at 21
# Job 1, Task 5 on M5 starts at 21
# Job 9, Task 3 on M6 starts at 21
# Job 3, Task 2 on M7 starts at 21
# Job 3, Task 3 on M9 starts at 21
# Job 11, Task 4 on M10 starts at 23
# Job 6, Task 5 on M3 starts at 24
# Job 4, Task 1 on M6 starts at 24
# Job 4, Task 2 on M7 starts at 24
# Job 12, Task 1 on M2 starts at 25
# Job 12, Task 2 on M8 starts at 25
# Job 16, Task 1 on M4 starts at 26
# Job 16, Task 2 on M5 starts at 26
# Job 16, Task 3 on M6 starts at 26
# Job 16, Task 4 on M10 starts at 26
# Job 16, Task 5 on M2 starts at 27
# Job 8, Task 4 on M3 starts at 27
# Job 8, Task 5 on M1 starts at 28
# Job 18, Task 3 on M4 starts at 28
# Job 5, Task 5 on M3 starts at 29
# Job 14, Task 2 on M6 starts at 29
# Job 14, Task 3 on M9 starts at 29
# Job 14, Task 4 on M4 starts at 30
# Job 3, Task 4 on M7 starts at 30
# Job 3, Task 5 on M8 starts at 30
# Job 4, Task 3 on M10 starts at 30
# Job 12, Task 3 on M2 starts at 31
# Job 12, Task 4 on M3 starts at 31
# Job 12, Task 5 on M5 starts at 31
# Job 4, Task 4 on M6 starts at 31
# Job 4, Task 5 on M7 starts at 32
# Job 13, Task 1 on M9 starts at 32
# Job 13, Task 2 on M10 starts at 32
# Job 13, Task 3 on M1 starts at 33
# Job 13, Task 4 on M2 starts at 33
# Job 13, Task 5 on M6 starts at 33
# Job 15, Task 1 on M9 starts at 33
# Job 15, Task 2 on M3 starts at 34
# Job 15, Task 3 on M4 starts at 34
# Job 15, Task 4 on M9 starts at 34
# Job 15, Task 5 on M2 starts at 36
# Job 17, Task 1 on M1 starts at 37
# Job 17, Task 2 on M5 starts at 37
# Job 17, Task 3 on M6 starts at 37
# Job 10, Task 2 on M9 starts at 37
# Job 10, Task 3 on M1 starts at 38
# Job 10, Task 4 on M8 starts at 38
# Job 10, Task 5 on M9 starts at 38
# Job 2, Task 3 on M3 starts at 39
# Job 2, Task 4 on M10 starts at 39
# Job 2, Task 5 on M3 starts at 40
# Job 20, Task 2 on M4 starts at 40
# Job 20, Task 3 on M7 starts at 40
# Job 19, Task 4 on M9 starts at 40
# Job 19, Task 5 on M4 starts at 41
# Job 9, Task 4 on M9 starts at 41
# Job 11, Task 5 on M9 starts at 42
# Job 18, Task 4 on M8 starts at 43
# Job 18, Task 5 on M9 starts at 43
# Job 14, Task 5 on M6 starts at 44
# Job 17, Task 4 on M8 starts at 44
# Job 17, Task 5 on M1 starts at 45
# Job 20, Task 4 on M2 starts at 45
# Job 20, Task 5 on M6 starts at 45
# Job 9, Task 5 on M8 starts at 45
#
# Testing Problem Instance 5
# Generation 1: Best Fitness = 428.0, Average Fitness = 539.26
# Generation 2: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 3: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 4: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 5: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 6: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 7: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 8: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 9: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 10: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 11: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 12: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 13: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 14: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 15: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 16: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 17: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 18: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 19: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 20: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 21: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 22: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 23: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 24: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 25: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 26: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 27: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 28: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 29: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 30: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 31: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 32: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 33: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 34: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 35: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 36: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 37: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 38: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 39: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 40: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 41: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 42: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 43: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 44: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 45: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 46: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 47: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 48: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 49: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 50: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 51: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 52: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 53: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 54: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 55: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 56: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 57: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 58: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 59: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 60: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 61: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 62: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 63: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 64: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 65: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 66: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 67: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 68: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 69: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 70: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 71: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 72: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 73: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 74: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 75: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 76: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 77: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 78: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 79: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 80: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 81: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 82: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 83: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 84: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 85: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 86: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 87: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 88: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 89: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 90: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 91: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 92: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 93: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 94: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 95: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 96: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 97: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 98: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 99: Best Fitness = 332.0, Average Fitness = 332.00
# Generation 100: Best Fitness = 332.0, Average Fitness = 332.00
# Best Schedule (Timeline):
# Job 15, Task 1 on M1 starts at 0
# Job 16, Task 1 on M2 starts at 0
# Job 18, Task 1 on M3 starts at 0
# Job 6, Task 1 on M4 starts at 0
# Job 7, Task 1 on M5 starts at 0
# Job 10, Task 1 on M6 starts at 0
# Job 13, Task 1 on M7 starts at 0
# Job 14, Task 1 on M8 starts at 0
# Job 19, Task 1 on M9 starts at 0
# Job 15, Task 2 on M10 starts at 0
# Job 15, Task 3 on M4 starts at 9
# Job 15, Task 4 on M5 starts at 9
# Job 9, Task 1 on M6 starts at 9
# Job 11, Task 1 on M7 starts at 9
# Job 11, Task 2 on M8 starts at 9
# Job 13, Task 2 on M9 starts at 9
# Job 13, Task 3 on M10 starts at 9
# Job 19, Task 2 on M1 starts at 10
# Job 10, Task 2 on M2 starts at 10
# Job 14, Task 2 on M3 starts at 10
# Job 14, Task 3 on M2 starts at 17
# Job 19, Task 3 on M3 starts at 17
# Job 3, Task 1 on M6 starts at 17
# Job 3, Task 2 on M7 starts at 17
# Job 3, Task 3 on M9 starts at 17
# Job 4, Task 1 on M1 starts at 18
# Job 4, Task 2 on M5 starts at 18
# Job 4, Task 3 on M10 starts at 18
# Job 20, Task 1 on M4 starts at 19
# Job 20, Task 2 on M8 starts at 19
# Job 5, Task 1 on M6 starts at 23
# Job 5, Task 2 on M1 starts at 24
# Job 6, Task 2 on M3 starts at 24
# Job 11, Task 3 on M9 starts at 24
# Job 11, Task 4 on M4 starts at 25
# Job 11, Task 5 on M2 starts at 26
# Job 10, Task 3 on M10 starts at 26
# Job 10, Task 4 on M7 starts at 27
# Job 10, Task 5 on M8 starts at 27
# Job 6, Task 3 on M5 starts at 28
# Job 8, Task 1 on M6 starts at 28
# Job 8, Task 2 on M3 starts at 29
# Job 16, Task 2 on M9 starts at 29
# Job 9, Task 2 on M10 starts at 31
# Job 9, Task 3 on M1 starts at 32
# Job 9, Task 4 on M6 starts at 32
# Job 9, Task 5 on M2 starts at 33
# Job 20, Task 3 on M5 starts at 33
# Job 20, Task 4 on M8 starts at 33
# Job 8, Task 3 on M9 starts at 33
# Job 8, Task 4 on M4 starts at 35
# Job 7, Task 2 on M10 starts at 35
# Job 7, Task 3 on M7 starts at 36
# Job 7, Task 4 on M1 starts at 37
# Job 15, Task 5 on M5 starts at 37
# Job 14, Task 4 on M9 starts at 37
# Job 19, Task 4 on M6 starts at 38
# Job 19, Task 5 on M10 starts at 38
# Job 3, Task 4 on M3 starts at 39
# Job 4, Task 4 on M8 starts at 39
# Job 5, Task 3 on M2 starts at 40
# Job 5, Task 4 on M4 starts at 40
# Job 5, Task 5 on M5 starts at 40
# Job 6, Task 4 on M7 starts at 40
# Job 6, Task 5 on M9 starts at 40
# Job 3, Task 5 on M6 starts at 41
# Job 1, Task 1 on M3 starts at 42
# Job 1, Task 2 on M8 starts at 42
# Job 1, Task 3 on M2 starts at 43
# Job 1, Task 4 on M7 starts at 43
# Job 1, Task 5 on M3 starts at 44
# Job 17, Task 1 on M6 starts at 44
# Job 17, Task 2 on M8 starts at 45
# Job 17, Task 3 on M1 starts at 46
# Job 13, Task 4 on M6 starts at 46
# Job 13, Task 5 on M10 starts at 46
# Job 16, Task 3 on M5 starts at 47
# Job 16, Task 4 on M7 starts at 47
# Job 20, Task 5 on M6 starts at 48
# Job 16, Task 5 on M4 starts at 49
# Job 2, Task 1 on M5 starts at 49
# Job 2, Task 2 on M2 starts at 50
# Job 2, Task 3 on M5 starts at 50
# Job 2, Task 4 on M6 starts at 50
# Job 2, Task 5 on M9 starts at 50
# Job 12, Task 1 on M4 starts at 51
# Job 12, Task 2 on M4 starts at 52
# Job 12, Task 3 on M3 starts at 53
# Job 12, Task 4 on M6 starts at 53
# Job 12, Task 5 on M7 starts at 53
# Job 18, Task 2 on M8 starts at 53
# Job 18, Task 3 on M4 starts at 54
# Job 18, Task 4 on M8 starts at 54
# Job 18, Task 5 on M7 starts at 55
# Job 8, Task 5 on M1 starts at 56
# Job 7, Task 5 on M4 starts at 56
# Job 14, Task 5 on M8 starts at 56
# Job 4, Task 5 on M9 starts at 56
# Job 17, Task 4 on M10 starts at 56
# Job 17, Task 5 on M1 starts at 57
#
# Testing Problem Instance 6
# ...
# Generation 53: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 54: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 55: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 56: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 57: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 58: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 59: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 60: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 61: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 62: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 63: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 64: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 65: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 66: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 67: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 68: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 69: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 70: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 71: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 72: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 73: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 74: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 75: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 76: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 77: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 78: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 79: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 80: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 81: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 82: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 83: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 84: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 85: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 86: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 87: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 88: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 89: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 90: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 91: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 92: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 93: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 94: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 95: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 96: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 97: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 98: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 99: Best Fitness = 344.0, Average Fitness = 344.00
# Generation 100: Best Fitness = 344.0, Average Fitness = 344.00
# Best Schedule (Timeline):
# Job 1, Task 1 on M1 starts at 0
# Job 3, Task 1 on M2 starts at 0
# Job 9, Task 1 on M3 starts at 0
# Job 1, Task 2 on M4 starts at 0
# Job 4, Task 1 on M5 starts at 0
# Job 11, Task 1 on M6 starts at 0
# Job 16, Task 1 on M7 starts at 0
# Job 19, Task 1 on M8 starts at 0
# Job 2, Task 1 on M9 starts at 0
# Job 14, Task 1 on M10 starts at 0
# Job 18, Task 1 on M9 starts at 8
# Job 1, Task 3 on M10 starts at 8
# Job 4, Task 2 on M5 starts at 9
# Job 8, Task 1 on M6 starts at 9
# Job 13, Task 1 on M7 starts at 9
# Job 13, Task 2 on M8 starts at 9
# Job 13, Task 3 on M1 starts at 10
# Job 15, Task 1 on M2 starts at 10
# Job 3, Task 2 on M3 starts at 10
# Job 19, Task 2 on M4 starts at 10
# Job 14, Task 2 on M6 starts at 16
# Job 14, Task 3 on M7 starts at 16
# Job 14, Task 4 on M9 starts at 16
# Job 14, Task 5 on M10 starts at 16
# Job 6, Task 1 on M2 starts at 17
# Job 6, Task 2 on M3 starts at 17
# Job 7, Task 1 on M4 starts at 17
# Job 7, Task 2 on M5 starts at 17
# Job 2, Task 2 on M8 starts at 18
# Job 2, Task 3 on M1 starts at 19
# Job 18, Task 2 on M2 starts at 23
# Job 7, Task 3 on M4 starts at 23
# Job 20, Task 1 on M6 starts at 23
# Job 11, Task 2 on M7 starts at 23
# Job 11, Task 3 on M9 starts at 23
# Job 7, Task 4 on M3 starts at 24
# Job 12, Task 1 on M8 starts at 24
# Job 17, Task 1 on M5 starts at 26
# Job 16, Task 2 on M10 starts at 26
# Job 15, Task 2 on M6 starts at 28
# Job 15, Task 3 on M7 starts at 28
# Job 15, Task 4 on M8 starts at 28
# Job 16, Task 3 on M1 starts at 29
# Job 9, Task 2 on M2 starts at 29
# Job 13, Task 4 on M3 starts at 29
# Job 13, Task 5 on M4 starts at 29
# Job 19, Task 3 on M9 starts at 29
# Job 7, Task 5 on M5 starts at 30
# Job 15, Task 5 on M10 starts at 30
# Job 9, Task 3 on M2 starts at 32
# Job 9, Task 4 on M3 starts at 32
# Job 9, Task 5 on M6 starts at 32
# Job 4, Task 3 on M9 starts at 32
# Job 4, Task 4 on M1 starts at 33
# Job 3, Task 3 on M5 starts at 33
# Job 3, Task 4 on M8 starts at 33
# Job 3, Task 5 on M10 starts at 33
# Job 6, Task 3 on M7 starts at 34
# Job 6, Task 4 on M9 starts at 34
# Job 6, Task 5 on M2 starts at 35
# Job 2, Task 4 on M5 starts at 35
# Job 2, Task 5 on M1 starts at 36
# Job 18, Task 3 on M7 starts at 36
# Job 18, Task 4 on M5 starts at 37
# Job 20, Task 2 on M4 starts at 38
# Job 20, Task 3 on M7 starts at 38
# Job 11, Task 4 on M8 starts at 39
# Job 11, Task 5 on M3 starts at 40
# Job 4, Task 5 on M4 starts at 40
# Job 18, Task 5 on M6 starts at 41
# Job 20, Task 4 on M8 starts at 41
# Job 20, Task 5 on M9 starts at 41
# Job 5, Task 1 on M10 starts at 41
# Job 5, Task 2 on M4 starts at 42
# Job 5, Task 3 on M5 starts at 42
# Job 5, Task 4 on M10 starts at 42
# Job 5, Task 5 on M1 starts at 43
# Job 10, Task 1 on M3 starts at 43
# Job 10, Task 2 on M6 starts at 43
# Job 10, Task 3 on M8 starts at 43
# Job 10, Task 4 on M2 starts at 44
# Job 1, Task 4 on M3 starts at 44
# Job 8, Task 2 on M7 starts at 44
# Job 8, Task 3 on M3 starts at 45
# Job 8, Task 4 on M7 starts at 45
# Job 8, Task 5 on M8 starts at 46
# Job 12, Task 2 on M9 starts at 46
# Job 12, Task 3 on M1 starts at 47
# Job 12, Task 4 on M3 starts at 47
# Job 12, Task 5 on M5 starts at 47
# Job 17, Task 2 on M7 starts at 47
# Job 17, Task 3 on M9 starts at 47
# Job 17, Task 4 on M7 starts at 48
# Job 17, Task 5 on M10 starts at 48
# Job 16, Task 4 on M1 starts at 51
# Job 16, Task 5 on M2 starts at 51
# Job 19, Task 4 on M4 starts at 51
# Job 19, Task 5 on M1 starts at 52
# Job 10, Task 5 on M4 starts at 52
# Job 1, Task 5 on M6 starts at 52
#
# Testing Problem Instance 10
# Generation 1: Best Fitness = 387.0, Average Fitness = 500.72
# Generation 2: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 3: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 4: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 5: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 6: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 7: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 8: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 9: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 10: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 11: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 12: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 13: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 14: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 15: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 16: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 17: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 18: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 19: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 20: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 21: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 22: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 23: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 24: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 25: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 26: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 27: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 28: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 29: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 30: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 31: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 32: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 33: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 34: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 35: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 36: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 37: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 38: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 39: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 40: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 41: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 42: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 43: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 44: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 45: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 46: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 47: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 48: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 49: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 50: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 51: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 52: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 53: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 54: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 55: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 56: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 57: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 58: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 59: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 60: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 61: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 62: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 63: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 64: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 65: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 66: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 67: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 68: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 69: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 70: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 71: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 72: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 73: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 74: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 75: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 76: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 77: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 78: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 79: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 80: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 81: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 82: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 83: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 84: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 85: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 86: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 87: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 88: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 89: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 90: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 91: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 92: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 93: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 94: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 95: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 96: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 97: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 98: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 99: Best Fitness = 336.0, Average Fitness = 336.00
# Generation 100: Best Fitness = 336.0, Average Fitness = 336.00
# Best Schedule (Timeline):
# Job 17, Task 1 on M1 starts at 0
# Job 20, Task 1 on M2 starts at 0
# Job 6, Task 1 on M3 starts at 0
# Job 7, Task 1 on M4 starts at 0
# Job 8, Task 1 on M5 starts at 0
# Job 9, Task 1 on M6 starts at 0
# Job 16, Task 1 on M7 starts at 0
# Job 6, Task 2 on M8 starts at 0
# Job 7, Task 2 on M9 starts at 0
# Job 7, Task 3 on M10 starts at 0
# Job 7, Task 4 on M9 starts at 7
# Job 2, Task 1 on M10 starts at 7
# Job 5, Task 1 on M8 starts at 8
# Job 7, Task 5 on M3 starts at 9
# Job 5, Task 2 on M4 starts at 9
# Job 5, Task 3 on M5 starts at 9
# Job 3, Task 1 on M6 starts at 9
# Job 10, Task 1 on M7 starts at 9
# Job 11, Task 1 on M1 starts at 10
# Job 15, Task 1 on M2 starts at 10
# Job 15, Task 2 on M10 starts at 13
# Job 9, Task 2 on M6 starts at 14
# Job 15, Task 3 on M7 starts at 14
# Job 15, Task 4 on M8 starts at 14
# Job 9, Task 3 on M9 starts at 14
# Job 9, Task 4 on M1 starts at 15
# Job 14, Task 1 on M2 starts at 15
# Job 14, Task 2 on M3 starts at 15
# Job 14, Task 3 on M4 starts at 15
# Job 14, Task 4 on M5 starts at 18
# Job 14, Task 5 on M2 starts at 19
# Job 20, Task 2 on M6 starts at 19
# Job 8, Task 2 on M7 starts at 19
# Job 10, Task 2 on M9 starts at 19
# Job 4, Task 1 on M4 starts at 20
# Job 13, Task 1 on M10 starts at 20
# Job 18, Task 1 on M1 starts at 21
# Job 16, Task 2 on M8 starts at 22
# Job 16, Task 3 on M4 starts at 23
# Job 16, Task 4 on M6 starts at 23
# Job 16, Task 5 on M7 starts at 23
# Job 6, Task 3 on M9 starts at 23
# Job 11, Task 2 on M10 starts at 23
# Job 20, Task 3 on M1 starts at 24
# Job 4, Task 2 on M3 starts at 25
# Job 4, Task 3 on M8 starts at 25
# Job 4, Task 4 on M5 starts at 26
# Job 18, Task 2 on M9 starts at 26
# Job 18, Task 3 on M10 starts at 26
# Job 18, Task 4 on M1 starts at 27
# Job 12, Task 1 on M2 starts at 28
# Job 12, Task 2 on M3 starts at 28
# Job 12, Task 3 on M4 starts at 28
# Job 12, Task 4 on M9 starts at 29
# Job 2, Task 2 on M2 starts at 30
# Job 2, Task 3 on M6 starts at 30
# Job 2, Task 4 on M7 starts at 31
# Job 2, Task 5 on M8 starts at 31
# Job 3, Task 2 on M2 starts at 32
# Job 9, Task 5 on M2 starts at 34
# Job 10, Task 3 on M5 starts at 34
# Job 6, Task 4 on M8 starts at 34
# Job 11, Task 3 on M3 starts at 35
# Job 6, Task 5 on M6 starts at 35
# Job 11, Task 4 on M9 starts at 35
# Job 11, Task 5 on M2 starts at 36
# Job 1, Task 1 on M5 starts at 36
# Job 1, Task 2 on M8 starts at 36
# Job 1, Task 3 on M10 starts at 36
# Job 1, Task 4 on M1 starts at 37
# Job 1, Task 5 on M3 starts at 37
# Job 19, Task 1 on M5 starts at 37
# Job 19, Task 2 on M6 starts at 37
# Job 19, Task 3 on M9 starts at 37
# Job 19, Task 4 on M4 starts at 38
# Job 17, Task 2 on M5 starts at 38
# Job 17, Task 3 on M7 starts at 38
# Job 17, Task 4 on M5 starts at 39
# Job 17, Task 5 on M9 starts at 39
# Job 5, Task 4 on M4 starts at 40
# Job 5, Task 5 on M4 starts at 41
# Job 15, Task 5 on M10 starts at 41
# Job 8, Task 3 on M10 starts at 42
# Job 8, Task 4 on M5 starts at 43
# Job 8, Task 5 on M10 starts at 43
# Job 13, Task 2 on M2 starts at 44
# Job 13, Task 3 on M3 starts at 44
# Job 13, Task 4 on M6 starts at 44
# Job 13, Task 5 on M1 starts at 45
# Job 20, Task 4 on M2 starts at 45
# Job 20, Task 5 on M8 starts at 45
# Job 4, Task 5 on M2 starts at 46
# Job 18, Task 5 on M7 starts at 46
# Job 12, Task 5 on M2 starts at 47
# Job 3, Task 3 on M5 starts at 47
# Job 3, Task 4 on M7 starts at 47
# Job 3, Task 5 on M1 starts at 48
# Job 10, Task 4 on M2 starts at 48
# Job 10, Task 5 on M5 starts at 48
# Job 19, Task 5 on M2 starts at 49

# %% [markdown]
# # Task 4(b): Test the Genetic Algorithm (GA) with Q-Learning.

# %%
import random
import numpy as np

# Example problem data generator
def generate_problem_instance(num_jobs, num_machines, num_tasks_per_job):
    jobs = [{"tasks": [random.randint(1, 10) for _ in range(num_tasks_per_job)]} for _ in range(num_jobs)]
    machines = [f"M{i+1}" for i in range(num_machines)]
    return jobs, machines

# Generate larger problem instances
problem_instances = [generate_problem_instance(20, 10, 5) for _ in range(10)]

# Transport times between machines (constant for simplicity)
transport_times = {
    (f"M{i+1}", f"M{j+1}"): random.randint(1, 5) if i != j else 0
    for i in range(10) for j in range(10)
}

# Q-Learning Parameters
ALPHA = 0.1  # Learning rate
GAMMA = 0.9  # Discount factor
EPSILON = 0.2  # Exploration rate

# Encode solution
def encode_solution(jobs, machines):
    chromosome = []
    machine_end_times = {machine: 0 for machine in machines}
    for job_id in range(len(jobs)):
        job_end_time = 0
        previous_machine = None
        for task_id in range(len(jobs[job_id]["tasks"])):
            machine_id = random.choice(machines)  # Introduce randomness for diversity
            transport_time = transport_times.get((previous_machine, machine_id), 0) if previous_machine else 0
            start_time = max(machine_end_times[machine_id], job_end_time + transport_time)
            task_duration = jobs[job_id]["tasks"][task_id]
            end_time = start_time + task_duration
            machine_end_times[machine_id] = end_time
            job_end_time = end_time
            previous_machine = machine_id
            chromosome.append((job_id, task_id, machine_id, start_time))
    return chromosome

# Fitness function
def calculate_fitness(chromosome, jobs, machines):
    machine_end_times = {machine: 0 for machine in machines}
    job_end_times = [0] * len(jobs)
    penalty = 0

    for i, (job_id, task_id, machine_id, start_time) in enumerate(chromosome):
        job_id = int(job_id)  # Ensure job_id is an integer
        task_id = int(task_id)  # Ensure task_id is an integer
        task_duration = jobs[job_id]["tasks"][task_id]
        if start_time < machine_end_times[machine_id]:
            penalty += (machine_end_times[machine_id] - start_time) * 10

        transport_time = 0
        if i > 0:
            _, _, prev_machine, _ = chromosome[i - 1]
            transport_time = transport_times.get((prev_machine, machine_id), 0)
        end_time = start_time + task_duration + transport_time
        job_end_times[job_id] = max(job_end_times[job_id], end_time)
        machine_end_times[machine_id] = max(machine_end_times[machine_id], end_time)

    makespan = max(job_end_times)
    fitness = makespan + penalty * 0.1  # Scale down penalty
    return fitness

# Q-Learning-based Repair Solution
def q_learning_repair(chromosome, jobs, machines):
    q_table = np.zeros((len(jobs), len(machines)))

    for job_id, task_id, machine_id, start_time in chromosome:
        state = job_id
        action = machines.index(machine_id)

        # Q-Learning update
        reward = -calculate_fitness(chromosome, jobs, machines)  # Negative fitness as reward
        next_state = (state + 1) % len(jobs)
        next_action = np.argmax(q_table[next_state]) if random.random() > EPSILON else random.randint(0, len(machines) - 1)

        q_table[state, action] = q_table[state, action] + ALPHA * (
            reward + GAMMA * np.max(q_table[next_state]) - q_table[state, action]
        )

        # Update chromosome with best action from Q-Learning
        machine_id = machines[next_action]
        chromosome[job_id] = (job_id, task_id, machine_id, start_time)

    return chromosome

# Genetic algorithm with Q-Learning
def genetic_algorithm_with_q_learning(jobs, machines, population_size=50, generations=100):
    population = [encode_solution(jobs, machines) for _ in range(population_size)]
    mutation_rate = 0.2  # Higher initial mutation rate to promote exploration

    for generation in range(generations):
        fitness_values = [calculate_fitness(ind, jobs, machines) for ind in population]
        best_fitness = min(fitness_values)
        best_solution = population[fitness_values.index(best_fitness)]
        average_fitness = sum(fitness_values) / len(fitness_values)
        print(f"Generation {generation + 1}: Best Fitness = {best_fitness}, Average Fitness = {average_fitness:.2f}")

        # Apply Q-Learning to improve solutions
        population = [q_learning_repair(ind, jobs, machines) for ind in population]

        # Selection: Tournament selection
        selected_parents = random.choices(population, k=len(population))

        # Crossover
        offspring = []
        for i in range(0, len(selected_parents) - 1, 2):
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            crossover_point1 = random.randint(1, len(parent1) // 2)
            crossover_point2 = random.randint(len(parent1) // 2, len(parent1) - 1)
            child1 = parent1[:crossover_point1] + parent2[crossover_point1:crossover_point2] + parent1[crossover_point2:]
            child2 = parent2[:crossover_point1] + parent1[crossover_point1:crossover_point2] + parent2[crossover_point2:]
            offspring.append(q_learning_repair(child1, jobs, machines))
            offspring.append(q_learning_repair(child2, jobs, machines))

        # Mutation
        for i in range(len(offspring)):
            if random.random() < mutation_rate:  # Dynamic mutation rate
                idx = random.randint(0, len(offspring[i]) - 1)
                job_id, task_id, _, start_time = offspring[i][idx]
                new_machine = random.choice(machines)
                offspring[i][idx] = (int(job_id), int(task_id), new_machine, start_time)
                offspring[i] = q_learning_repair(offspring[i], jobs, machines)

        # Update population
        population = offspring

        # Adjust mutation rate dynamically
        mutation_rate = max(0.05, mutation_rate * 0.95)  # Gradually reduce mutation rate

    return best_solution

# Example usage for problem instances
for idx, (jobs, machines) in enumerate(problem_instances):
    print(f"\nTesting Problem Instance {idx + 1} with Q-Learning")
# Generation 90: Best Fitness = 3793.0, Average Fitness = 4839.14
# Generation 91: Best Fitness = 3425.0, Average Fitness = 4874.10
# Generation 92: Best Fitness = 3372.0, Average Fitness = 4748.46
# Generation 93: Best Fitness = 3764.0, Average Fitness = 4750.04
# Generation 94: Best Fitness = 3041.0, Average Fitness = 4696.86
# Generation 95: Best Fitness = 3321.0, Average Fitness = 4671.40
# Generation 96: Best Fitness = 3358.0, Average Fitness = 4679.94
# Generation 97: Best Fitness = 3487.0, Average Fitness = 4527.36
# Generation 98: Best Fitness = 3427.0, Average Fitness = 4556.26
# Generation 99: Best Fitness = 3444.0, Average Fitness = 4613.28
# Generation 100: Best Fitness = 3502.0, Average Fitness = 4582.84
# Best Schedule (Timeline):
# Job 1, Task 5 on M1 starts at 36
# Job 2, Task 5 on M1 starts at 39
# Job 3, Task 5 on M6 starts at 47
# Job 4, Task 5 on M1 starts at 61
# Job 5, Task 5 on M1 starts at 113
# Job 6, Task 5 on M1 starts at 74
# Job 7, Task 5 on M7 starts at 138
# Job 8, Task 5 on M2 starts at 179
# Job 9, Task 5 on M2 starts at 178
# Job 10, Task 5 on M1 starts at 229
# Job 11, Task 5 on M5 starts at 211
# Job 12, Task 5 on M1 starts at 212
# Job 13, Task 5 on M7 starts at 294
# Job 14, Task 5 on M2 starts at 208
# Job 15, Task 5 on M1 starts at 299
# Job 16, Task 5 on M2 starts at 310
# Job 17, Task 5 on M1 starts at 252
# Job 18, Task 5 on M2 starts at 211
# Job 19, Task 5 on M3 starts at 256
# Job 20, Task 5 on M2 starts at 390
# Job 5, Task 1 on M3 starts at 49
# Job 5, Task 2 on M8 starts at 83
# Job 5, Task 3 on M7 starts at 71
# Job 5, Task 4 on M8 starts at 77
# Job 5, Task 5 on M10 starts at 113
# Job 6, Task 1 on M10 starts at 95
# Job 6, Task 2 on M10 starts at 38
# Job 6, Task 3 on M9 starts at 109
# Job 6, Task 4 on M4 starts at 121
# Job 6, Task 5 on M4 starts at 74
# Job 7, Task 1 on M10 starts at 41
# Job 7, Task 2 on M9 starts at 71
# Job 7, Task 3 on M5 starts at 129
# Job 7, Task 4 on M1 starts at 108
# Job 7, Task 5 on M7 starts at 138
# Job 8, Task 1 on M4 starts at 124
# Job 8, Task 2 on M7 starts at 146
# Job 8, Task 3 on M5 starts at 159
# Job 8, Task 4 on M9 starts at 126
# Job 8, Task 5 on M1 starts at 179
# Job 9, Task 1 on M5 starts at 165
# Job 9, Task 2 on M10 starts at 171
# Job 9, Task 3 on M5 starts at 182
# Job 9, Task 4 on M6 starts at 167
# Job 9, Task 5 on M4 starts at 178
# Job 10, Task 1 on M8 starts at 212
# Job 10, Task 2 on M6 starts at 224
# Job 10, Task 3 on M7 starts at 236
# Job 10, Task 4 on M1 starts at 246
# Job 10, Task 5 on M7 starts at 229
# Job 11, Task 1 on M2 starts at 185
# Job 11, Task 2 on M5 starts at 200
# Job 11, Task 3 on M2 starts at 206
# Job 11, Task 4 on M4 starts at 215
# Job 11, Task 5 on M8 starts at 211
# Job 12, Task 1 on M7 starts at 241
# Job 12, Task 2 on M3 starts at 204
# Job 12, Task 3 on M5 starts at 196
# Job 12, Task 4 on M8 starts at 202
# Job 12, Task 5 on M7 starts at 212
# Job 13, Task 1 on M8 starts at 207
# Job 13, Task 2 on M10 starts at 211
# Job 13, Task 3 on M8 starts at 232
# Job 13, Task 4 on M2 starts at 301
# Job 13, Task 5 on M4 starts at 294
# Job 14, Task 1 on M6 starts at 116
# Job 14, Task 2 on M4 starts at 247
# Job 14, Task 3 on M5 starts at 257
# Job 14, Task 4 on M2 starts at 205
# Job 14, Task 5 on M6 starts at 208
# Job 15, Task 1 on M6 starts at 125
# Job 15, Task 2 on M10 starts at 269
# Job 15, Task 3 on M10 starts at 238
# Job 15, Task 4 on M8 starts at 280
# Job 15, Task 5 on M7 starts at 299
# Job 16, Task 1 on M10 starts at 250
# Job 16, Task 2 on M9 starts at 279
# Job 16, Task 3 on M6 starts at 285
# Job 16, Task 4 on M4 starts at 291
# Job 16, Task 5 on M7 starts at 310
# Job 17, Task 1 on M8 starts at 209
# Job 17, Task 2 on M8 starts at 213
# Job 17, Task 3 on M1 starts at 177
# Job 17, Task 4 on M2 starts at 275
# Job 17, Task 5 on M5 starts at 252
# Job 18, Task 1 on M5 starts at 273
# Job 18, Task 2 on M5 starts at 281
# Job 18, Task 3 on M7 starts at 202
# Job 18, Task 4 on M6 starts at 208
# Job 18, Task 5 on M4 starts at 211
# Job 19, Task 1 on M7 starts at 324
# Job 19, Task 2 on M3 starts at 230
# Job 19, Task 3 on M2 starts at 345
# Job 19, Task 4 on M9 starts at 249
# Job 19, Task 5 on M8 starts at 256
# Job 20, Task 1 on M6 starts at 224
# Job 20, Task 2 on M7 starts at 248
# Job 20, Task 3 on M3 starts at 253
# Job 20, Task 4 on M3 starts at 258
# Job 20, Task 5 on M1 starts at 390
#
# Testing Problem Instance 2 with Q-Learning
# Generation 1: Best Fitness = 420.0, Average Fitness = 502.34
# Generation 2: Best Fitness = 1205.0, Average Fitness = 4526.54
# Generation 3: Best Fitness = 2938.0, Average Fitness = 4894.14
# Generation 4: Best Fitness = 2671.0, Average Fitness = 5019.48
# Generation 5: Best Fitness = 3020.0, Average Fitness = 5228.84
# Generation 6: Best Fitness = 2969.0, Average Fitness = 5452.66
# Generation 7: Best Fitness = 3327.0, Average Fitness = 5520.28
# Generation 8: Best Fitness = 3010.0, Average Fitness = 5254.28
# Generation 9: Best Fitness = 2962.0, Average Fitness = 5478.52
# Generation 10: Best Fitness = 2873.0, Average Fitness = 5517.92
# Generation 11: Best Fitness = 3270.0, Average Fitness = 5537.42
# Generation 12: Best Fitness = 3355.0, Average Fitness = 5703.00
# Generation 13: Best Fitness = 3384.0, Average Fitness = 5501.94
# Generation 14: Best Fitness = 3224.0, Average Fitness = 5543.78
# Generation 15: Best Fitness = 3313.0, Average Fitness = 5902.20
# Generation 16: Best Fitness = 3476.0, Average Fitness = 5663.36
# Generation 17: Best Fitness = 3304.0, Average Fitness = 5694.38
# Job 15, Task 5 on M1 starts at 320
# Job 16, Task 5 on M2 starts at 274
# Job 17, Task 5 on M1 starts at 325
# Job 18, Task 5 on M10 starts at 364
# Job 19, Task 5 on M1 starts at 378
# Job 20, Task 5 on M2 starts at 487
# Job 5, Task 1 on M10 starts at 7
# Job 5, Task 2 on M6 starts at 89
# Job 5, Task 3 on M3 starts at 99
# Job 5, Task 4 on M10 starts at 102
# Job 5, Task 5 on M5 starts at 111
# Job 6, Task 1 on M4 starts at 0
# Job 6, Task 2 on M6 starts at 98
# Job 6, Task 3 on M5 starts at 99
# Job 6, Task 4 on M4 starts at 143
# Job 6, Task 5 on M6 starts at 74
# Job 7, Task 1 on M9 starts at 12
# Job 7, Task 2 on M10 starts at 81
# Job 7, Task 3 on M1 starts at 122
# Job 7, Task 4 on M6 starts at 124
# Job 7, Task 5 on M10 starts at 131
# Job 8, Task 1 on M3 starts at 135
# Job 8, Task 2 on M3 starts at 125
# Job 8, Task 3 on M10 starts at 143
# Job 8, Task 4 on M9 starts at 147
# Job 8, Task 5 on M1 starts at 148
# Job 9, Task 1 on M7 starts at 0
# Job 9, Task 2 on M9 starts at 155
# Job 9, Task 3 on M5 starts at 164
# Job 9, Task 4 on M1 starts at 178
# Job 9, Task 5 on M4 starts at 186
# Job 10, Task 1 on M7 starts at 121
# Job 10, Task 2 on M4 starts at 189
# Job 10, Task 3 on M6 starts at 169
# Job 10, Task 4 on M8 starts at 195
# Job 10, Task 5 on M10 starts at 183
# Job 11, Task 1 on M2 starts at 167
# Job 11, Task 2 on M4 starts at 190
# Job 11, Task 3 on M4 starts at 199
# Job 11, Task 4 on M3 starts at 207
# Job 11, Task 5 on M1 starts at 217
# Job 12, Task 1 on M6 starts at 79
# Job 12, Task 2 on M1 starts at 224
# Job 12, Task 3 on M8 starts at 149
# Job 12, Task 4 on M6 starts at 286
# Job 12, Task 5 on M7 starts at 297
# Job 13, Task 1 on M6 starts at 108
# Job 13, Task 2 on M3 starts at 244
# Job 13, Task 3 on M4 starts at 256
# Job 13, Task 4 on M2 starts at 244
# Job 13, Task 5 on M10 starts at 257
# Job 14, Task 1 on M1 starts at 215
# Job 14, Task 2 on M10 starts at 260
# Job 14, Task 3 on M9 starts at 274
# Job 14, Task 4 on M3 starts at 284
# Job 14, Task 5 on M9 starts at 289
# Job 15, Task 1 on M7 starts at 112
# Job 15, Task 2 on M9 starts at 189
# Job 15, Task 3 on M2 starts at 277
# Job 15, Task 4 on M4 starts at 305
# Job 15, Task 5 on M8 starts at 320
# Job 16, Task 1 on M3 starts at 234
# Job 16, Task 2 on M5 starts at 243
# Job 16, Task 3 on M1 starts at 252
# Job 16, Task 4 on M10 starts at 265
# Job 16, Task 5 on M9 starts at 274
# Job 17, Task 1 on M10 starts at 353
# Job 17, Task 2 on M4 starts at 364
# Job 17, Task 3 on M5 starts at 299
# Job 17, Task 4 on M7 starts at 307
# Job 17, Task 5 on M1 starts at 325
# Job 18, Task 1 on M1 starts at 334
# Job 18, Task 2 on M1 starts at 340
# Generation 85: Best Fitness = 3784.0, Average Fitness = 5225.14
# Generation 86: Best Fitness = 3544.0, Average Fitness = 5335.32
# Generation 87: Best Fitness = 3965.0, Average Fitness = 5423.24
# Generation 88: Best Fitness = 3814.0, Average Fitness = 5276.60
# Generation 89: Best Fitness = 3743.0, Average Fitness = 5250.62
# Generation 90: Best Fitness = 3695.0, Average Fitness = 5352.10
# Generation 91: Best Fitness = 3649.0, Average Fitness = 5298.42
# Generation 92: Best Fitness = 3734.0, Average Fitness = 5230.78
# Generation 93: Best Fitness = 3241.0, Average Fitness = 5035.80
# Generation 94: Best Fitness = 3764.0, Average Fitness = 5213.10
# Generation 95: Best Fitness = 4044.0, Average Fitness = 5131.86
# Generation 96: Best Fitness = 3817.0, Average Fitness = 5071.98
# Generation 97: Best Fitness = 4130.0, Average Fitness = 5267.08
# Generation 98: Best Fitness = 3852.0, Average Fitness = 5182.54
# Generation 99: Best Fitness = 3791.0, Average Fitness = 5270.12
# Generation 100: Best Fitness = 4071.0, Average Fitness = 5125.62
# Best Schedule (Timeline):
# Job 1, Task 5 on M1 starts at 36
# Job 2, Task 5 on M1 starts at 49
# Job 3, Task 5 on M1 starts at 72
# Job 4, Task 5 on M1 starts at 109
# Job 5, Task 5 on M1 starts at 120
# Job 6, Task 5 on M3 starts at 156
# Job 7, Task 5 on M1 starts at 134
# Job 8, Task 5 on M1 starts at 194
# Job 9, Task 5 on M1 starts at 159
# Job 10, Task 5 on M1 starts at 229
# Job 11, Task 5 on M2 starts at 284
# Job 12, Task 5 on M2 starts at 310
# Job 13, Task 5 on M4 starts at 280
# Job 14, Task 5 on M1 starts at 284
# Job 15, Task 5 on M2 starts at 255
# Job 16, Task 5 on M2 starts at 274
# Job 17, Task 5 on M2 starts at 311
# Job 18, Task 5 on M1 starts at 293
# Job 19, Task 5 on M1 starts at 340
# Job 20, Task 5 on M2 starts at 399
# Job 5, Task 1 on M6 starts at 88
# Job 5, Task 2 on M1 starts at 92
# Job 5, Task 3 on M1 starts at 103
# Job 5, Task 4 on M4 starts at 115
# Job 5, Task 5 on M3 starts at 120
# Job 6, Task 1 on M1 starts at 111
# Job 6, Task 2 on M3 starts at 126
# Job 6, Task 3 on M3 starts at 84
# Job 6, Task 4 on M6 starts at 150
# Job 6, Task 5 on M2 starts at 156
# Job 7, Task 1 on M5 starts at 145
# Job 7, Task 2 on M6 starts at 155
# Job 7, Task 3 on M1 starts at 118
# Job 7, Task 4 on M2 starts at 171
# Job 7, Task 5 on M7 starts at 134
# Job 8, Task 1 on M8 starts at 50
# Job 8, Task 2 on M9 starts at 127
# Job 8, Task 3 on M1 starts at 182
# Job 8, Task 4 on M4 starts at 186
# Job 8, Task 5 on M2 starts at 194
# Job 9, Task 1 on M7 starts at 166
# Job 9, Task 2 on M3 starts at 173
# Job 9, Task 3 on M4 starts at 190
# Job 9, Task 4 on M2 starts at 201
# Job 9, Task 5 on M4 starts at 159
# Job 10, Task 1 on M4 starts at 6
# Job 10, Task 2 on M8 starts at 85
# Job 10, Task 3 on M7 starts at 203
# Job 10, Task 4 on M4 starts at 189
# Job 10, Task 5 on M3 starts at 229
# Job 11, Task 1 on M8 starts at 91
# Job 11, Task 2 on M9 starts at 143
# Job 11, Task 3 on M9 starts at 188
# Job 11, Task 4 on M2 starts at 280
# Job 11, Task 5 on M1 starts at 284
# Job 12, Task 1 on M10 starts at 195
# Job 12, Task 2 on M8 starts at 229
# Job 12, Task 3 on M9 starts at 232
# Job 12, Task 4 on M10 starts at 301
# Job 12, Task 5 on M4 starts at 310
# Job 13, Task 1 on M3 starts at 187
# Job 13, Task 2 on M4 starts at 215
# Job 13, Task 3 on M1 starts at 282
# Job 13, Task 4 on M6 starts at 268
# Job 13, Task 5 on M1 starts at 280
# Job 14, Task 1 on M3 starts at 189
# Job 14, Task 2 on M4 starts at 198
# Job 14, Task 3 on M9 starts at 237
# Job 14, Task 4 on M9 starts at 244
# Job 14, Task 5 on M2 starts at 284
# Job 15, Task 1 on M2 starts at 222
# Job 15, Task 2 on M3 starts at 221
# Job 15, Task 3 on M10 starts at 239
# Job 15, Task 4 on M7 starts at 244
# Job 15, Task 5 on M10 starts at 255
# Job 16, Task 1 on M1 starts at 238
# Job 16, Task 2 on M7 starts at 250
# Job 16, Task 3 on M6 starts at 351
# Job 16, Task 4 on M4 starts at 269
# Job 16, Task 5 on M4 starts at 274
# Job 17, Task 1 on M10 starts at 321
# Job 17, Task 2 on M9 starts at 350
# Job 17, Task 3 on M4 starts at 281
# Job 17, Task 4 on M7 starts at 286
# Job 17, Task 5 on M6 starts at 311
# Job 18, Task 1 on M6 starts at 360
# Job 18, Task 2 on M6 starts at 364
# Job 18, Task 3 on M5 starts at 275
# Job 18, Task 4 on M7 starts at 378
# Job 18, Task 5 on M5 starts at 293
# Job 19, Task 1 on M8 starts at 314
# Job 19, Task 2 on M1 starts at 288
# Job 19, Task 3 on M7 starts at 323
# Job 19, Task 4 on M10 starts at 333
# Job 19, Task 5 on M3 starts at 340
# Job 20, Task 1 on M6 starts at 341
# Job 20, Task 2 on M2 starts at 349
# Job 20, Task 3 on M6 starts at 364
# Job 20, Task 4 on M6 starts at 394
# Job 20, Task 5 on M4 starts at 399
#
# Testing Problem Instance 4 with Q-Learning
# Generation 1: Best Fitness = 395.0, Average Fitness = 484.54
# Generation 2: Best Fitness = 1940.0, Average Fitness = 3948.98
# Generation 3: Best Fitness = 2113.0, Average Fitness = 4200.30
# Generation 4: Best Fitness = 1818.0, Average Fitness = 4544.08
# Generation 5: Best Fitness = 2671.0, Average Fitness = 4590.30
# Generation 6: Best Fitness = 2285.0, Average Fitness = 4261.60
# Generation 7: Best Fitness = 2635.0, Average Fitness = 4344.82
# Generation 8: Best Fitness = 1648.0, Average Fitness = 4416.10
# Generation 9: Best Fitness = 2338.0, Average Fitness = 4633.62
# Generation 10: Best Fitness = 2160.0, Average Fitness = 4454.60
# Generation 11: Best Fitness = 2510.0, Average Fitness = 4266.20
# Generation 12: Best Fitness = 2383.0, Average Fitness = 4400.54
# Job 8, Task 5 on M1 starts at 189
# Job 9, Task 5 on M2 starts at 190
# Job 10, Task 5 on M4 starts at 178
# Job 11, Task 5 on M2 starts at 192
# Job 12, Task 5 on M2 starts at 170
# Job 13, Task 5 on M1 starts at 246
# Job 14, Task 5 on M2 starts at 277
# Job 15, Task 5 on M1 starts at 264
# Job 16, Task 5 on M6 starts at 206
# Job 17, Task 5 on M1 starts at 300
# Job 18, Task 5 on M1 starts at 325
# Job 19, Task 5 on M1 starts at 362
# Job 20, Task 5 on M2 starts at 343
# Job 5, Task 1 on M7 starts at 66
# Job 5, Task 2 on M7 starts at 51
# Job 5, Task 3 on M6 starts at 59
# Job 5, Task 4 on M7 starts at 63
# Job 5, Task 5 on M1 starts at 86
# Job 6, Task 1 on M3 starts at 103
# Job 6, Task 2 on M7 starts at 101
# Job 6, Task 3 on M4 starts at 111
# Job 6, Task 4 on M4 starts at 136
# Job 6, Task 5 on M8 starts at 142
# Job 7, Task 1 on M10 starts at 103
# Job 7, Task 2 on M3 starts at 112
# Job 7, Task 3 on M7 starts at 15
# Job 7, Task 4 on M9 starts at 146
# Job 7, Task 5 on M9 starts at 66
# Job 8, Task 1 on M3 starts at 87
# Job 8, Task 2 on M3 starts at 132
# Job 8, Task 3 on M8 starts at 180
# Job 8, Task 4 on M7 starts at 218
# Job 8, Task 5 on M9 starts at 189
# Job 9, Task 1 on M8 starts at 153
# Job 9, Task 2 on M4 starts at 168
# Job 9, Task 3 on M1 starts at 171
# Job 9, Task 4 on M3 starts at 183
# Job 9, Task 5 on M7 starts at 190
# Job 10, Task 1 on M10 starts at 110
# Job 10, Task 2 on M9 starts at 154
# Job 10, Task 3 on M3 starts at 186
# Job 10, Task 4 on M9 starts at 174
# Job 10, Task 5 on M9 starts at 178
# Job 11, Task 1 on M4 starts at 156
# Job 11, Task 2 on M10 starts at 167
# Job 11, Task 3 on M3 starts at 114
# Job 11, Task 4 on M6 starts at 127
# Job 11, Task 5 on M3 starts at 192
# Job 12, Task 1 on M7 starts at 194
# Job 12, Task 2 on M8 starts at 201
# Job 12, Task 3 on M4 starts at 214
# Job 12, Task 4 on M9 starts at 220
# Job 12, Task 5 on M4 starts at 170
# Job 13, Task 1 on M7 starts at 184
# Job 13, Task 2 on M7 starts at 231
# Job 13, Task 3 on M1 starts at 122
# Job 13, Task 4 on M9 starts at 129
# Job 13, Task 5 on M9 starts at 246
# Job 14, Task 1 on M3 starts at 243
# Job 14, Task 2 on M5 starts at 166
# Job 14, Task 3 on M9 starts at 243
# Job 14, Task 4 on M2 starts at 267
# Job 14, Task 5 on M8 starts at 277
# Job 15, Task 1 on M4 starts at 205
# Job 15, Task 2 on M1 starts at 244
# Job 15, Task 3 on M5 starts at 228
# Job 15, Task 4 on M7 starts at 253
# Job 15, Task 5 on M1 starts at 264
# Job 16, Task 1 on M2 starts at 120
# Job 16, Task 2 on M7 starts at 327
# Job 16, Task 3 on M10 starts at 271
# Job 16, Task 4 on M10 starts at 195
# Job 16, Task 5 on M5 starts at 206
# Job 17, Task 1 on M1 starts at 180
# Job 17, Task 2 on M7 starts at 276
# Job 17, Task 3 on M2 starts at 291
# Job 17, Task 4 on M2 starts at 205
# Job 17, Task 5 on M9 starts at 300
# Job 18, Task 1 on M1 starts at 269
# Job 18, Task 2 on M6 starts at 212
# Job 18, Task 3 on M6 starts at 218
# Job 18, Task 4 on M4 starts at 312
# Job 18, Task 5 on M2 starts at 325
# Job 19, Task 1 on M2 starts at 333
# Job 19, Task 2 on M10 starts at 347
# Job 19, Task 3 on M9 starts at 230
# Job 19, Task 4 on M5 starts at 239
# Job 19, Task 5 on M7 starts at 362
# Job 20, Task 1 on M1 starts at 358
# Job 20, Task 2 on M3 starts at 378
# Job 20, Task 3 on M10 starts at 388
# Job 20, Task 4 on M5 starts at 350
# Job 20, Task 5 on M4 starts at 343
#
# Testing Problem Instance 5 with Q-Learning
# Generation 1: Best Fitness = 389.0, Average Fitness = 496.58
# Generation 2: Best Fitness = 1978.0, Average Fitness = 4084.54
# Generation 3: Best Fitness = 1682.0, Average Fitness = 4957.86
# Generation 4: Best Fitness = 1987.0, Average Fitness = 4649.14
# Generation 5: Best Fitness = 1859.0, Average Fitness = 4675.94
# Generation 6: Best Fitness = 2411.0, Average Fitness = 4844.12
# Generation 7: Best Fitness = 3271.0, Average Fitness = 5067.08
# Generation 8: Best Fitness = 2949.0, Average Fitness = 5220.94
# Generation 9: Best Fitness = 3125.0, Average Fitness = 5270.56
# Generation 10: Best Fitness = 3238.0, Average Fitness = 5239.26
# Generation 11: Best Fitness = 3212.0, Average Fitness = 5149.46
# Generation 12: Best Fitness = 2533.0, Average Fitness = 4972.20
# Generation 13: Best Fitness = 2602.0, Average Fitness = 5130.06
# Generation 14: Best Fitness = 2777.0, Average Fitness = 5303.64
# Generation 15: Best Fitness = 3313.0, Average Fitness = 5226.50
# Generation 16: Best Fitness = 2836.0, Average Fitness = 5313.34
# Generation 17: Best Fitness = 3090.0, Average Fitness = 5199.12
# Generation 18: Best Fitness = 3610.0, Average Fitness = 5541.70
# Generation 19: Best Fitness = 3564.0, Average Fitness = 5307.64
# Generation 20: Best Fitness = 3856.0, Average Fitness = 5569.34
# Generation 21: Best Fitness = 3125.0, Average Fitness = 5345.26
# Generation 22: Best Fitness = 2847.0, Average Fitness = 5641.66
# Generation 23: Best Fitness = 3715.0, Average Fitness = 5497.30
# Generation 24: Best Fitness = 3257.0, Average Fitness = 5206.66
# Generation 25: Best Fitness = 3370.0, Average Fitness = 5298.32
# Generation 26: Best Fitness = 3220.0, Average Fitness = 4964.90
# Generation 27: Best Fitness = 3460.0, Average Fitness = 5310.60
# Generation 28: Best Fitness = 3567.0, Average Fitness = 5127.78
# Generation 29: Best Fitness = 3411.0, Average Fitness = 5089.64
# Generation 30: Best Fitness = 2943.0, Average Fitness = 4852.42
# Generation 31: Best Fitness = 3191.0, Average Fitness = 4749.38
# Generation 32: Best Fitness = 2599.0, Average Fitness = 4958.56
# Generation 33: Best Fitness = 3137.0, Average Fitness = 4991.38
# Generation 80: Best Fitness = 3548.0, Average Fitness = 5060.28
# Generation 81: Best Fitness = 3522.0, Average Fitness = 5177.84
# Generation 82: Best Fitness = 3516.0, Average Fitness = 5284.70
# Generation 83: Best Fitness = 3412.0, Average Fitness = 5010.98
# Generation 84: Best Fitness = 3358.0, Average Fitness = 5021.00
# Generation 85: Best Fitness = 3700.0, Average Fitness = 5305.54
# Generation 86: Best Fitness = 4034.0, Average Fitness = 5352.44
# Generation 87: Best Fitness = 3679.0, Average Fitness = 5180.16
# Generation 88: Best Fitness = 3742.0, Average Fitness = 5365.48
# Generation 89: Best Fitness = 3203.0, Average Fitness = 5225.06
# Generation 90: Best Fitness = 3625.0, Average Fitness = 5210.42
# Generation 91: Best Fitness = 3271.0, Average Fitness = 5291.46
# Generation 92: Best Fitness = 3351.0, Average Fitness = 5180.48
# Generation 93: Best Fitness = 3605.0, Average Fitness = 5111.02
# Generation 94: Best Fitness = 3608.0, Average Fitness = 5327.32
# Generation 95: Best Fitness = 3550.0, Average Fitness = 5251.80
# Generation 96: Best Fitness = 3646.0, Average Fitness = 5313.00
# Generation 97: Best Fitness = 3656.0, Average Fitness = 5406.14
# Generation 98: Best Fitness = 3731.0, Average Fitness = 5407.66
# Generation 99: Best Fitness = 3958.0, Average Fitness = 5427.28
# Generation 100: Best Fitness = 4458.0, Average Fitness = 5695.80
# Best Schedule (Timeline):
# Job 1, Task 5 on M1 starts at 46
# Job 2, Task 5 on M1 starts at 40
# Job 3, Task 5 on M1 starts at 59
# Job 4, Task 5 on M1 starts at 79
# Job 5, Task 5 on M2 starts at 166
# Job 6, Task 5 on M1 starts at 113
# Job 7, Task 5 on M2 starts at 138
# Job 8, Task 5 on M2 starts at 124
# Job 9, Task 5 on M2 starts at 181
# Job 10, Task 5 on M2 starts at 185
# Job 11, Task 5 on M1 starts at 159
# Job 12, Task 5 on M2 starts at 203
# Job 13, Task 5 on M2 starts at 213
# Job 14, Task 5 on M1 starts at 251
# Job 15, Task 5 on M4 starts at 285
# Job 16, Task 5 on M9 starts at 300
# Job 17, Task 5 on M1 starts at 329
# Job 18, Task 5 on M2 starts at 320
# Job 19, Task 5 on M2 starts at 405
# Job 20, Task 5 on M2 starts at 406
# Job 5, Task 1 on M7 starts at 45
# Job 5, Task 2 on M5 starts at 59
# Job 5, Task 3 on M4 starts at 146
# Job 5, Task 4 on M2 starts at 157
# Job 5, Task 5 on M6 starts at 166
# Job 6, Task 1 on M10 starts at 79
# Job 6, Task 2 on M10 starts at 82
# Job 6, Task 3 on M4 starts at 101
# Job 6, Task 4 on M7 starts at 106
# Job 6, Task 5 on M9 starts at 113
# Job 7, Task 1 on M4 starts at 105
# Job 7, Task 2 on M7 starts at 115
# Job 7, Task 3 on M8 starts at 120
# Job 7, Task 4 on M9 starts at 134
# Job 7, Task 5 on M2 starts at 138
# Job 8, Task 1 on M6 starts at 31
# Job 8, Task 2 on M8 starts at 95
# Job 8, Task 3 on M8 starts at 100
# Job 8, Task 4 on M8 starts at 114
# Generation 98: Best Fitness = 3895.0, Average Fitness = 5207.06
# Generation 99: Best Fitness = 3700.0, Average Fitness = 4897.26
# Generation 100: Best Fitness = 3267.0, Average Fitness = 4831.18
# Best Schedule (Timeline):
# Job 1, Task 5 on M1 starts at 32
# Job 2, Task 5 on M1 starts at 30
# Job 3, Task 5 on M1 starts at 61
# Job 4, Task 5 on M1 starts at 35
# Job 5, Task 5 on M1 starts at 51
# Job 6, Task 5 on M1 starts at 107
# Job 7, Task 5 on M10 starts at 146
# Job 8, Task 5 on M1 starts at 125
# Job 9, Task 5 on M2 starts at 166
# Job 10, Task 5 on M2 starts at 203
# Job 11, Task 5 on M1 starts at 228
# Job 12, Task 5 on M2 starts at 205
# Job 13, Task 5 on M2 starts at 238
# Job 14, Task 5 on M1 starts at 271
# Job 15, Task 5 on M2 starts at 220
# Job 16, Task 5 on M8 starts at 296
# Job 17, Task 5 on M1 starts at 247
# Job 18, Task 5 on M1 starts at 319
# Job 19, Task 5 on M1 starts at 304
# Job 20, Task 5 on M4 starts at 319
# Job 5, Task 1 on M6 starts at 11
# Job 5, Task 2 on M9 starts at 76
# Job 5, Task 3 on M5 starts at 87
# Job 5, Task 4 on M1 starts at 40
# Job 5, Task 5 on M2 starts at 51
# Job 6, Task 1 on M7 starts at 69
# Job 6, Task 2 on M3 starts at 81
# Job 6, Task 3 on M9 starts at 134
# Job 6, Task 4 on M10 starts at 144
# Job 6, Task 5 on M10 starts at 107
# Job 7, Task 1 on M5 starts at 2
# Job 7, Task 2 on M3 starts at 86
# Job 7, Task 3 on M6 starts at 93
# Job 7, Task 4 on M7 starts at 139
# Job 7, Task 5 on M10 starts at 146
# Job 8, Task 1 on M4 starts at 123
# Job 8, Task 2 on M5 starts at 130
# Job 8, Task 3 on M2 starts at 134
# Job 8, Task 4 on M5 starts at 139
# Job 8, Task 5 on M2 starts at 125
# Job 9, Task 1 on M2 starts at 138
# Job 9, Task 2 on M1 starts at 145
# Job 9, Task 3 on M2 starts at 119
# Job 9, Task 4 on M6 starts at 162
# Job 9, Task 5 on M6 starts at 166
# Job 10, Task 1 on M6 starts at 189
# Job 10, Task 2 on M1 starts at 110
# Job 10, Task 3 on M5 starts at 223
# Job 10, Task 4 on M7 starts at 230
# Job 10, Task 5 on M1 starts at 203
# Job 11, Task 1 on M3 starts at 122
# Job 11, Task 2 on M2 starts at 131
# Job 11, Task 3 on M9 starts at 159
# Job 11, Task 4 on M4 starts at 166
# Job 11, Task 5 on M8 starts at 228
# Job 12, Task 1 on M3 starts at 158
# Job 12, Task 2 on M6 starts at 170
# Job 12, Task 3 on M8 starts at 181
# Job 12, Task 4 on M8 starts at 189
# Job 12, Task 5 on M8 starts at 205
# Job 13, Task 1 on M5 starts at 173
# Job 13, Task 2 on M1 starts at 223
# Job 13, Task 3 on M7 starts at 228
# Job 13, Task 4 on M8 starts at 241
# Job 13, Task 5 on M5 starts at 238
# Job 14, Task 1 on M10 starts at 203
# Job 14, Task 2 on M5 starts at 245
# Job 14, Task 3 on M4 starts at 241
# Job 14, Task 4 on M6 starts at 257
# Job 14, Task 5 on M2 starts at 271
# Job 15, Task 1 on M8 starts at 242
# Job 15, Task 2 on M8 starts at 235
# Job 15, Task 3 on M10 starts at 270
# Job 15, Task 4 on M2 starts at 280
# Job 15, Task 5 on M10 starts at 220
# Job 16, Task 1 on M9 starts at 222
# Job 16, Task 2 on M6 starts at 251
# Job 16, Task 3 on M10 starts at 233
# Job 16, Task 4 on M4 starts at 276
# Job 16, Task 5 on M10 starts at 296
# Job 17, Task 1 on M4 starts at 222
# Job 17, Task 2 on M3 starts at 220
# Job 17, Task 3 on M1 starts at 229
# Job 17, Task 4 on M7 starts at 299
# Job 17, Task 5 on M9 starts at 247
# Job 18, Task 1 on M7 starts at 253
# Job 18, Task 2 on M1 starts at 297
# Job 18, Task 3 on M5 starts at 310
# Job 18, Task 4 on M8 starts at 315
# Job 18, Task 5 on M1 starts at 319
# Job 19, Task 1 on M10 starts at 356
# Job 19, Task 2 on M6 starts at 346
# Job 19, Task 3 on M7 starts at 295
# Job 19, Task 4 on M4 starts at 299
# Job 19, Task 5 on M3 starts at 304
# Job 20, Task 1 on M2 starts at 242
# Job 20, Task 2 on M8 starts at 302
# Job 20, Task 3 on M3 starts at 380
# Job 20, Task 4 on M5 starts at 320
# Job 20, Task 5 on M6 starts at 319
#
# Testing Problem Instance 10 with Q-Learning
# Generation 1: Best Fitness = 441.0, Average Fitness = 526.20
# Generation 2: Best Fitness = 1873.0, Average Fitness = 4600.52
# Generation 3: Best Fitness = 3023.0, Average Fitness = 4922.96
# Generation 4: Best Fitness = 2959.0, Average Fitness = 4942.92
# Generation 5: Best Fitness = 1791.0, Average Fitness = 4974.20
# Generation 6: Best Fitness = 2190.0, Average Fitness = 5326.44
# Generation 7: Best Fitness = 2543.0, Average Fitness = 4897.38
# Generation 8: Best Fitness = 3065.0, Average Fitness = 5337.58
# Generation 9: Best Fitness = 2812.0, Average Fitness = 5305.26
# Generation 10: Best Fitness = 3432.0, Average Fitness = 5500.10
# Generation 11: Best Fitness = 3067.0, Average Fitness = 5364.40
# Generation 12: Best Fitness = 3201.0, Average Fitness = 5548.44
# Generation 13: Best Fitness = 2725.0, Average Fitness = 5468.00
# Generation 14: Best Fitness = 3026.0, Average Fitness = 5970.54
# Generation 15: Best Fitness = 2784.0, Average Fitness = 5699.82
# Generation 16: Best Fitness = 2996.0, Average Fitness = 5435.30
# Generation 17: Best Fitness = 3503.0, Average Fitness = 5325.82
# Generation 18: Best Fitness = 3199.0, Average Fitness = 5554.06
# Generation 19: Best Fitness = 3203.0, Average Fitness = 5779.38
# Generation 20: Best Fitness = 3456.0, Average Fitness = 5788.78
# Generation 21: Best Fitness = 3958.0, Average Fitness = 5805.80
# Generation 22: Best Fitness = 3038.0, Average Fitness = 5823.60
# Generation 23: Best Fitness = 3356.0, Average Fitness = 6028.74
# Generation 24: Best Fitness = 3177.0, Average Fitness = 5619.76
# Generation 25: Best Fitness = 2900.0, Average Fitness = 5761.14
# Generation 72: Best Fitness = 3627.0, Average Fitness = 5748.84
# Generation 73: Best Fitness = 4354.0, Average Fitness = 6039.84
# Generation 74: Best Fitness = 4287.0, Average Fitness = 6010.66
# Generation 75: Best Fitness = 4232.0, Average Fitness = 6024.58
# Generation 76: Best Fitness = 3674.0, Average Fitness = 5951.58
# Generation 77: Best Fitness = 4124.0, Average Fitness = 5892.12
# Generation 78: Best Fitness = 3678.0, Average Fitness = 5867.60
# Generation 79: Best Fitness = 3916.0, Average Fitness = 5662.08
# Generation 80: Best Fitness = 3416.0, Average Fitness = 5837.76
# Generation 81: Best Fitness = 4274.0, Average Fitness = 5980.60
# Generation 82: Best Fitness = 4066.0, Average Fitness = 5735.42
# Generation 83: Best Fitness = 3588.0, Average Fitness = 6037.64
# Generation 84: Best Fitness = 3769.0, Average Fitness = 6082.26
# Generation 85: Best Fitness = 3966.0, Average Fitness = 6023.34
# Generation 86: Best Fitness = 4196.0, Average Fitness = 5831.98
# Generation 87: Best Fitness = 4105.0, Average Fitness = 5793.52
# Generation 88: Best Fitness = 3581.0, Average Fitness = 5551.62
# Generation 89: Best Fitness = 3867.0, Average Fitness = 5956.94
# Generation 90: Best Fitness = 4235.0, Average Fitness = 6226.54
# Generation 91: Best Fitness = 4388.0, Average Fitness = 5962.94
# Generation 92: Best Fitness = 3761.0, Average Fitness = 6006.54
# Generation 93: Best Fitness = 3834.0, Average Fitness = 5929.48
# Generation 94: Best Fitness = 4345.0, Average Fitness = 5707.76
# Generation 95: Best Fitness = 4362.0, Average Fitness = 6036.78
# Generation 96: Best Fitness = 4208.0, Average Fitness = 6062.54
# Generation 97: Best Fitness = 4477.0, Average Fitness = 6061.06
# Generation 98: Best Fitness = 4051.0, Average Fitness = 6040.14
# Generation 99: Best Fitness = 4191.0, Average Fitness = 5898.64
# Generation 100: Best Fitness = 3528.0, Average Fitness = 5909.86
# Best Schedule (Timeline):
# Job 1, Task 5 on M1 starts at 27
# Job 2, Task 5 on M1 starts at 78
# Job 3, Task 5 on M4 starts at 101
# Job 4, Task 5 on M1 starts at 87
# Job 5, Task 5 on M2 starts at 107
# Job 6, Task 5 on M2 starts at 169
# Job 7, Task 5 on M3 starts at 232
# Job 8, Task 5 on M1 starts at 215
# Job 9, Task 5 on M2 starts at 179
# Job 10, Task 5 on M1 starts at 159
# Job 11, Task 5 on M2 starts at 236
# Job 12, Task 5 on M2 starts at 277
# Job 13, Task 5 on M5 starts at 269
# Job 14, Task 5 on M2 starts at 297
# Job 15, Task 5 on M2 starts at 325
# Job 16, Task 5 on M2 starts at 395
# Job 17, Task 5 on M4 starts at 304
# Job 18, Task 5 on M2 starts at 292
# Job 19, Task 5 on M2 starts at 492
# Job 20, Task 5 on M2 starts at 490
# Job 5, Task 1 on M7 starts at 131
# Job 5, Task 2 on M3 starts at 118
# Job 5, Task 3 on M9 starts at 87
# Job 5, Task 4 on M9 starts at 97
# Job 5, Task 5 on M2 starts at 107
# Job 6, Task 1 on M8 starts at 78
# Job 6, Task 2 on M10 starts at 124
# Job 6, Task 3 on M2 starts at 112
# Job 6, Task 4 on M3 starts at 118
# Job 6, Task 5 on M8 starts at 169
# Job 7, Task 1 on M9 starts at 120
# Job 7, Task 2 on M4 starts at 201
# Job 7, Task 3 on M9 starts at 212
# Job 7, Task 4 on M9 starts at 189
# Job 7, Task 5 on M7 starts at 232
# Job 8, Task 1 on M9 starts at 0
# Job 8, Task 2 on M6 starts at 130
# Job 8, Task 3 on M6 starts at 132
# Job 8, Task 4 on M10 starts at 182
# Job 8, Task 5 on M9 starts at 215
# Job 9, Task 1 on M2 starts at 0
# Job 9, Task 2 on M6 starts at 176
# Job 9, Task 3 on M7 starts at 182
# Job 9, Task 4 on M4 starts at 216
# Job 9, Task 5 on M5 starts at 179
# Job 10, Task 1 on M7 starts at 157
# Job 10, Task 2 on M5 starts at 187
# Job 10, Task 3 on M8 starts at 197
# Job 10, Task 4 on M1 starts at 206
# Job 10, Task 5 on M6 starts at 159
# Job 11, Task 1 on M6 starts at 196
# Job 11, Task 2 on M10 starts at 227
# Job 11, Task 3 on M7 starts at 236
# Job 11, Task 4 on M2 starts at 241
# Job 11, Task 5 on M10 starts at 236
# Job 12, Task 1 on M9 starts at 217
# Job 12, Task 2 on M4 starts at 225
# Job 12, Task 3 on M7 starts at 212
# Job 12, Task 4 on M3 starts at 270
# Job 12, Task 5 on M6 starts at 277
# Job 13, Task 1 on M8 starts at 132
# Job 13, Task 2 on M3 starts at 273
# Job 13, Task 3 on M2 starts at 260
# Job 13, Task 4 on M6 starts at 267
# Job 13, Task 5 on M9 starts at 269
# Job 14, Task 1 on M2 starts at 210
# Job 14, Task 2 on M5 starts at 326
# Job 14, Task 3 on M7 starts at 271
# Job 14, Task 4 on M3 starts at 290
# Job 14, Task 5 on M8 starts at 297
# Job 15, Task 1 on M2 starts at 302
# Job 15, Task 2 on M4 starts at 333
# Job 15, Task 3 on M5 starts at 345
# Job 15, Task 4 on M10 starts at 312
# Job 15, Task 5 on M6 starts at 325
# Job 16, Task 1 on M9 starts at 219
# Job 16, Task 2 on M7 starts at 307
# Job 16, Task 3 on M3 starts at 378
# Job 16, Task 4 on M7 starts at 392
# Job 16, Task 5 on M3 starts at 395
# Job 17, Task 1 on M8 starts at 384
# Job 17, Task 2 on M9 starts at 391
# Job 17, Task 3 on M6 starts at 346
# Job 17, Task 4 on M6 starts at 351
# Job 17, Task 5 on M1 starts at 304
# Job 18, Task 1 on M2 starts at 374
# Job 18, Task 2 on M3 starts at 429
# Job 18, Task 3 on M1 starts at 437
# Job 18, Task 4 on M1 starts at 445
# Job 18, Task 5 on M1 starts at 292
# Job 19, Task 1 on M6 starts at 282
# Job 19, Task 2 on M7 starts at 471
# Job 19, Task 3 on M4 starts at 485
# Job 19, Task 4 on M2 starts at 496
# Job 19, Task 5 on M6 starts at 492
# Job 20, Task 1 on M5 starts at 390
# Job 20, Task 2 on M3 starts at 399
# Job 20, Task 3 on M1 starts at 410
# Job 20, Task 4 on M1 starts at 404
# Job 20, Task 5 on M6 starts at 490
